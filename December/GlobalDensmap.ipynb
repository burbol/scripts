# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from scipy import stats
from matplotlib.font_manager import FontProperties
from fractions import Fraction
from scipy import constants

# %%
# %cd /Users/burbol2/Dropbox/Apps/Computable/Definitions_Interface/All_systems_without66
# Out:
# /Users/burbol2/Dropbox/Apps/Computable/Definitions_Interface/All_systems_without66

# %%
#Here we read from a file the positions of the first water peaks of each system and save them in the array "peak"
peak = np.loadtxt('/Users/burbol2/Dropbox/Apps/Computable/Definitions_Interface/All_systems_without66/WaterPeaksFinal.txt', skiprows=1)

# We create the dictionary "systems" which relates the systems with the positions of the array "peakcount". 
# For example: "systems[(11, 3000)]" would give back the position 22, which can be used to call "peakcount[22]" 
# and get back the shift value of the system with a SAM  with 11% OH- coverage and a water droplet of 3000 molecules.
# This is done for the case of using this script with only a subgroup of systems
SAMs=[0, 5, 11, 17,33,50]
peakpos = 0
systems={}
for b in SAMs:
    for c in [1000, 2000, 3000, 4000, 5000, 6500, 7000, 8000, 9000, 10000]:
        z = b, c
        systems[z] = peakpos
        peakpos = peakpos + 1
#print systems[(11, 3000)]

#We substitute the values "b" and "c" to get the corresponding shift value
b=0
c=9000
peakcount = systems[(b, c)]
shift = peak[peakcount]
print "shift=", shift
# Out:
# shift= 2.544

# %%
#Here we read from a file the positions of the first water peaks of each system and save them in the array "peak"
peak3 = np.loadtxt('/Users/burbol2/Dropbox/Apps/Computable/Definitions_Interface/All_systems_without66/GDS_positions_CORRECTED.txt', skiprows=1)

# We create the dictionary "systems" which relates the systems with the positions of the array "peakcount". 
# For example: "systems[(11, 3000)]" would give back the position 22, which can be used to call "peakcount[22]" 
# and get back the shift value of the system with a SAM  with 11% OH- coverage and a water droplet of 3000 molecules.
# This is done for the case of using this script with only a subgroup of systems
peakpos = 0
systems3={}
for b in SAMs:
    for c in [1000, 2000, 3000, 4000, 5000, 6500, 7000, 8000, 9000, 10000]:
        z = b, c
        systems3[z] = peakpos
        peakpos = peakpos + 1
#print systems[(11, 3000)]

#We substitute the values "b" and "c" to get the corresponding shift value
b=0
c=9000
peakcount = systems3[(b, c)]
shift2 = peak3[peakcount]
print "shift2=", shift2
# Out:
# shift2= 2.42575

# %%
#Here we read from a file the positions of the first water peaks of each system and save them in the array "peak"
peak2 = np.loadtxt('/Users/burbol2/Dropbox/Apps/Computable/Definitions_Interface/All_systems_without66/SAMPeaks.txt', skiprows=1)

# We create the dictionary "systems" which relates the systems with the positions of the array "peakcount". 
# For example: "systems[(11, 3000)]" would give back the position 22, which can be used to call "peakcount[22]" 
# and get back the shift value of the system with a SAM  with 11% OH- coverage and a water droplet of 3000 molecules.
# This is done for the case of using this script with only a subgroup of systems
peakpos = 0
systems2={}
for b in [0, 5, 11, 17,33]:
    for c in [1000, 2000, 3000, 4000, 5000, 6500, 7000, 8000, 9000, 10000]:
        z = b, c
        systems2[z] = peakpos
        peakpos = peakpos + 1
#print systems[(11, 3000)]

#We substitute the values "b" and "c" to get the corresponding shift value
b=0
c=9000
peakcount = systems2[(b, c)]
shift3 = peak2[peakcount]
print "shift3=", shift3
# Out:
# shift3= 2.16

# %%
# %cd /Users/burbol2/Dropbox/Apps/Computable/December/StepByStepDropletMethod
>>> import numpy as np
>>> import gromacs.formats
>>> xvg = gromacs.formats.XVG()
xvg.read("ng_density_NVT_sam0_water9000.xvg")
water = xvg.array
xvg.read("ng_density_SAM_sam0_water9000.xvg")
SAM = xvg.array

#change folder to save plots
# %cd /Users/burbol2/Dropbox/Apps/Texpad/DiplomThesis/diplombody_lyx/subfiles/Methods/Images/
# Out:
# /Users/burbol2/Dropbox/Apps/Computable/December/StepByStepDropletMethod
# [Errno 2] No such file or directory: '/Users/burbol2/Dropbox/Apps/Texpad/DiplomThesis/diplombody_lyx/subfiles/Methods/Images/'
# /Users/burbol2/Dropbox/Apps/Computable/December/StepByStepDropletMethod

# %%
xvg.plot()

# %%
#To transform mass density to molec. density: =>not needed for unit density maps, because Hydrogens  are  not counted!!
molarmass = 18.01524 # (M) (10−3 kg/mol) or (g/mol)
unitdens = 33.3679 # (c) (103 mol/m3) or (mol/L)
molarconc = 55.4086 # (n) (1027 m−3) or (1021 cm−3)
# we have: [rho] = kg/m3, we want molec/m3= Avogadro*mol/m3:
# rho/M*avogadro

print constants.N_A
print constants.N_A*molarmass
#print constants.N_A*molarmass*water[1] #now we have molecules/m3
# Out:
# 6.02214129e+23
# 1.08490320653e+25

# %%
#ymax=max(water[1])
ymax=33
d= np.linspace(0, ymax, num=40)
wline=np.ones(len(d))*shift
mline=np.ones(len(d))*shift2
sline=np.ones(len(d))*shift3
plt.plot(water[0],water[1], label='Water Density',color='blue')
plt.plot(SAM[0],SAM[1], label='SAM Density', color='lightblue',lw=0.5)
plt.plot(wline,d, label='Water Peak', lw=1,color='orange')
plt.plot(mline,d, label='GDS', lw=1,color='black')
plt.plot(sline,d, label='SAM Peak', lw=1,color='green')
plt.xlabel('z [nm]',fontsize=22)
plt.ylabel(r'Density $[\frac{Molec.}{m^3}]$',fontsize=22)
plt.legend()
#Set x limits
#xlim(1,12)
# Set y limits
ylim(0,ymax)
plt.suptitle('SAM '+str(b)+'%, Water '+str(c)+' molec.',style='italic',bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
#pylab.savefig('global_densmap1_'+str(b)+'.jpg', bbox_inches='tight')

# %%
ymax=300
d= np.linspace(0, ymax, num=40)
wline=np.ones(len(d))*shift
mline=np.ones(len(d))*shift2
sline=np.ones(len(d))*shift3
plt.plot(water[0],water[1], label='Water Density',color='blue')
plt.plot(SAM[0],SAM[1], label='SAM Density', color='lightblue',lw=1.5)
plt.plot(wline,d, label='Water Peak', lw=3,color='orange')
plt.plot(mline,d, label='GDS', lw=3,color='black')
plt.plot(sline,d, label='SAM Peak', lw=3,color='green')
plt.xlabel('z [nm]',fontsize=22)
plt.ylabel(r'Density $[\frac{Kg}{m3}]$',fontsize=22)
plt.legend()
#Set x limits
xlim(4,7)
# Set y limits
ylim(0,ymax)
plt.suptitle('SAM '+str(b)+'%, Water '+str(c)+' molec.',style='italic',bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
#pylab.savefig('global_densmap2_'+str(b)+'.jpg', bbox_inches='tight')

# %%
ymax=8000
d= np.linspace(0, ymax, num=40)
wline=np.ones(len(d))*shift
mline=np.ones(len(d))*shift2
sline=np.ones(len(d))*shift3
plt.plot(water[0],water[1], label='Water Density',color='blue')
plt.plot(SAM[0],SAM[1], label='SAM Density', color='lightblue',lw=1.5)
plt.plot(wline,d, label='Water Peak', lw=3,color='orange')
plt.plot(mline,d, label='GDS', lw=3,color='black')
plt.plot(sline,d, label='SAM Peak', lw=3,color='green')
plt.xlabel('z [nm]',fontsize=22)
plt.ylabel(r'Density $[\frac{Kg}{m3}]$',fontsize=22)
plt.legend()
#Set x limits
xlim(2,3)
# Set y limits
#ylim(0,ymax)
plt.suptitle('SAM '+str(b)+'%, Water '+str(c)+' molec.',style='italic',bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
#pylab.savefig('global_densmap3_'+str(b)+'.jpg', bbox_inches='tight')

# %%
b=33
c=1000
peakcount = systems[(b, c)]
shift = peak[peakcount]
print "shift=", shift

peakcount = systems2[(b, c)]
shift3 = peak2[peakcount]
print "shift3=", shift3

peakcount = systems3[(b, c)]
shift2 = peak3[peakcount]
print "shift2=", shift2
# Out:
# shift= 5.12
# shift3= 4.96
# shift2= 5.05654

# %%
# %cd /Users/burbol2/Dropbox/Apps/Computable/December/StepByStepDropletMethod
xvg = gromacs.formats.XVG()

xvg.read("g_density_NVT_sam33_water9000.xvg")
water = xvg.array
xvg.read("g_density_SAM_sam33_water9000.xvg")
SAM = xvg.array

#change folder to save plots
# %cd /Users/burbol2/Dropbox/Apps/Texpad/DiplomThesis/diplombody_lyx/subfiles/Methods/Images/
# Out:
# /Users/burbol2/Dropbox/Apps/Computable/December/StepByStepDropletMethod
# [Errno 2] No such file or directory: '/Users/burbol2/Dropbox/Apps/Texpad/DiplomThesis/diplombody_lyx/subfiles/Methods/Images/'
# /Users/burbol2/Dropbox/Apps/Computable/December/StepByStepDropletMethod

# %%
ymax=400
d= np.linspace(0, ymax, num=40)
wline=np.ones(len(d))*shift
mline=np.ones(len(d))*shift2
sline=np.ones(len(d))*shift3
plt.plot(water[0],water[1], label='Water Density',color='blue')
plt.plot(SAM[0],SAM[1], label='SAM Density', color='lightblue',lw=0.5)
plt.plot(wline,d, label='Water Peak', lw=3,color='orange')
plt.plot(mline,d, label='GDS', lw=3,color='black')
plt.plot(sline,d, label='SAM Peak', lw=3,color='green')
plt.xlabel('z [nm]',fontsize=22)
plt.ylabel(r'Density $[\frac{Kg}{m3}]$',fontsize=22)
plt.legend()
#Set x limits
xlim(1,12)
# Set y limits
ylim(0,ymax)
plt.suptitle('SAM '+str(b)+'%, Water '+str(c)+' molec.',style='italic',bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
#pylab.savefig('global_densmap1_'+str(b)+'.jpg', bbox_inches='tight')

# %%
ymax=400
d= np.linspace(0, ymax, num=40)
wline=np.ones(len(d))*shift
mline=np.ones(len(d))*shift2
sline=np.ones(len(d))*shift3
plt.plot(water[0],water[1], label='Water Density',color='blue')
plt.plot(SAM[0],SAM[1], label='SAM Density', color='lightblue',lw=1.5)
plt.plot(wline,d, label='Water Peak', lw=3,color='orange')
plt.plot(mline,d, label='GDS', lw=3,color='black')
plt.plot(sline,d, label='SAM Peak', lw=3,color='green')
plt.xlabel('z [nm]',fontsize=22)
plt.ylabel(r'Density $[\frac{Kg}{m3}]$',fontsize=22)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
#plt.legend()
#Set x limits
xlim(4.7,5.9)
# Set y limits
ylim(0,ymax)
plt.suptitle('SAM '+str(b)+'%, Water '+str(c)+' molec.',style='italic',bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
#pylab.savefig('global_densmap2_'+str(b)+'.jpg', bbox_inches='tight')

# %%
ymax=6000
d= np.linspace(0, ymax, num=40)
wline=np.ones(len(d))*shift
mline=np.ones(len(d))*shift2
sline=np.ones(len(d))*shift3
plt.plot(water[0],water[1], label='Water Density',color='blue')
plt.plot(SAM[0],SAM[1], label='SAM Density', color='lightblue',lw=1.5)
plt.plot(wline,d, label='Water Peak', lw=3,color='orange')
plt.plot(mline,d, label='GDS', lw=3,color='black')
plt.plot(sline,d, label='SAM Peak', lw=3,color='green')
plt.xlabel('z [nm]',fontsize=22)
plt.ylabel(r'Density $[\frac{Kg}{m3}]$',fontsize=22)
plt.legend()
#Set x limits
xlim(4.7,5.9)
# Set y limits
#ylim(0,ymax)
plt.suptitle('SAM '+str(b)+'%, Water '+str(c)+' molec.',style='italic',bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
#pylab.savefig('global_densmap3_'+str(b)+'.jpg', bbox_inches='tight')
