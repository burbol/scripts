# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
# %cd /home/eixeres/Downloads/Contact_Angles_WaterPeak
#%cd /Users/burbol/
# Out:
# /home/eixeres/Downloads/Contact_Angles_WaterPeak

# %%
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# %%
theta_results = np.zeros(5)
sigma = np.zeros(5)
percentages = np.zeros(5)
percentages = [0, 5, 11, 17, 66]

# %%
# We save the data in the arrays "theta_all" and "rbase_all"
theta_all, rbase_all = np.loadtxt('Contact_Angles2_all_s5.txt', skiprows=2, usecols = (0,1),unpack=True)

# %%
print len(theta_all), len(rbase_all)
# Out:
# 1600 1600

# %%
# Here we create two dictionaries named "angles" and "radii". Each dictionary consists of a set of "key: value" pairs, each one corresponding to a different system. The keys are (also) a pair of numbers "b, c".
# "b" refers to the OH-coverage percentage of the SAM, and "c" to the number of water molecules of the droplet. For example, the key "5, 1000" refers to the system with a surface with 5% OH-coverage, 
# and a droplet with 1000 water molecules. The value corresponding to each key is an array with the 40 calculated angles/base radii, that belong to that system. For example: "radii[(11, 3000)]" would give back
# the array with the 40 calculated values of the base radii corresponding to the system with a surface with 11% OH-coverage, and a droplet with 3000 water molecules.
angles={}
radii={}
k = 0
for b in [5]:
    for c in [1000, 2000, 3000, 4000, 5000, 6500, 7000, 8000, 9000, 10000]:
        z = b, c
        m = 0
        th = [0] * 160
        r = [0] * 160
        i=k*160
        j=(k+1)*160
        for l in range(i,j):
            th[m]=theta_all[l]
            r[m]=rbase_all[l]
            m = m +1
        angles[z] = th
        radii[z] = r
        k=k+1


theta_s5 = np.zeros(10)
rbase_s5 = np.zeros(10)
#We choose a system and substitute the values "b" and "c" to save the corresponding angle and radii values in two arrays named, respectively, "theta" and "rbase".
#b=0
#c=4000
#theta = array(angles[(b, c)])
#rbase = array(radii[(b, c)])
#print "theta=", th
#print "rbase=", r
#print theta[0]

# %%
# The data of the SAM with 11% OH-coverage gets handled separately, because there are still some simulations missing. We save the data in the arrays "theta_all11" and "rbase_all11"
theta_all11, rbase_all11 = np.loadtxt('Contact_Angles2_all_s11.txt', skiprows=2, usecols = (0,1),unpack=True)

# %%
# DICTIONARIES FOR SAM 11% (MODIFIED CELL COPY)
# Here we create two dictionaries named "angles11" and "radii11". Each dictionary consists of a set of "key: value" pairs, each one corresponding to a different system. The keys are (also) a pair of numbers "b, c".
# "b" refers to the OH-coverage percentage of the SAM, and "c" to the number of water molecules of the droplet. For example, the key "5, 1000" refers to the system with a surface with 5% OH-coverage, 
# and a droplet with 1000 water molecules. The value corresponding to each key is an array with the 40 calculated angles/base radii, that belong to that system. For example: "radii[(11, 3000)]" would give back
# the array with the 40 calculated values of the base radii corresponding to the system with a surface with 11% OH-coverage, and a droplet with 3000 water molecules.
#angles11={}
#radii11={}
k = 0
for b in [11]:
    for c in [1000, 2000, 3000, 4000, 5000, 6500, 7000, 8000, 9000, 10000]:
        z = b, c
        m = 0
        t11 = [0] * 160
        r11 = [0] * 160
        i=k*160
        j=(k+1)*160
        for l in range(i,j):
            t11[m]=theta_all11[l]
            r11[m]=rbase_all11[l]
            m = m +1
#        angles11[z] = t11 THESE 2 LINES HAVE BEEN SUBSTITUTED BY THE FOLLOWING TWO.
#        radii11[z] = r11
        angles[z] = t11
        radii[z] = r11
        k=k+1
    
theta_s11 = np.zeros(8)
rbase_s11 = np.zeros(8)

#We choose a system and substitute the values "b" and "c" to save the corresponding angle and radii values in two arrays named, respectively, "theta" and "rbase".
#b=11
#c=4000
#theta11 = array(angles11[(b, c)])
#rbase11 = array(radii11[(b, c)])
#print "theta11=", theta11
#print "rbase11=", rbase11
#print theta11[0]

# %%
# We save the data in the arrays "theta_all" and "rbase_all"
theta_all_s, rbase_all_s = np.loadtxt('Contact_Angles2_all_s0.txt', skiprows=2, usecols = (0,1),unpack=True)
print len(theta_all_s)
# Out:
# 1600

# %%
# Here we create two dictionaries named "angles" and "radii". Each dictionary consists of a set of "key: value" pairs, each one corresponding to a different system. The keys are (also) a pair of numbers "b, c".
# "b" refers to the OH-coverage percentage of the SAM, and "c" to the number of water molecules of the droplet. For example, the key "5, 1000" refers to the system with a surface with 5% OH-coverage, 
# and a droplet with 1000 water molecules. The value corresponding to each key is an array with the 40 calculated angles/base radii, that belong to that system. For example: "radii[(11, 3000)]" would give back
# the array with the 40 calculated values of the base radii corresponding to the system with a surface with 11% OH-coverage, and a droplet with 3000 water molecules.
#angles={}
#radii={}
k = 0
for b in [0]:
    for c in [1000, 2000, 3000, 4000, 5000, 6500, 7000, 8000, 9000, 10000]:
        z = b, c
        m = 0
        th = [0] * 160
        r = [0] * 160
        i=k*160
        j=(k+1)*160
        for l in range(i,j):
            th[m]=theta_all_s[l]
            r[m]=rbase_all_s[l]
            m = m +1
        angles[z] = th
        radii[z] = r
        k=k+1

theta_s0 = np.zeros(9)
rbase_s0 = np.zeros(9)
#We choose a system and substitute the values "b" and "c" to save the corresponding angle and radii values in two arrays named, respectively, "theta" and "rbase".
#b=0
#c=4000
#theta = array(angles[(b, c)])
#rbase = array(radii[(b, c)])
#print "theta=", theta
#print "rbase=", rbase
#print theta[0]

# %%
# We save the data in the arrays "theta_all" and "rbase_all"
theta_all_17, rbase_all_17 = np.loadtxt('Contact_Angles2_all_s17.txt', skiprows=2, usecols = (0,1),unpack=True)

# %%
# Here we create two dictionaries named "angles" and "radii". Each dictionary consists of a set of "key: value" pairs, each one corresponding to a different system. The keys are (also) a pair of numbers "b, c".
# "b" refers to the OH-coverage percentage of the SAM, and "c" to the number of water molecules of the droplet. For example, the key "5, 1000" refers to the system with a surface with 5% OH-coverage, 
# and a droplet with 1000 water molecules. The value corresponding to each key is an array with the 40 calculated angles/base radii, that belong to that system. For example: "radii[(11, 3000)]" would give back
# the array with the 40 calculated values of the base radii corresponding to the system with a surface with 11% OH-coverage, and a droplet with 3000 water molecules.
#angles={}
#radii={}
k = 0
for b in [17]:
    for c in [1000, 2000, 3000, 4000, 5000, 6500, 7000, 8000, 9000, 10000]:
        z = b, c
        m = 0
        th = [0] * 160
        r = [0] * 160
        i=k*160
        j=(k+1)*160
        for l in range(i,j):
            th[m]=theta_all_17[l]
            r[m]=rbase_all_17[l]
            m = m +1
        angles[z] = th
        radii[z] = r
        k=k+1

theta_s17 = np.zeros(10)
rbase_s17 = np.zeros(10)
#We choose a system and substitute the values "b" and "c" to save the corresponding angle and radii values in two arrays named, respectively, "theta" and "rbase".
#b=0
#c=4000
#theta = array(angles[(b, c)])
#rbase = array(radii[(b, c)])
#print "theta=", theta
#print "rbase=", rbase
#print theta[0]

# %%
# This function allows to use ranges, just as the built-in function range(), but with float arguments.
# Taken from "http://code.activestate.com/recipes/66472-frange-a-range-function-with-float-increments/"
def frange(start, end=None, inc=None):
    if end == None:
        end = start + 0.0
        start = 0.0

    if inc == None:
        inc = 1.0

    L = []
    while 1:
        next = start + len(L) * inc
        if inc > 0 and next >= end:
            break
        elif inc < 0 and next <= end:
            break
        L.append(next)
    return L

# %%
# We create an array named "t" with the time values.
t = np.zeros(160)
i=0
for d in frange(0, 80, 0.5):
    t[i] = d
    i = i + 1

# %%
b=0
c=1000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=9
end=79
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s0[0]=theta_avr[0] 
rbase_s0[0]=rbase_avr[0] 
print theta_s0[0]
print rbase_s0[0]

#PLOT FOR CONTACT ANGLE OF SAM 0% & 1000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 140, 'SAM 0%, Water 1000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 85, 150])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 1000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 0.3, 'SAM 0%, Water 1000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 0, 2])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 133.158091961
# 1.44221576898

# %%
b=0
c=2000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=50
end=80
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s0[1]=theta_avr[0] 
rbase_s0[1]=rbase_avr[0] 
print theta_s0[1]
print rbase_s0[1]


#PLOT FOR CONTACT ANGLE OF SAM 0% & 2000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 155, 'SAM 0%, Water 2000 molec.',style='italic',bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 2000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 0.8, 'SAM 0%, Water 2000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 135.45512633
# 1.732917295

# %%
b=0
c=3000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=22
end=79
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s0[2]=theta_avr[0] 
rbase_s0[2]=rbase_avr[0] 
print theta_s0[2]
print rbase_s0[2]

#PLOT FOR CONTACT ANGLE OF SAM 0% & 3000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 155, 'SAM 0%, Water 3000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 3000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.6, 'SAM 0%, Water 3000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 39.5, 0, 0.8, 2.6])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 136.150426852
# 1.93946673216

# %%
b=0
c=4000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=42
end=76
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s0[3]=theta_avr[0] 
rbase_s0[3]=rbase_avr[0] 
print theta_s0[3]
print rbase_s0[3]

#PLOT FOR CONTACT ANGLE OF SAM 0% & 4000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 160, 'SAM 0%, Water 4000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 4000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 0.8, 'SAM 0%, Water 4000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 136.884013267
# 2.1113941889

# %%
b=0
c=5000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=50
end=79
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s0[4]=theta_avr[0] 
rbase_s0[4]=rbase_avr[0] 
print theta_s0[4]
print rbase_s0[4]

#PLOT FOR CONTACT ANGLE OF SAM 0% & 5000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 152, 'SAM 0%, Water 5000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 5000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.5, 'SAM 0%, Water 5000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 137.187231269
# 2.25838746385

# %%
b=0
c=6500
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=80
end=120
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s0[5]=theta_avr[0] 
rbase_s0[5]=rbase_avr[0] 
print theta_s0[5]
print rbase_s0[5]

#PLOT FOR CONTACT ANGLE OF SAM 0% & 6500 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 159, 'SAM 0%, Water 6500 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 6500 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.6, 'SAM 0%, Water 6500 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 137.268253288
# 2.4675606506

# %%
b=0
c=7000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=86
end=120
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s0[6]=theta_avr[0] 
rbase_s0[6]=rbase_avr[0] 
print theta_s0[6]
print rbase_s0[6]

#PLOT FOR CONTACT ANGLE OF SAM 0% & 7000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 155, 'SAM 0%, Water 7000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 7000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.4, 'SAM 0%, Water 7000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 137.548306616
# 2.50861505945

# %%
b=0
c=8000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=90
end=120
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s0[7]=theta_avr[0] 
rbase_s0[7]=rbase_avr[0] 
print theta_s0[7]
print rbase_s0[7]

#PLOT FOR CONTACT ANGLE OF SAM 0% & 8000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 150, 'SAM 0%, Water 8000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 8000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.8, 'SAM 0%, Water 8000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 137.424448175
# 2.62821549511

# %%
b=0
c=9000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=100
end=120
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s0[8]=theta_avr[0] 
rbase_s0[8]=rbase_avr[0] 
print theta_s0[8]
print rbase_s0[8]

#PLOT FOR CONTACT ANGLE OF SAM 0% & 9000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 150, 'SAM 0%, Water 9000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 9000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 2, 'SAM 0%, Water 9000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 137.925985592
# 2.7122304126

# %%
b=0
c=10000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=120
end=159
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s0[9]=theta_avr[0] 
rbase_s0[9]=rbase_avr[0] 
print theta_s0[9]
print rbase_s0[9]

#PLOT FOR CONTACT ANGLE OF SAM 0% & 10000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 150, 'SAM 0%, Water 10000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 10000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.8, 'SAM 0%, Water 10000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-328-5185bf07f800> in <module>()
#      12 t_avr = t[start:end]
#      13
# ---> 14 theta_s0[9]=theta_avr[0]
#      15 rbase_s0[9]=rbase_avr[0]
#      16 print theta_s0[9]
#
# IndexError: index out of bounds

# %%
b=5
c=1000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=10
end=80
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s5[0]=theta_avr[0] 
rbase_s5[0]=rbase_avr[0] 
print theta_s5[0]
print rbase_s5[0]


#PLOT FOR CONTACT ANGLE OF SAM 5% & 1000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 145, 'SAM 5%, Water 1000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 100, 150])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 1000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.4, 'SAM 5%, Water 1000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 1.3, 2.1])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 127.573557706
# 1.57699688955

# %%
b=5
c=2000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
#print theta
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=10
end=80
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s5[1]=theta_avr[0] 
rbase_s5[1]=rbase_avr[0] 
print theta_s5[0]
print rbase_s5[0]


#PLOT FOR CONTACT ANGLE OF SAM 5% & 2000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 145, 'SAM 5%, Water 2000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 2000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.2, 'SAM 5%, Water 2000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 127.573557706
# 1.57699688955

# %%
b=5
c=3000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=16
end=80
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s5[2]=theta_avr[0] 
rbase_s5[2]=rbase_avr[0] 
print theta_s5[2]
print rbase_s5[2]


#PLOT FOR CONTACT ANGLE OF SAM 5% & 3000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 141, 'SAM 5%, Water 3000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 100, 150])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 3000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.9, 'SAM 5%, Water 3000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 1.8, 2.6])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 130.739520188
# 2.13355850185

# %%
b=5
c=4000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
#print rbase
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=15
end=80
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s5[3]=theta_avr[0] 
rbase_s5[3]=rbase_avr[0] 
print theta_s5[3]
print rbase_s5[3]


#PLOT FOR CONTACT ANGLE OF SAM 5% & 4000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 150, 'SAM 5%, Water 4000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 110, 200])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 4000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 2.1, 'SAM 5%, Water 4000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 1.0, 3.0])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 133.427692386
# 2.25256926384

# %%
b=5
c=5000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=20
end=80
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s5[4]=theta_avr[0] 
rbase_s5[4]=rbase_avr[0] 
print theta_s5[4]
print rbase_s5[4]


#PLOT FOR CONTACT ANGLE OF SAM 5% & 5000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 170, 'SAM 5%, Water 5000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 125, 180])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 5000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.6, 'SAM 5%, Water 5000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 1.5, 2.5])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 134.696520839
# 2.36657995223

# %%
b=5
c=6500
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=50
end=80
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s5[5]=theta_avr[0] 
rbase_s5[5]=rbase_avr[0] 
print theta_s5[5]
print rbase_s5[5]


#PLOT FOR CONTACT ANGLE OF SAM 5% & 6500 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 170, 'SAM 5%, Water 6500 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 120, 200])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 6500 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 2.1, 'SAM 5%, Water 6500 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 2, 3])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 129.472468585
# 2.8413589213

# %%
b=5
c=7000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=70
end=120
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s5[6]=theta_avr[0] 
rbase_s5[6]=rbase_avr[0] 
print theta_s5[6]
print rbase_s5[6]


#PLOT FOR CONTACT ANGLE OF SAM 5% & 7000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 150, 'SAM 5%, Water 7000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 7000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.8, 'SAM 5%, Water 7000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 128.837849627
# 2.93329987706

# %%
b=5
c=8000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=70
end=120
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s5[7]=theta_avr[0] 
rbase_s5[7]=rbase_avr[0] 
print theta_s5[7]
print rbase_s5[7]


#PLOT FOR CONTACT ANGLE OF SAM 5% & 9000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 146, 'SAM 5%, Water 8000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 9000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.8, 'SAM 5%, Water 8000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 129.83051831
# 3.01961553193

# %%
b=5
c=9000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=76
end=120
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s5[8]=theta_avr[0] 
rbase_s5[8]=rbase_avr[0] 
print theta_s5[8]
print rbase_s5[8]


#PLOT FOR CONTACT ANGLE OF SAM 5% & 9000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 146, 'SAM 5%, Water 9000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 9000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 2.0, 'SAM 5%, Water 9000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 130.372384879
# 3.12167403282

# %%
b=5
c=10000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=130
end=160
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s5[9]=theta_avr[0] 
rbase_s5[9]=rbase_avr[0] 
print theta_s5[9]
print rbase_s5[9]


#PLOT FOR CONTACT ANGLE OF SAM 5% & 10000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 146, 'SAM 5%, Water 10000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 10000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 2, 'SAM 5%, Water 10000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 130.27294575
# 3.23877139042

# %%
plt.plot(1/rbase_s5, cos((theta_s5/180)*np.pi), 'ro')

# %%
b=11
c=1000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
#print theta
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=60
end=80
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s11[0]=theta_avr[0] 
rbase_s11[0]=rbase_avr[0] 
print theta_s11[0]
print rbase_s11[0]

#PLOT FOR CONTACT ANGLE OF SAM 11% & 1000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 102, 'SAM 11%, Water 1000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 1000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 1.61, 'SAM 11%, Water 1000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 107.338563714
# 2.0133356019

# %%
b=11
c=2000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=60
end=80
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

#theta_s11[1]=theta_avr[0] 
#rbase_s11[1]=rbase_avr[0] 
#print theta_s11[1]
#print rbase_s11[1]

#PLOT FOR CONTACT ANGLE OF SAM 11% & 2000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 155, 'SAM 11%, Water 2000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 20, 90, 170])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 2000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 0.5, 'SAM 11%, Water 2000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 20, 0, 3])
pylab.savefig(namebaserad)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-341-b728104d8b29> in <module>()
#      29 #plt.axis([0, 20, 90, 170])
#      30 pylab.savefig(nametheta)
# ---> 31 plt.show()
#      32
#      33 #PLOT FOR BASE RADIUS OF SAM 11% & 2000 WATER MOLECULES.(Also saved to file)
#
# /usr/lib/pymodules/python2.7/matplotlib/pyplot.pyc in show(*args, **kw)
#     137     """
#     138     global _show
# --> 139     _show(*args, **kw)
#     140
#     141
#
# /usr/lib/python2.7/dist-packages/IPython/zmq/pylab/backend_inline.pyc in show(close)
#     100     try:
#     101         for figure_manager in Gcf.get_all_fig_managers():
# --> 102             send_figure(figure_manager.canvas.figure)
#     103     finally:
#     104         show._to_draw = []
#
# /usr/lib/python2.7/dist-packages/IPython/zmq/pylab/backend_inline.pyc in send_figure(fig)
#     209     """
#     210     fmt = InlineBackend.instance().figure_format
# --> 211     data = print_figure(fig, fmt)
#     212     # print_figure will return None if there's nothing to draw:
#     213     if data is None:
#
# /usr/lib/python2.7/dist-packages/IPython/core/pylabtools.pyc in print_figure(fig, fmt)
#     102     try:
#     103         bytes_io = BytesIO()
# --> 104         fig.canvas.print_figure(bytes_io, format=fmt, bbox_inches='tight')
#     105         data = bytes_io.getvalue()
#     106     finally:
#
# /usr/lib/pymodules/python2.7/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2019                 orientation=orientation,
#    2020                 bbox_inches_restore=_bbox_inches_restore,
# -> 2021                 **kwargs)
#    2022         finally:
#    2023             if bbox_inches and restore_bbox:
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     467
#     468     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 469         FigureCanvasAgg.draw(self)
#     470         renderer = self.get_renderer()
#     471         original_dpi = renderer.dpi
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in draw(self)
#     414         if __debug__: verbose.report('FigureCanvasAgg.draw', 'debug-annoying')
#     415
# --> 416         self.renderer = self.get_renderer()
#     417         # acquire a lock on the shared font cache
#     418         RendererAgg.lock.acquire()
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in get_renderer(self)
#     433
#     434         if need_new_renderer:
# --> 435             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     436             self._lastKey = key
#     437         return self.renderer
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in __init__(self, width, height, dpi)
#      70         self.height = height
#      71         if __debug__: verbose.report('RendererAgg.__init__ width=%s, height=%s'%(width, height), 'debug-annoying')
# ---> 72         self._renderer = _RendererAgg(int(width), int(height), dpi, debug=False)
#      73         self._filter_renderers = []
#      74
#
# ValueError: width and height must each be below 32768

# %%
b=11
c=3000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
#print theta
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=10
end=80
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s11[1]=theta_avr[0] 
rbase_s11[1]=rbase_avr[0] 
print theta_s11[1]
print rbase_s11[1]

#PLOT FOR CONTACT ANGLE OF SAM 11% & 3000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 150, 'SAM 11%, Water 3000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 3000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 0.7, 'SAM 11%, Water 3000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 113.060514987
# 2.72243457257

# %%
b=11
c=4000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
#print theta
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=20
end=80
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s11[2]=theta_avr[0] 
rbase_s11[2]=rbase_avr[0] 
print theta_s11[2]
print rbase_s11[2]


#PLOT FOR CONTACT ANGLE OF SAM 11% & 4000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 142, 'SAM 11%, Water 4000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 4000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 1.7, 'SAM 11%, Water 4000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 112.938997625
# 3.01315194678

# %%
b=11
c=5000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=20
end=80
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s11[3]=theta_avr[0] 
rbase_s11[3]=rbase_avr[0] 
print theta_s11[3]
print rbase_s11[3]


#PLOT FOR CONTACT ANGLE OF SAM 11% & 5000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 95, 'SAM 11%, Water 5000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 90, 130])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 5000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 2.6, 'SAM 11%, Water 5000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 2.5, 3.5])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 117.276236836
# 3.08048219457

# %%
b=11
c=6500
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=38
end=40
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s11[4]=theta_avr[0] 
rbase_s11[4]=rbase_avr[0] 
print theta_s11[4]
print rbase_s11[4]


#PLOT FOR CONTACT ANGLE OF SAM 11% & 5000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 95, 'SAM 11%, Water 5000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 90, 130])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 5000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 2.6, 'SAM 11%, Water 5000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 2.5, 3.5])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 113.089968271
# 3.54761567438

# %%
b=11
c=7000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=80
end=120
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s11[5]=theta_avr[0] 
rbase_s11[5]=rbase_avr[0] 
print theta_s11[5]
print rbase_s11[5]


#PLOT FOR CONTACT ANGLE OF SAM 11% & 7000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 145, 'SAM 11%, Water 7000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 7000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 1.5, 'SAM 11%, Water 7000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 116.271748234
# 3.4921045136

# %%
b=11
c=8000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=80#PLOT for SAM 0% (Also saved to file) with old results
print 
x = 1/rbase_s0
y = cos((theta_s0/180)*np.pi)
print old_s0_rbase 
x_old = 1/old_s0_rbase
y_old = cos((old_s0_theta/180)*np.pi)

popt, pcov = curve_fit(func, x, y)
print "Line equation (old): a*x+b with a=", popt_old[0], "and b=", popt_old[1]
theta_results_old[0] = math.degrees(np.arccos(popt_old[1]))
sigma_old[0] = popt_old[0]*(-52.7)
print 'Theta_old =', theta_results_old[0]
print 'Sigma_old =', sigma_old[0]

popt_old, pcov_old = curve_fit(func, x_old, y_old)

plt.plot(x, y, 'ro')
plt.plot(x, func(x, popt[0], popt[1]))
plt.plot(x_old,y_old,'g^')
plt.plot(x_old, func(x_old, popt_old[0], popt_old[1]))
#plt.plot(1/old_s0_rbase,cos((old_s0_theta/180)*np.pi))
plt.xlabel('$R \ _{BASE}\ [ nm ^{-1} ]$')
plt.ylabel(r' $\cos\Theta$ ')
plt.suptitle(r'$\cos\Theta$ vs. ${R \ _{BASE}}^{-1}$', fontsize=14, fontweight='bold')
plt.text(0.37, -0.7, 'SAM 0%',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 80, 3.4, 4.8])
pylab.savefig('Theta_old_new_together_s0.png')
plt.show()
end=120
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s11[6]=theta_avr[0] 
rbase_s11[6]=rbase_avr[0] 
print theta_s11[6]
print rbase_s11[6]


#PLOT FOR CONTACT ANGLE OF SAM 11% & 8000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 155, 'SAM 11%, Water 8000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 8000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 1, 'SAM 11%, Water 8000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# [ 1.32183131  1.7771987   1.93947167  2.17695035]
# Line equation (old): a*x+b with a= 0.186421927321 and b= -0.50974061203
# Theta_old = 120.646553586
# Sigma_old = -9.82443556981
# 113.948130381
# 3.75717275682

# %%
b=11
c=10000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=80
end=160
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s11[7]=theta_avr[0] 
rbase_s11[7]=rbase_avr[0] 
print theta_s11[7]
print rbase_s11[7]


#PLOT FOR CONTACT ANGLE OF SAM 11% & 10000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 155, 'SAM 11%, Water 10000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 10000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 1.0, 'SAM 11%, Water 10000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 113.978799033
# 4.0618365119

# %%
b=17
c=1000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
#print theta
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=40
end=80
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s17[0]=theta_avr[0] 
rbase_s17[0]=rbase_avr[0] 
print theta_s17[0]
print rbase_s17[0]

#PLOT FOR CONTACT ANGLE OF SAM 17% & 1000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 125, 'SAM 17%, Water 1000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 1000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.6, 'SAM 17%, Water 1000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 100.460746397
# 2.15435785252

# %%
b=17
c=2000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
#print theta
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=50
end=80
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s17[1]=theta_avr[0] 
rbase_s17[1]=rbase_avr[0] 
print theta_s17[1]
print rbase_s17[1]


#PLOT FOR CONTACT ANGLE OF SAM 17% & 2000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 115, 'SAM 17%, Water 2000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 2000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 2.2, 'SAM 17%, Water 2000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 101.101569571
# 2.70091714635

# %%
b=17
c=3000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=50
end=80
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s17[2]=theta_avr[0] 
rbase_s17[2]=rbase_avr[0] 
print theta_s17[2]
print rbase_s17[2]


#PLOT FOR CONTACT ANGLE OF SAM 17% & 3000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 150, 'SAM 17%, Water 3000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 80, 170])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 3000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 2.2, 'SAM 17%, Water 3000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 1.5, 4])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 101.297234281
# 3.0666859261

# %%
b=17
c=4000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=24
end=80
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s17[3]=theta_avr[0] 
rbase_s17[3]=rbase_avr[0] 
print theta_s17[3]
print rbase_s17[3]

#PLOT FOR CONTACT ANGLE OF SAM 17% & 4000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 130, 'SAM 17%, Water 4000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 80, 140])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 4000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 3, 'SAM 17%, Water 4000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 2.5, 5])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 101.046875453
# 3.3996213754

# %%
b=17
c=5000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=30
end=80
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s17[4]=theta_avr[0] 
rbase_s17[4]=rbase_avr[0] 
print theta_s17[4]
print rbase_s17[4]

#PLOT FOR CONTACT ANGLE OF SAM 17% & 5000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 85, 'SAM 17%, Water 5000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 80, 110])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 5000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 4.2, 'SAM 17%, Water 5000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 3, 4.6])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 102.59471308
# 3.61179839279

# %%
b=17
c=6500
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=40
end=120
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s17[5]=theta_avr[0] 
rbase_s17[5]=rbase_avr[0] 
print theta_s17[5]
print rbase_s17[5]

#PLOT FOR CONTACT ANGLE OF SAM 17% & 6500 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 100, 'SAM 17%, Water 6500 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 60, 80, 110])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 6500 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 4.2, 'SAM 17%, Water 6500 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 60, 3, 4.6])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 105.230087499
# 3.85769047964

# %%
b=17
c=7000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=80
end=120
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s17[6]=theta_avr[0] 
rbase_s17[6]=rbase_avr[0] 
print theta_s17[6]
print rbase_s17[6]

#PLOT FOR CONTACT ANGLE OF SAM 17% & 7000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(9, 97, 'SAM 17%, Water 7000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 60, 80, 110])
pylab.savefig(nametheta)
plt.show()
plt.axis([0, 60, 3, 4.6])
#PLOT FOR BASE RADIUS OF SAM 17% & 7000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(9, 4.2, 'SAM 17%, Water 7000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)

pylab.savefig(namebaserad)
plt.show()
# Out:
# 103.848204013
# 3.99772737549

# %%
b=17
c=8000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=80
end=120
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s17[7]=theta_avr[0] 
rbase_s17[7]=rbase_avr[0] 
print theta_s17[7]
print rbase_s17[7]

#PLOT FOR CONTACT ANGLE OF SAM 17% & 8000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 83, 'SAM 17%, Water 8000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 60, 80, 120])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 8000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 3.2, 'SAM 17%, Water 8000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 60, 3, 4.6])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 102.916965401
# 4.22377245798

# %%
b=17
c=9000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=100
end=120
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s17[8]=theta_avr[0] 
rbase_s17[8]=rbase_avr[0] 
print theta_s17[8]
print rbase_s17[8]

#PLOT FOR CONTACT ANGLE OF SAM 17% & 9000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 160, 'SAM 17%, Water 9000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 60, 90, 120])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 9000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1, 'SAM 17%, Water 9000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 60, 3, 4.6])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 102.955435325
# 4.40746452718

# %%
b=17
c=10000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=100
end=160
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s17[9]=theta_avr[0] 
rbase_s17[9]=rbase_avr[0] 
print theta_s17[9]
print rbase_s17[9]

#PLOT FOR CONTACT ANGLE OF SAM 17% & 10000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10, 155, 'SAM 17%, Water 10000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 80, 90, 120])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 10000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10, 1.5, 'SAM 17%, Water 10000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 80, 3.4, 4.8])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 101.660524019
# 4.62135292751

# %%
def func(x, a, b):
    return a*x + b

# %%
d = 0
namethetabaserad = "theta_r_s%s.png" % (d)
    
x = 1/rbase_s0
y = cos((theta_s0/180)*np.pi)

popt, pcov = curve_fit(func, x, y)
print "Line equation: a*x+b with a=", popt[0], "and b=", popt[1]
theta_results[0] = math.degrees(np.arccos(popt[1]))
sigma[0] = popt[0]*(-52.7)
print 'Theta =', theta_results[0]
print 'Sigma =', sigma[0]

#PLOT for SAM 0% (Also saved to file)
plt.plot(1/rbase_s0, cos(theta_s0/180*np.pi), 'ro')
plt.plot(x, func(x, popt[0], popt[1]))
plt.xlabel('$R \ _{BASE}\ [ nm ^{-1} ]$')
plt.ylabel(r' $\cos\Theta$ ')
plt.suptitle(r'$\cos\Theta$ vs. ${R \ _{BASE}}^{-1}$', fontsize=14, fontweight='bold')
plt.text(0.37, -0.7, 'SAM 0%',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 80, 3.4, 4.8])
pylab.savefig(namethetabaserad)
plt.show()
# Out:
# Line equation: a*x+b with a= 0.165661286267 and b= -0.804161544279
# Theta = 143.529358551
# Sigma = -8.73034978627

# %%
d = 5
namethetabaserad = "theta_r_s%s.png" % (d)
    
x = 1/rbase_s5
y = cos((theta_s5/180)*np.pi)

popt, pcov = curve_fit(func, x, y)
print "Line equation: a*x+b with a=", popt[0], "and b=", popt[1]
theta_results[1] = math.degrees(np.arccos(popt[1]))
sigma[1] = popt[0]*(-52.7)
print 'Theta =', theta_results[1]
print 'Sigma =', sigma[1]

#PLOT for SAM 5% (Also saved to file)
plt.plot(1/rbase_s5, cos(theta_s5/180*np.pi), 'ro')
plt.plot(x, func(x, popt[0], popt[1]))
plt.xlabel('$R \ _{BASE}\ [ nm ^{-1} ]$')
plt.ylabel(r' $\cos\Theta$ ')
plt.suptitle(r'$\cos\Theta$ vs. ${R \ _{BASE}}^{-1}$', fontsize=14, fontweight='bold')
plt.text(0.35, -0.61, 'SAM 5%',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 80, 3.4, 4.8])
pylab.savefig(namethetabaserad)
plt.show()
# Out:
# Line equation: a*x+b with a= 0.0814436267304 and b= -0.678320899099
# Theta = 132.712571107
# Sigma = -4.29207912869

# %%
d = 11
namethetabaserad = "theta_r_s%s.png" % (d)
    
x = 1/rbase_s11
y = cos((theta_s11/180)*np.pi)
print x
print y

popt, pcov = curve_fit(func, x, y)
print "Line equation: a*x+b with a=", popt[0], "and b=", popt[1]
theta_results[2] = math.degrees(np.arccos(popt[1]))
sigma[2] = popt[0]*(-52.7)
print 'Theta =', theta_results[2]
print 'Sigma =', sigma[2]

#PLOT for SAM 11% (Also saved to file)
plt.plot(1/rbase_s11, cos(theta_s11/180*np.pi), 'ro')
plt.plot(x, func(x, popt[0], popt[1]))
plt.xlabel('$R \ _{BASE}\ [ nm ^{-1} ]$')
plt.ylabel(r' $\cos\Theta$ ')
plt.suptitle(r'$\cos\Theta$ vs. ${R \ _{BASE}}^{-1}$', fontsize=14, fontweight='bold')
plt.text(0.25,-0.34, 'SAM 11%',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 80, 3.4, 4.8])
pylab.savefig(namethetabaserad)
plt.show()
# Out:
# [ 0.49668818  0.36731829  0.33187838  0.3246245   0.28187946  0.28636027
#   0.26615758  0.24619405]
# [-0.29801742 -0.39170313 -0.38975085 -0.45828097 -0.39217606 -0.44262909
#  -0.40590945 -0.40639858]
# Line equation: a*x+b with a= 0.453592760645 and b= -0.545588251489
# Theta = 123.06487185
# Sigma = -23.904338486

# %%
plt.plot(1/rbase_s17, cos((theta_s17/180)*np.pi), 'ro')

d = 17
namethetabaserad = "theta_r_s%s.png" % (d)
    
x = 1/rbase_s17
y = cos((theta_s17/180)*np.pi)

popt, pcov = curve_fit(func, x, y)
print "Line equation: a*x+b with a=", popt[0], "and b=", popt[1]
theta_results[3] = math.degrees(np.arccos(popt[1]))
sigma[3] = popt[0]*(-52.7)
print 'Theta =', theta_results[3]
print 'Sigma =', sigma[3]

#PLOT for SAM 17% (Also saved to file)
plt.plot(1/rbase_s17, cos(theta_s17/180*np.pi), 'ro')
plt.plot(x, func(x, popt[0], popt[1]))
plt.xlabel('$R \ _{BASE}\ [ nm ^{-1} ]$')
plt.ylabel(r' $\cos\Theta$ ')
plt.suptitle(r'$\cos\Theta$ vs. ${R \ _{BASE}}^{-1}$', fontsize=14, fontweight='bold')
plt.text(0.4, -0.23, 'SAM 17%',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 80, 3.4, 4.8])
pylab.savefig(namethetabaserad)
plt.show()
# Out:
# Line equation: a*x+b with a= 0.206392373311 and b= -0.273442110696
# Theta = 105.869195626
# Sigma = -10.8768780735

# %%
plt.plot(percentages, theta_results, 'ro')
plt.plot(percentages, theta_results)
plt.ylabel('CONTACT ANGLES [deg]')
plt.xlabel('OH- PERCENTAGE')
plt.suptitle('Contact Angles vs. OH- Percentages' , fontsize=14, fontweight='bold')
plt.grid(True)
#plt.axis([0, 80, 3.4, 4.8])
pylab.savefig('C_Angles_OH.png')
plt.show()

# %%
plt.plot(percentages, sigma, 'ro', k)
plt.plot(percentages, sigma)
plt.ylabel(r' $\sigma $ [pN]')
plt.xlabel('OH- PERCENTAGE')
plt.suptitle('Contact Angles vs. OH- Percentages' , fontsize=14, fontweight='bold')
plt.grid(True)
#plt.axis([0, 80, 3.4, 4.8])
pylab.savefig('Sigma_OH.png')
plt.show()

# %%
theta_results_old = np.zeros(5)
sigma_old = np.zeros(5)
x_old = np.zeros(4)
y_old = np.zeros(4)
old_s0_rbase = np.zeros(4)
old_s0_theta = np.zeros(4)
old_s5_rbase = np.zeros(4)
old_s5_theta = np.zeros(4)
old_s11_rbase = np.zeros(4)
old_s11_theta = np.zeros(4)
old_s17_rbase = np.zeros(4)
old_s17_theta = np.zeros(4)
old_s0_rbase = np.asarray([1.321831311995715, 1.777198697495715, 1.9394716652000004, 2.1769503464528577])
old_s0_theta = np.asarray([139.50193996500002, 135.53781773342862, 137.3304999494286,136.70700505600004])                                                                                                                                 
old_s5_rbase = np.asarray([1.3384336533187002, 1.8309841931620001, 2.041411750949, 2.4807026393260005])
old_s5_theta = np.asarray([138.92059118720002, 134.53625385520002, 125.45823807340001, 130.94196403330002])
old_s11_rbase = np.asarray([2.015948142545, 2.4663530361300006, 2.856645804237001, 3.0686094655820013])
old_s11_theta = np.asarray([114.9542682970000152, 115.58141286840001, 114.81478809430003, 118.13289369870004])                                                                                                                    
old_s17_rbase = np.asarray([2.191056271616, 2.9348488390400007, 3.329791693112, 3.7772744415450004])
old_s17_theta = np.asarray([107.62978975850002,100.83666103307003, 102.83541406403,103.4593823350001])

# %%
#PLOT for SAM 0% (Also saved to file) with old results
print 
x = 1/rbase_s0
y = cos((theta_s0/180)*np.pi)
print old_s0_rbase 
x_old = 1/old_s0_rbase
y_old = cos((old_s0_theta/180)*np.pi)

popt, pcov = curve_fit(func, x, y)
print "Line equation (old): a*x+b with a=", popt_old[0], "and b=", popt_old[1]
theta_results_old[0] = math.degrees(np.arccos(popt_old[1]))
sigma_old[0] = popt_old[0]*(-52.7)
print 'Theta_old =', theta_results_old[0]
print 'Sigma_old =', sigma_old[0]

popt_old, pcov_old = curve_fit(func, x_old, y_old)

plt.plot(x, y, 'ro')
plt.plot(x, func(x, popt[0], popt[1]))
plt.plot(x_old,y_old,'g^')
plt.plot(x_old, func(x_old, popt_old[0], popt_old[1]))
#plt.plot(1/old_s0_rbase,cos((old_s0_theta/180)*np.pi))
plt.xlabel('${R \ _{BASE}}^{-1} \ [ nm ^{-1} ]$')
plt.ylabel(r' $\cos\Theta_{mic}$ ')
plt.suptitle(r'$\cos\Theta$ vs. ${R \ _{BASE}}^{-1}$', fontsize=14, fontweight='bold')
plt.text(0.37, -0.7, 'SAM 0%',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 80, 3.4, 4.8])
pylab.savefig('Theta_old_new_together_s0.png')
plt.show()
# Out:
# [ 1.32183131  1.7771987   1.93947167  2.17695035]
# Line equation (old): a*x+b with a= 0.186421927321 and b= -0.50974061203
# Theta_old = 120.646553586
# Sigma_old = -9.82443556981

# %%
#PLOT for SAM 5% (Also saved to file) with old results
print 
x = 1/rbase_s5
y = cos((theta_s5/180)*np.pi)
print old_s5_rbase 
x_old = 1/old_s5_rbase
y_old = cos((old_s5_theta/180)*np.pi)

popt, pcov = curve_fit(func, x, y)
print "Line equation (old): a*x+b with a=", popt_old[0], "and b=", popt_old[1]
theta_results_old[1] = math.degrees(np.arccos(popt_old[1]))
sigma_old[1] = popt_old[0]*(-52.7)
print 'Theta_old =', theta_results_old[1]
print 'Sigma_old =', sigma_old[1]

popt_old, pcov_old = curve_fit(func, x_old, y_old)

plt.plot(x, y, 'ro')
plt.plot(x, func(x, popt[0], popt[1]))
plt.plot(x_old,y_old,'g^')
plt.plot(x_old, func(x_old, popt_old[0], popt_old[1]))
#plt.plot(1/old_s0_rbase,cos((old_s0_theta/180)*np.pi))
plt.xlabel('${R \ _{BASE}}^{-1} \ [ nm ^{-1} ]$')
plt.ylabel(r' $\cos\Theta_{mic}$ ')
plt.suptitle(r'$\cos\Theta$ vs. ${R \ _{BASE}}^{-1}$', fontsize=14, fontweight='bold')
plt.text(0.37, -0.74, 'SAM 5%',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 80, 3.4, 4.8])
pylab.savefig('Theta_old_new_together_s5.png')
plt.show()
# Out:
# [ 1.33843365  1.83098419  2.04141175  2.48070264]
# Line equation (old): a*x+b with a= -0.113684771287 and b= -0.669115138134
# Theta_old = 131.998807425
# Sigma_old = 5.99118744682

# %%
plt.plot([1,2,3], label="test1")
plt.plot([3,2,1], label="test2")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
#PLOT for SAM 11% (Also saved to file) with old results
print 
x = 1/rbase_s11
y = cos((theta_s11/180)*np.pi)
print x
print old_s11_rbase 
x_old = 1/old_s11_rbase
y_old = cos((old_s11_theta/180)*np.pi)

popt, pcov = curve_fit(func, x, y)
print "Line equation (old): a*x+b with a=", popt_old[0], "and b=", popt_old[1]
theta_results_old[2] = math.degrees(np.arccos(popt_old[1]))
sigma_old[2] = popt_old[0]*(-52.7)
print 'Theta_old =', theta_results_old[2]
print 'Sigma_old =', sigma_old[2]

popt_old, pcov_old = curve_fit(func, x_old, y_old)

plt.plot(x, y, 'ro')
plt.plot(x, func(x, popt[0], popt[1]))
plt.plot(x_old,y_old,'g^')
plt.plot(x_old, func(x_old, popt_old[0], popt_old[1]))
#plt.plot(1/old_s0_rbase,cos((old_s0_theta/180)*np.pi))
plt.xlabel('${R \ _{BASE}}^{-1} \ [ nm ^{-1} ]$')
plt.ylabel(r' $\cos\Theta_{mic}$ ')
plt.suptitle(r'$\cos\Theta$ vs. ${R \ _{BASE}}^{-1}$', fontsize=14, fontweight='bold')
plt.text(0.37, -0.3, 'SAM 11%',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 80, 3.4, 4.8])
pylab.savefig('Theta_old_new_together_s11.png')
plt.show()
# Out:
# [ 0.49668818  0.36731829  0.33187838  0.3246245   0.28187946  0.28636027
#   0.26615758  0.24619405]
# [ 2.01594814  2.46635304  2.8566458   3.06860947]
# Line equation (old): a*x+b with a= -0.410868694912 and b= -0.0965248668185
# Theta_old = 95.5390916344
# Sigma_old = 21.6527802218

# %%
#PLOT for SAM 17% (Also saved to file) with old results
print 
x = 1/rbase_s17
y = cos((theta_s17/180)*np.pi)
print x
print old_s17_rbase 
x_old = 1/old_s17_rbase
y_old = cos((old_s17_theta/180)*np.pi)

popt, pcov = curve_fit(func, x, y)
print "Line equation (old): a*x+b with a=", popt_old[0], "and b=", popt_old[1]
theta_results_old[3] = math.degrees(np.arccos(popt_old[1]))
sigma_old[3] = popt_old[0]*(-52.7)
print 'Theta_old =', theta_results_old[2]
print 'Sigma_old =', sigma_old[2]

popt_old, pcov_old = curve_fit(func, x_old, y_old)

plt.plot(x, y, 'ro')
plt.plot(x, func(x, popt[0], popt[1]))
plt.plot(x_old,y_old,'g^')
plt.plot(x_old, func(x_old, popt_old[0], popt_old[1]))
#plt.plot(1/old_s0_rbase,cos((old_s0_theta/180)*np.pi))
plt.xlabel('${R \ _{BASE}}^{-1} \ [ nm ^{-1} ]$')
plt.ylabel(r' $\cos\Theta_{mic}$ ')
plt.suptitle(r'$\cos\Theta$ vs. ${R \ _{BASE}}^{-1}$', fontsize=14, fontweight='bold')
plt.text(0.37, -0.3, 'SAM 17%',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 80, 3.4, 4.8])
pylab.savefig('Theta_old_new_together_s17.png')
plt.show()
# Out:
# [ 0.46417544  0.3702446   0.32608491  0.2941504   0.27687038  0.25922246
#   0.25014212  0.23675518  0.22688782  0.21638685]
# [ 2.19105627  2.93484884  3.32979169  3.77727444]
# Line equation (old): a*x+b with a= -0.410868694912 and b= -0.0965248668185
# Theta_old = 117.887728851
# Sigma_old = 19.7565261251

# %%
plt.plot(percentages, theta_results, 'ro')
plt.plot(percentages, theta_results)
plt.plot(percentages, theta_results_old, 'g^')
plt.plot(percentages, theta_results_old)
plt.ylabel('CONTACT ANGLES [deg]')
plt.xlabel('OH- PERCENTAGE')
plt.suptitle('Contact Angles vs. OH- Percentages' , fontsize=14, fontweight='bold')
plt.grid(True)
#plt.axis([0, 80, 3.4, 4.8])
pylab.savefig('C_Angles_OH_old_new.png')
plt.show()

# %%
plt.plot(percentages, sigma, 'ro', k)
plt.plot(percentages, sigma)
plt.plot(percentages, sigma_old, 'g^', k)
plt.plot(percentages, sigma_old)
plt.ylabel(r' $\sigma $ [pN]')
plt.xlabel('OH- PERCENTAGE')
plt.suptitle('Contact Angles vs. OH- Percentages' , fontsize=14, fontweight='bold')
plt.grid(True)
#plt.axis([0, 80, 3.4, 4.8])
pylab.savefig('Sigma_OH_old_new.png')
plt.show()

# %%
print math.atan(0)

# %%
print type(rbase_s0)
