# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np
import math
import decimal

# %%
# This function allows to use ranges, just as the built-in function range(), but with float arguments.
# Taken from "http://code.activestate.com/recipes/66472-frange-a-range-function-with-float-increments/"
def frange(start, end=None, inc=None):
    if end == None:
        end = start + 0.0
        start = 0.0

    if inc == None:
        inc = 1.0

    L = []
    while 1:
        next = start + len(L) * inc
        if inc > 0 and next >= end:
            break
        elif inc < 0 and next <= end:
            break
        L.append(next)  #WE CHANGE THIS LINE FOR THE NEXT ONE, IN ORDER TO GET ONLY 2 DECIMALS PRECISSION
        #L.append(int(next * 100) / 100.0)
    return L

# %%
delta_m = frange(-0.45, 0.45, 0.001)
y1 = np.zeros(len(delta_m))
y2 = np.zeros(len(delta_m))
y3 = np.zeros(len(delta_m))
y4 = np.zeros(len(delta_m))
y5 = np.zeros(len(delta_m))
y6 = np.zeros(len(delta_m))
y7 = np.zeros(len(delta_m))
y8 = np.zeros(len(delta_m))
y9 = np.zeros(len(delta_m))

# %%
for i in range(len(delta_m)):
    R = 2
    m = 1.5
    y1[i] = math.degrees(math.atan(((m + delta_m[i])/math.sqrt(R**2 - (m + delta_m[i])**2)) + math.pi/2))
    R = 2.3
    m = 1.8
    y2[i] = math.degrees(math.atan(((m + delta_m[i])/math.sqrt(R**2 - (m + delta_m[i])**2)) + math.pi/2))
    R = 2.9
    m = 2.2
    y3[i] = math.degrees(math.atan(((m + delta_m[i])/math.sqrt(R**2 - (m + delta_m[i])**2)) + math.pi/2))
    R = 3.0
    m = 2.3
    y4[i] = math.degrees(math.atan(((m + delta_m[i])/math.sqrt(R**2 - (m + delta_m[i])**2)) + math.pi/2))
    R = 3.3
    m = 2.85
    y5[i] = math.degrees(math.atan(((m + delta_m[i])/math.sqrt(R**2 - (m + delta_m[i])**2)) + math.pi/2))
    R = 3.8
    m = 2.95
    y6[i] = math.degrees(math.atan(((m + delta_m[i])/math.sqrt(R**2 - (m + delta_m[i])**2)) + math.pi/2))
    R = 3.9
    m = 3.0
    y7[i] = math.degrees(math.atan(((m + delta_m[i])/math.sqrt(R**2 - (m + delta_m[i])**2)) + math.pi/2))
    R = 4.1
    m = 3.15
    y8[i] = math.degrees(math.atan(((m + delta_m[i])/math.sqrt(R**2 - (m + delta_m[i])**2)) + math.pi/2))
    R = 4.2
    m = 3.2
    y9[i] = math.degrees(math.atan(((m + delta_m[i])/math.sqrt(R**2 - (m + delta_m[i])**2)) + math.pi/2))
p1 = plt.plot(delta_m, y1, label="R = 2 nm, m = 1.5 nm")
p2 = plt.plot(delta_m, y2, label="R = 2.3 nm, m = 1.8 nm")
p3 = plt.plot(delta_m, y3, label="R = 2.9, m = 2.2 nm")
p4 = plt.plot(delta_m, y4, label="R = 3.0 nm, m = 2.3")
p5 = plt.plot(delta_m, y5, label="R = 2.5 nm, m = 2.85")
p6 = plt.plot(delta_m, y6, label="R = 3.3 nm, m = 2.85")
p7 = plt.plot(delta_m, y7, label="R = 3.8 nm, m = 2.85")
p8 = plt.plot(delta_m, y8, label="R = 4.1 nm, m = 2.85")
p9 = plt.plot(delta_m, y8, label="R = 4.2 nm, m = 2.85")
plt.xlabel(r' $\Delta (z)$ [nm]')
plt.ylabel(r' $\Theta $ [deg]')
supti = plt.suptitle('Contact Angles $\Theta$ vs. Displacement in z-direction $\Delta z$' , fontsize=16, fontweight='bold')
plt.grid(True)
plt.axis([-0.45, 0.45, 65, 90])
txt=" R is the droplet radius.\n m is the z-position of the circle center.\n Realistic pairs of values (R,m) were used"
lgd = plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
texti = plt.text(0.57, 67, txt,style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.savefig('Theta_Delta_m.png', bbox_extra_artists=(texti, supti, lgd,), bbox_inches='tight')
plt.show()
