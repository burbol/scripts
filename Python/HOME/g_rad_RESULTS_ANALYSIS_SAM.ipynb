# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
# %cd /home/eixeres/Downloads/Python/Results_SAM_last_peak
#%cd /Users/burbol/Downloads/Results_SAM_last_peak
# Out:
# /home/eixeres/Downloads/Python/Results_SAM_last_peak

# %%
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from scipy import stats

# %%
theta_results = np.zeros(5)
sigma = np.zeros(5)
percentages = np.zeros(5)
percentages = [0, 5, 11, 17, 66]

# %%
# We save the data in the arrays "theta_all" and "rbase_all"
theta_all, rbase_all = np.loadtxt('Contact_Angles2_SAM_s5.txt', skiprows=2, usecols = (0,1),unpack=True)

# %%
print len(theta_all), len(rbase_all)
# Out:
# 1600 1600

# %%
# Here we create two dictionaries named "angles" and "radii". Each dictionary consists of a set of "key: value" pairs, each one corresponding to a different system. The keys are (also) a pair of numbers "b, c".
# "b" refers to the OH-coverage percentage of the SAM, and "c" to the number of water molecules of the droplet. For example, the key "5, 1000" refers to the system with a surface with 5% OH-coverage, 
# and a droplet with 1000 water molecules. The value corresponding to each key is an array with the 40 calculated angles/base radii, that belong to that system. For example: "radii[(11, 3000)]" would give back
# the array with the 40 calculated values of the base radii corresponding to the system with a surface with 11% OH-coverage, and a droplet with 3000 water molecules.
angles={}
radii={}
k = 0
for b in [5]:
    for c in [1000, 2000, 3000, 4000, 5000, 6500, 7000, 8000, 9000, 10000]:
        z = b, c
        m = 0
        th = [0] * 200
        r = [0] * 200
        i=k*200
        j=(k+1)*200
        for l in range(i,j):
            th[m]=theta_all[l]
            r[m]=rbase_all[l]
            m = m +1
        angles[z] = th
        radii[z] = r
        k=k+1


theta_s5 = np.zeros(10)
rbase_s5 = np.zeros(10)
errortheta_s5 = np.zeros(10)
errorr_base_s5 = np.zeros(10)
#We choose a system and substitute the values "b" and "c" to save the corresponding angle and radii values in two arrays named, respectively, "theta" and "rbase".
#b=0
#c=4000
#theta = array(angles[(b, c)])
#rbase = array(radii[(b, c)])
#print "theta=", th
#print "rbase=", r
#print theta[0]

# %%
# The data of the SAM with 11% OH-coverage gets handled separately, because there are still some simulations missing. We save the data in the arrays "theta_all11" and "rbase_all11"
theta_all11, rbase_all11 = np.loadtxt('Contact_Angles2_SAM_s11.txt', skiprows=2, usecols = (0,1),unpack=True)

# %%
# DICTIONARIES FOR SAM 11% (MODIFIED CELL COPY)
# Here we create two dictionaries named "angles11" and "radii11". Each dictionary consists of a set of "key: value" pairs, each one corresponding to a different system. The keys are (also) a pair of numbers "b, c".
# "b" refers to the OH-coverage percentage of the SAM, and "c" to the number of water molecules of the droplet. For example, the key "5, 1000" refers to the system with a surface with 5% OH-coverage, 
# and a droplet with 1000 water molecules. The value corresponding to each key is an array with the 40 calculated angles/base radii, that belong to that system. For example: "radii[(11, 3000)]" would give back
# the array with the 40 calculated values of the base radii corresponding to the system with a surface with 11% OH-coverage, and a droplet with 3000 water molecules.
#angles11={}
#radii11={}
k = 0
for b in [11]:
    for c in [1000, 2000, 3000, 4000, 5000, 6500, 7000, 8000, 9000, 10000]:
        z = b, c
        m = 0
        t11 = [0] * 200
        r11 = [0] * 200
        i=k*200
        j=(k+1)*200
        for l in range(i,j):
            t11[m]=theta_all11[l]
            r11[m]=rbase_all11[l]
            m = m +1
#        angles11[z] = t11 THESE 2 LINES HAVE BEEN SUBSTITUTED BY THE FOLLOWING TWO.
#        radii11[z] = r11
        angles[z] = t11
        radii[z] = r11
        k=k+1
    
#theta_s11 = np.zeros(10) # UNCOMMENT THESE 2 LINES AND DELETE THE NEXT TWO, ONCE THE DATA FOR SAM11% WATER 2000
#rbase_s11 = np.zeros(10)

theta_s11 = np.zeros(9)
rbase_s11 = np.zeros(9)
errortheta_s11 = np.zeros(9)
errorr_base_s11 = np.zeros(9)

#We choose a system and substitute the values "b" and "c" to save the corresponding angle and radii values in two arrays named, respectively, "theta" and "rbase".
#b=11
#c=4000
#theta11 = array(angles11[(b, c)])
#rbase11 = array(radii11[(b, c)])
#print "theta11=", theta11
#print "rbase11=", rbase11
#print theta11[0]

# %%
# We save the data in the arrays "theta_all" and "rbase_all"
theta_all_s, rbase_all_s = np.loadtxt('Contact_Angles2_SAM_s0.txt', skiprows=2, usecols = (0,1),unpack=True)
print len(theta_all_s)
# Out:
# 1600

# %%
# Here we create two dictionaries named "angles" and "radii". Each dictionary consists of a set of "key: value" pairs, each one corresponding to a different system. The keys are (also) a pair of numbers "b, c".
# "b" refers to the OH-coverage percentage of the SAM, and "c" to the number of water molecules of the droplet. For example, the key "5, 1000" refers to the system with a surface with 5% OH-coverage, 
# and a droplet with 1000 water molecules. The value corresponding to each key is an array with the 40 calculated angles/base radii, that belong to that system. For example: "radii[(11, 3000)]" would give back
# the array with the 40 calculated values of the base radii corresponding to the system with a surface with 11% OH-coverage, and a droplet with 3000 water molecules.
#angles={}
#radii={}
k = 0
for b in [0]:
    for c in [1000, 2000, 3000, 4000, 5000, 6500, 7000, 8000, 9000, 10000]:
        z = b, c
        m = 0
        th = [0] * 200
        r = [0] * 200
        i=k*200
        j=(k+1)*200
        for l in range(i,j):
            th[m]=theta_all_s[l]
            r[m]=rbase_all_s[l]
            m = m +1
        angles[z] = th
        radii[z] = r
        k=k+1

theta_s0 = np.zeros(10)
rbase_s0 = np.zeros(10)
errortheta_s0 = np.zeros(10)
errorr_base_s0 = np.zeros(10)
#We choose a system and substitute the values "b" and "c" to save the corresponding angle and radii values in two arrays named, respectively, "theta" and "rbase".
#b=0
#c=4000
#theta = array(angles[(b, c)])
#rbase = array(radii[(b, c)])
#print "theta=", theta
#print "rbase=", rbase
#print theta[0]

# %%
# We save the data in the arrays "theta_all" and "rbase_all"
theta_all_17, rbase_all_17 = np.loadtxt('Contact_Angles2_SAM_s17.txt', skiprows=2, usecols = (0,1),unpack=True)

# %%
# Here we create two dictionaries named "angles" and "radii". Each dictionary consists of a set of "key: value" pairs, each one corresponding to a different system. The keys are (also) a pair of numbers "b, c".
# "b" refers to the OH-coverage percentage of the SAM, and "c" to the number of water molecules of the droplet. For example, the key "5, 1000" refers to the system with a surface with 5% OH-coverage, 
# and a droplet with 1000 water molecules. The value corresponding to each key is an array with the 40 calculated angles/base radii, that belong to that system. For example: "radii[(11, 3000)]" would give back
# the array with the 40 calculated values of the base radii corresponding to the system with a surface with 11% OH-coverage, and a droplet with 3000 water molecules.
#angles={}
#radii={}
k = 0
for b in [17]:
    for c in [1000, 2000, 3000, 4000, 5000, 6500, 7000, 8000, 9000, 10000]:
        z = b, c
        m = 0
        th = [0] * 200
        r = [0] * 200
        i=k*200
        j=(k+1)*200
        for l in range(i,j):
            th[m]=theta_all_17[l]
            r[m]=rbase_all_17[l]
            m = m +1
        angles[z] = th
        radii[z] = r
        k=k+1

theta_s17 = np.zeros(10)
rbase_s17 = np.zeros(10)
errortheta_s17 = np.zeros(10)
errorr_base_s17 = np.zeros(10)
#We choose a system and substitute the values "b" and "c" to save the corresponding angle and radii values in two arrays named, respectively, "theta" and "rbase".
#b=0
#c=4000
#theta = array(angles[(b, c)])
#rbase = array(radii[(b, c)])
#print "theta=", theta
#print "rbase=", rbase
#print theta[0]

# %%
# This function allows to use ranges, just as the built-in function range(), but with float arguments.
# Taken from "http://code.activestate.com/recipes/66472-frange-a-range-function-with-float-increments/"
def frange(start, end=None, inc=None):
    if end == None:
        end = start + 0.0
        start = 0.0

    if inc == None:
        inc = 1.0

    L = []
    while 1:
        next = start + len(L) * inc
        if inc > 0 and next >= end:
            break
        elif inc < 0 and next <= end:
            break
        L.append(next)
    return L

# %%
# We create an array named "t" with the time values.
t = np.zeros(200)
i=0
for d in frange(0, 100, 0.5):
    t[i] = d
    i = i + 1

# %%
def naive_variance(data):
    n = 0
    Sum = 0
    Sum_sqr = 0
 
    for x in data:
        n = n + 1
        Sum = Sum + x
        Sum_sqr = Sum_sqr + x*x
 
    variance = (Sum_sqr - (Sum*Sum)/n)/(n - 1)
    return variance

def blockAverage(datastream, Nblocks):
    
    # FIRST WE CREATE AN ARRAY TO STORE THE MEAN VALUES OF THE DATA BLOCKS (blockMean)
    blockMean = np.zeros(Nblocks)  
        
    # Nobs is the number of points (observations) in our data
    Nobs = len(datastream) 
    # BlockSize is the size of each block of data
    BlockSize = int(Nobs//Nblocks) 
    
    if Nblocks==1:
        errorbar = naive_variance(datastream)
        return errorbar

    else:
       # WE CALCULATE IN A LOOP THE MEAN VALUES OF EACH DATA BLOCK (blockMean)
        for i in range(0,Nblocks-1):
            ibeg = i*BlockSize
            iend = (i+1)*BlockSize
            blockMean[i] = mean(datastream[ibeg:iend])
        # WE TREAT THE LAST BLOCK SEPARATELY, BECAUSE WE HAVE TO TAKE INTO ACCOUNT THE POSSIBLE REMAINING POINTS 
        # WHEN THE NUMBER OF DATA POINTS ISN'T A MULTIPLE OF THE NUMBER OF BLOCKS
        ibeg = (Nblocks-1)*BlockSize
        iend = Nobs
        blockMean[Nblocks-1] = mean(datastream[ibeg:iend])
     
        errorbar = (np.std(blockMean))/sqrt(Nblocks -1) #np.std(blockMean) is the standard deviation of blockmean
        simulavr = mean(blockMean)
        return simulavr, errorbar

# %%
n=0
b=0
c=1000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=9
end=79
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
end = m

omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS
error = np.zeros(end-omit-1)
average = np.zeros(end-omit-1)
error = error.tolist()
j=0
for i in range (omit, end-1):
    average[j],error[j] = blockAverage((theta[i:end]),3)    
    error[j] = sin(radians(average[j]))*error[j]   
    j = j+1
bestblock = error.index(min(error))
start = bestblock + omit

print "start of bestblock = " , (bestblock+omit)
print "smallest average = ", error[bestblock]
#print "error=", error

average, dummy = blockAverage((theta[start:end]),3)  
theta_avr = average*np.ones(end - start)
errortheta_s0[n] = dummy

average, dummy = blockAverage((rbase[start:end]),3)
rbase_avr = average*np.ones(end - start)
errorr_base_s0[n] = dummy
t_avr = t[start:end]

theta_s0[n]=theta_avr[0] 
rbase_s0[n]=rbase_avr[0] 
print "theta_s0[n] = ", theta_s0[n]
print "rbase_s0[n] = ",rbase_s0[n]


#PLOT FOR CONTACT ANGLE OF SAM 0% & 1000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta_{mic}$ vs. Time')
plt.text(11, 166, 'SAM 0%, Water 1000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 120, 180])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 1000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta_{mic}$ vs. Time')
plt.text(11, 0.3, 'SAM 0%, Water 1000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 0, 2])
pylab.savefig(namebaserad)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c52193d83f80> in <module>()
#       2 b=0
#       3 c=1000
# ----> 4 theta = array(angles[(b, c)])
#       5 rbase = array(radii[(b, c)])
#       6 nametheta = "thetas%sw%s.png" % (b,c)
#
# NameError: name 'array' is not defined

# %%
n=1
b=0
c=2000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=50
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
end = m

omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS
error = np.zeros(end-omit-1)
average = np.zeros(end-omit-1)
error = error.tolist()
j=0
for i in range (omit, end-1):
    average[j],error[j] = blockAverage((theta[i:end]),3)    
    error[j] = sin(radians(average[j]))*error[j]   
    j = j+1
bestblock = error.index(min(error))
start = bestblock + omit

print "start of bestblock = " , (bestblock+omit)
print "smallest average = ", error[bestblock]
#print "error=", error

average, dummy = blockAverage((theta[start:end]),3)  
theta_avr = average*np.ones(end - start)
errortheta_s0[n] = dummy

average, dummy = blockAverage((rbase[start:end]),3)
rbase_avr = average*np.ones(end - start)
errorr_base_s0[n] = dummy
t_avr = t[start:end]

theta_s0[n]=theta_avr[0] 
rbase_s0[n]=rbase_avr[0] 
print "theta_s0[n] = ", theta_s0[n]
print "rbase_s0[n] = ",rbase_s0[n]


#PLOT FOR CONTACT ANGLE OF SAM 0% & 2000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta_{mic}$ vs. Time')
plt.text(11, 155, 'SAM 0%, Water 2000 molec.',style='italic',bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 2000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta_{mic}$ vs. Time')
plt.text(11, 0.8, 'SAM 0%, Water 2000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# start of bestblock =  67
# smallest average =  0.0283426198274
# theta_s0[n] =  148.359078803
# rbase_s0[n] =  1.29667143818

# %%
n=2
b=0
c=3000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=22
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
end = m

omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS
error = np.zeros(end-omit-1)
average = np.zeros(end-omit-1)
error = error.tolist()
j=0
for i in range (omit, end-1):
    average[j],error[j] = blockAverage((theta[i:end]),3)    
    error[j] = sin(radians(average[j]))*error[j]   
    j = j+1
bestblock = error.index(min(error))
start = bestblock + omit

print "start of bestblock = " , (bestblock+omit)
print "smallest average = ", error[bestblock]
#print "error=", error

average, dummy = blockAverage((theta[start:end]),3)  
theta_avr = average*np.ones(end - start)
errortheta_s0[n] = dummy

average, dummy = blockAverage((rbase[start:end]),3)
rbase_avr = average*np.ones(end - start)
errorr_base_s0[n] = dummy
t_avr = t[start:end]

theta_s0[n]=theta_avr[0] 
rbase_s0[n]=rbase_avr[0] 
print "theta_s0[n] = ", theta_s0[n]
print "rbase_s0[n] = ",rbase_s0[n]
#PLOT FOR CONTACT ANGLE OF SAM 0% & 3000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta_{mic}$ vs. Time')
plt.text(11, 155, 'SAM 0%, Water 3000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 3000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta_{mic}$ vs. Time')
plt.text(11, 1.6, 'SAM 0%, Water 3000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 0.8, 2.3])
pylab.savefig(namebaserad)
plt.show()
# Out:
# start of bestblock =  27
# smallest average =  0.0258649396675
# theta_s0[n] =  147.75959864
# rbase_s0[n] =  1.49333781122

# %%
n=3
b=0
c=4000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=42
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
end = m

omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS
error = np.zeros(end-omit-1)
average = np.zeros(end-omit-1)
error = error.tolist()
j=0
for i in range (omit, end-1):
    average[j],error[j] = blockAverage((theta[i:end]),3)    
    error[j] = sin(radians(average[j]))*error[j]   
    j = j+1
bestblock = error.index(min(error))
start = bestblock + omit

print "start of bestblock = " , (bestblock+omit)
print "smallest average = ", error[bestblock]
#print "error=", error

average, dummy = blockAverage((theta[start:end]),3)  
theta_avr = average*np.ones(end - start)
errortheta_s0[n] = dummy

average, dummy = blockAverage((rbase[start:end]),3)
rbase_avr = average*np.ones(end - start)
errorr_base_s0[n] = dummy
t_avr = t[start:end]

theta_s0[n]=theta_avr[0] 
rbase_s0[n]=rbase_avr[0] 
print "theta_s0[n] = ", theta_s0[n]
print "rbase_s0[n] = ",rbase_s0[n]

#PLOT FOR CONTACT ANGLE OF SAM 0% & 4000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta_{mic}$ vs. Time')
plt.text(11, 160, 'SAM 0%, Water 4000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 4000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1, 'SAM 0%, Water 4000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 0.6, 2.5])
pylab.savefig(namebaserad)
plt.show()
# Out:
# start of bestblock =  73
# smallest average =  0.0165109537076
# theta_s0[n] =  147.106200026
# rbase_s0[n] =  1.67870377529

# %%
n=4
b=0
c=5000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=50
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
end = m

omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS
error = np.zeros(end-omit-1)
average = np.zeros(end-omit-1)
error = error.tolist()
j=0
for i in range (omit, end-1):
    average[j],error[j] = blockAverage((theta[i:end]),3)    
    error[j] = sin(radians(average[j]))*error[j]   
    j = j+1
bestblock = error.index(min(error))
start = bestblock + omit

print "start of bestblock = " , (bestblock+omit)
print "smallest average = ", error[bestblock]
#print "error=", error

average, dummy = blockAverage((theta[start:end]),3)  
theta_avr = average*np.ones(end - start)
errortheta_s0[n] = dummy

average, dummy = blockAverage((rbase[start:end]),3)
rbase_avr = average*np.ones(end - start)
errorr_base_s0[n] = dummy
t_avr = t[start:end]

theta_s0[n]=theta_avr[0] 
rbase_s0[n]=rbase_avr[0] 
print "theta_s0[n] = ", theta_s0[n]
print "rbase_s0[n] = ",rbase_s0[n]


#PLOT FOR CONTACT ANGLE OF SAM 0% & 5000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(20, 165, 'SAM 0%, Water 5000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 40, 134, 154])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 5000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(20, 0.6, 'SAM 0%, Water 5000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 40, 1.4, 2.5])
pylab.savefig(namebaserad)
plt.show()
# Out:
# start of bestblock =  76
# smallest average =  0.0487618848119
# theta_s0[n] =  147.383012755
# rbase_s0[n] =  1.78987804648

# %%
n=5
b=0
c=6500
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=80
end=120
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
end = m

omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS
error = np.zeros(end-omit-1)
average = np.zeros(end-omit-1)
error = error.tolist()
j=0
for i in range (omit, end-1):
    average[j],error[j] = blockAverage((theta[i:end]),3)    
    error[j] = sin(radians(average[j]))*error[j]   
    j = j+1
bestblock = error.index(min(error))
start = bestblock + omit

print "start of bestblock = " , (bestblock+omit)
print "smallest average = ", error[bestblock]
#print "error=", error

average, dummy = blockAverage((theta[start:end]),3)  
theta_avr = average*np.ones(end - start)
errortheta_s0[n] = dummy

average, dummy = blockAverage((rbase[start:end]),3)
rbase_avr = average*np.ones(end - start)
errorr_base_s0[n] = dummy
t_avr = t[start:end]

theta_s0[n]=theta_avr[0] 
rbase_s0[n]=rbase_avr[0] 
print "theta_s0[n] = ", theta_s0[n]
print "rbase_s0[n] = ",rbase_s0[n]

#PLOT FOR CONTACT ANGLE OF SAM 0% & 6500 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 150, 'SAM 0%, Water 6500 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 6500 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 1.6, 'SAM 0%, Water 6500 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# start of bestblock =  112
# smallest average =  0.00364891439143
# theta_s0[n] =  146.562753114
# rbase_s0[n] =  2.00397783654

# %%
n=6
b=0
c=7000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=86
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
end = m

omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS
error = np.zeros(end-omit-1)
average = np.zeros(end-omit-1)
error = error.tolist()
j=0
for i in range (omit, end-1):
    average[j],error[j] = blockAverage((theta[i:end]),3)    
    error[j] = sin(radians(average[j]))*error[j]   
    j = j+1
bestblock = error.index(min(error))
start = bestblock + omit

print "start of bestblock = " , (bestblock+omit)
print "smallest average = ", error[bestblock]
#print "error=", error

average, dummy = blockAverage((theta[start:end]),3)  
theta_avr = average*np.ones(end - start)
errortheta_s0[n] = dummy

average, dummy = blockAverage((rbase[start:end]),3)
rbase_avr = average*np.ones(end - start)
errorr_base_s0[n] = dummy
t_avr = t[start:end]

theta_s0[n]=theta_avr[0] 
rbase_s0[n]=rbase_avr[0] 
print "theta_s0[n] = ", theta_s0[n]
print "rbase_s0[n] = ",rbase_s0[n]

#PLOT FOR CONTACT ANGLE OF SAM 0% & 7000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 155, 'SAM 0%, Water 7000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 60, 133, 160])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 7000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 1.4, 'SAM 0%, Water 7000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 60, 1.2, 2.8])
pylab.savefig(namebaserad)
plt.show()
# Out:
# start of bestblock =  106
# smallest average =  0.00483379646436
# theta_s0[n] =  146.312256762
# rbase_s0[n] =  2.06220745201

# %%
n=7
b=0
c=8000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=90
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
end = m

omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS
error = np.zeros(end-omit-1)
average = np.zeros(end-omit-1)
error = error.tolist()
j=0
for i in range (omit, end-1):
    average[j],error[j] = blockAverage((theta[i:end]),3)    
    error[j] = sin(radians(average[j]))*error[j]   
    j = j+1
bestblock = error.index(min(error))
start = bestblock + omit

print "start of bestblock = " , (bestblock+omit)
print "smallest average = ", error[bestblock]
#print "error=", error

average, dummy = blockAverage((theta[start:end]),3)  
theta_avr = average*np.ones(end - start)
errortheta_s0[n] = dummy

average, dummy = blockAverage((rbase[start:end]),3)
rbase_avr = average*np.ones(end - start)
errorr_base_s0[n] = dummy
t_avr = t[start:end]

theta_s0[n]=theta_avr[0] 
rbase_s0[n]=rbase_avr[0] 
print "theta_s0[n] = ", theta_s0[n]
print "rbase_s0[n] = ",rbase_s0[n]


#PLOT FOR CONTACT ANGLE OF SAM 0% & 8000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(30, 172, 'SAM 0%, Water 8000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 8000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(30, 0.3, 'SAM 0%, Water 8000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# start of bestblock =  106
# smallest average =  0.0153971650406
# theta_s0[n] =  146.489990784
# rbase_s0[n] =  2.14486759594

# %%
n=8
b=0
c=9000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=100
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
end = m

omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS
error = np.zeros(end-omit-1)
average = np.zeros(end-omit-1)
error = error.tolist()
j=0
for i in range (omit, end-1):
    average[j],error[j] = blockAverage((theta[i:end]),3)    
    error[j] = sin(radians(average[j]))*error[j]   
    j = j+1
bestblock = error.index(min(error))
start = bestblock + omit

print "start of bestblock = " , (bestblock+omit)
print "smallest average = ", error[bestblock]
#print "error=", error

average, dummy = blockAverage((theta[start:end]),3)  
theta_avr = average*np.ones(end - start)
errortheta_s0[n] = dummy

average, dummy = blockAverage((rbase[start:end]),3)
rbase_avr = average*np.ones(end - start)
errorr_base_s0[n] = dummy
t_avr = t[start:end]

theta_s0[n]=theta_avr[0] 
rbase_s0[n]=rbase_avr[0] 
print "theta_s0[n] = ", theta_s0[n]
print "rbase_s0[n] = ",rbase_s0[n]


#PLOT FOR CONTACT ANGLE OF SAM 0% & 9000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(30, 165, 'SAM 0%, Water 9000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 9000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(30, 0.9, 'SAM 0%, Water 9000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# start of bestblock =  117
# smallest average =  0.0336239609675
# theta_s0[n] =  146.847479123
# rbase_s0[n] =  2.21510486024

# %%
n=9
b=0
c=10000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=120
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
end = m

omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS
error = np.zeros(end-omit-1)
average = np.zeros(end-omit-1)
error = error.tolist()
j=0
for i in range (omit, end-1):
    average[j],error[j] = blockAverage((theta[i:end]),3)    
    error[j] = sin(radians(average[j]))*error[j]   
    j = j+1
bestblock = error.index(min(error))
start = bestblock + omit

print "start of bestblock = " , (bestblock+omit)
print "smallest average = ", error[bestblock]
#print "error=", error

average, dummy = blockAverage((theta[start:end]),3)  
theta_avr = average*np.ones(end - start)
errortheta_s0[n] = dummy

average, dummy = blockAverage((rbase[start:end]),3)
rbase_avr = average*np.ones(end - start)
errorr_base_s0[n] = dummy
t_avr = t[start:end]

theta_s0[n]=theta_avr[0] 
rbase_s0[n]=rbase_avr[0] 
print "theta_s0[n] = ", theta_s0[n]
print "rbase_s0[n] = ",rbase_s0[n]


#PLOT FOR CONTACT ANGLE OF SAM 0% & 10000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(30, 167, 'SAM 0%, Water 10000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 10000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(30, 0.7, 'SAM 0%, Water 10000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# start of bestblock =  152
# smallest average =  0.00803511417027
# theta_s0[n] =  146.61620864
# rbase_s0[n] =  2.30666458999

# %%
n=0
b=5
c=1000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=10
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
end = m
omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS
error = np.zeros(end-omit-1)
average = np.zeros(end-omit-1)
error = error.tolist()
j=0
for i in range (omit, end-1):
    average[j],error[j] = blockAverage((theta[i:end]),3)    
    error[j] = sin(radians(average[j]))*error[j]   
    j = j+1
bestblock = error.index(min(error))
start = bestblock + omit

print "start of bestblock = " , (bestblock+omit)
print "smallest average = ", error[bestblock]
#print "error=", error

average, dummy = blockAverage((theta[start:end]),3)  
theta_avr = average*np.ones(end - start)
errortheta_s5[n] = dummy

average, dummy = blockAverage((rbase[start:end]),3)
rbase_avr = average*np.ones(end - start)
errorr_base_s5[n] = dummy
t_avr = t[start:end]

theta_s5[n]=theta_avr[0] 
rbase_s5[n]=rbase_avr[0] 
print "theta_s5[n] = ", theta_s5[n]
print "rbase_s5[n] = ",rbase_s5[n]



#PLOT FOR CONTACT ANGLE OF SAM 5% & 1000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 160, 'SAM 5%, Water 1000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 115, 170])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 1000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.1, 'SAM 5%, Water 1000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 1.0, 1.8])
pylab.savefig(namebaserad)
plt.show()
# Out:
# start of bestblock =  12
# smallest average =  0.0129037139316
# theta_s5[n] =  141.162858934
# rbase_s5[n] =  1.2476049234

# %%
n=1
b=5
c=2000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
#print theta
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=10
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
end = m
omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS
error = np.zeros(end-omit-1)
average = np.zeros(end-omit-1)
error = error.tolist()
j=0
for i in range (omit, end-1):
    average[j],error[j] = blockAverage((theta[i:end]),3)    
    error[j] = sin(radians(average[j]))*error[j]   
    j = j+1
bestblock = error.index(min(error))
start = bestblock + omit

print "start of bestblock = " , (bestblock+omit)
print "smallest average = ", error[bestblock]
#print "error=", error

average, dummy = blockAverage((theta[start:end]),3)  
theta_avr = average*np.ones(end - start)
errortheta_s5[n] = dummy

average, dummy = blockAverage((rbase[start:end]),3)
rbase_avr = average*np.ones(end - start)
errorr_base_s5[n] = dummy
t_avr = t[start:end]

theta_s5[n]=theta_avr[0] 
rbase_s5[n]=rbase_avr[0] 
print "theta_s5[n] = ", theta_s5[n]
print "rbase_s5[n] = ",rbase_s5[n]


#PLOT FOR CONTACT ANGLE OF SAM 5% & 2000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 147, 'SAM 5%, Water 2000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 120, 155])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 2000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.2, 'SAM 5%, Water 2000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 1.0, 2.3])
pylab.savefig(namebaserad)
plt.show()
# Out:
# start of bestblock =  30
# smallest average =  0.013152555475
# theta_s5[n] =  137.542225412
# rbase_s5[n] =  1.68864595688

# %%
n=1
b=5
c=3000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=16
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
end = m
omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS
error = np.zeros(end-omit-1)
average = np.zeros(end-omit-1)
error = error.tolist()
j=0
for i in range (omit, end-1):
    average[j],error[j] = blockAverage((theta[i:end]),3)    
    error[j] = sin(radians(average[j]))*error[j]   
    j = j+1
bestblock = error.index(min(error))
start = bestblock + omit

print "start of bestblock = " , (bestblock+omit)
print "smallest average = ", error[bestblock]
#print "error=", error

average, dummy = blockAverage((theta[start:end]),3)  
theta_avr = average*np.ones(end - start)
errortheta_s5[n] = dummy

average, dummy = blockAverage((rbase[start:end]),3)
rbase_avr = average*np.ones(end - start)
errorr_base_s5[n] = dummy
t_avr = t[start:end]

theta_s5[n]=theta_avr[0] 
rbase_s5[n]=rbase_avr[0] 
print "theta_s5[n] = ", theta_s5[n]
print "rbase_s5[n] = ",rbase_s5[n]


#PLOT FOR CONTACT ANGLE OF SAM 5% & 3000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 160, 'SAM 5%, Water 3000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 120, 170])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 3000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.6, 'SAM 5%, Water 3000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 1.45, 2.35])
pylab.savefig(namebaserad)
plt.show()
# Out:
# start of bestblock =  55
# smallest average =  0.0131432915763
# theta_s5[n] =  141.414500984
# rbase_s5[n] =  1.75394971312

# %%
n=3
b=5
c=4000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
#print rbase
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=15
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
end = m
omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS
error = np.zeros(end-omit-1)
average = np.zeros(end-omit-1)
error = error.tolist()
j=0
for i in range (omit, end-1):
    average[j],error[j] = blockAverage((theta[i:end]),3)    
    error[j] = sin(radians(average[j]))*error[j]   
    j = j+1
bestblock = error.index(min(error))
start = bestblock + omit

print "start of bestblock = " , (bestblock+omit)
print "smallest average = ", error[bestblock]
#print "error=", error

average, dummy = blockAverage((theta[start:end]),3)  
theta_avr = average*np.ones(end - start)
errortheta_s5[n] = dummy

average, dummy = blockAverage((rbase[start:end]),3)
rbase_avr = average*np.ones(end - start)
errorr_base_s5[n] = dummy
t_avr = t[start:end]

theta_s5[n]=theta_avr[0] 
rbase_s5[n]=rbase_avr[0] 
print "theta_s5[n] = ", theta_s5[n]
print "rbase_s5[n] = ",rbase_s5[n]


#PLOT FOR CONTACT ANGLE OF SAM 5% & 4000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 180, 'SAM 5%, Water 4000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 115, 205])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 4000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 0.8, 'SAM 5%, Water 4000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 0.6, 2.6])
pylab.savefig(namebaserad)
plt.show()
# Out:
# start of bestblock =  38
# smallest average =  0.00590503565452
# theta_s5[n] =  143.524373368
# rbase_s5[n] =  1.8425501507

# %%
n=4
b=5
c=5000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=20
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
end = m
omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS
error = np.zeros(end-omit-1)
average = np.zeros(end-omit-1)
error = error.tolist()
j=0
for i in range (omit, end-1):
    average[j],error[j] = blockAverage((theta[i:end]),3)    
    error[j] = sin(radians(average[j]))*error[j]   
    j = j+1
bestblock = error.index(min(error))
start = bestblock + omit

print "start of bestblock = " , (bestblock+omit)
print "smallest average = ", error[bestblock]
#print "error=", error

average, dummy = blockAverage((theta[start:end]),3)  
theta_avr = average*np.ones(end - start)
errortheta_s5[n] = dummy

average, dummy = blockAverage((rbase[start:end]),3)
rbase_avr = average*np.ones(end - start)
errorr_base_s5[n] = dummy
t_avr = t[start:end]

theta_s5[n]=theta_avr[0] 
rbase_s5[n]=rbase_avr[0] 
print "theta_s5[n] = ", theta_s5[n]
print "rbase_s5[n] = ",rbase_s5[n]


#PLOT FOR CONTACT ANGLE OF SAM 5% & 5000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 170, 'SAM 5%, Water 5000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 125, 180])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 5000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.8, 'SAM 5%, Water 5000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 1.6, 2.6])
pylab.savefig(namebaserad)
plt.show()
# Out:
# start of bestblock =  61
# smallest average =  0.0195677554639
# theta_s5[n] =  144.43952209
# rbase_s5[n] =  1.93411852703

# %%
n=5
b=5
c=6500
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=50
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
end = m
omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS
error = np.zeros(end-omit-1)
average = np.zeros(end-omit-1)
error = error.tolist()
j=0
for i in range (omit, end-1):
    average[j],error[j] = blockAverage((theta[i:end]),3)    
    error[j] = sin(radians(average[j]))*error[j]   
    j = j+1
bestblock = error.index(min(error))
start = bestblock + omit

print "start of bestblock = " , (bestblock+omit)
print "smallest average = ", error[bestblock]
#print "error=", error

average, dummy = blockAverage((theta[start:end]),3)  
theta_avr = average*np.ones(end - start)
errortheta_s5[n] = dummy

average, dummy = blockAverage((rbase[start:end]),3)
rbase_avr = average*np.ones(end - start)
errorr_base_s5[n] = dummy
t_avr = t[start:end]

theta_s5[n]=theta_avr[0] 
rbase_s5[n]=rbase_avr[0] 
print "theta_s5[n] = ", theta_s5[n]
print "rbase_s5[n] = ",rbase_s5[n]

#PLOT FOR CONTACT ANGLE OF SAM 5% & 6500 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 181, 'SAM 5%, Water 6500 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 60, 120, 200])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 6500 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 2.1, 'SAM 5%, Water 6500 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 60, 2, 3])
pylab.savefig(namebaserad)
plt.show()
# Out:
# start of bestblock =  88
# smallest average =  0.00677658595846
# theta_s5[n] =  136.173339047
# rbase_s5[n] =  2.55277455304

# %%
n=6
b=5
c=7000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=70
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
end = m
omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS
error = np.zeros(end-omit-1)
average = np.zeros(end-omit-1)
error = error.tolist()
j=0
for i in range (omit, end-1):
    average[j],error[j] = blockAverage((theta[i:end]),3)    
    error[j] = sin(radians(average[j]))*error[j]   
    j = j+1
bestblock = error.index(min(error))
start = bestblock + omit

print "start of bestblock = " , (bestblock+omit)
print "smallest average = ", error[bestblock]
#print "error=", error

average, dummy = blockAverage((theta[start:end]),3)  
theta_avr = average*np.ones(end - start)
errortheta_s5[n] = dummy

average, dummy = blockAverage((rbase[start:end]),3)
rbase_avr = average*np.ones(end - start)
errorr_base_s5[n] = dummy
t_avr = t[start:end]

theta_s5[n]=theta_avr[0] 
rbase_s5[n]=rbase_avr[0] 
print "theta_s5[n] = ", theta_s5[n]
print "rbase_s5[n] = ",rbase_s5[n]


#PLOT FOR CONTACT ANGLE OF SAM 5% & 7000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 150, 'SAM 5%, Water 7000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 7000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 2.05, 'SAM 5%, Water 7000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 60, 1.9, 3.2])
pylab.savefig(namebaserad)
plt.show()
# Out:
# start of bestblock =  117
# smallest average =  0.0253577331372
# theta_s5[n] =  136.354389335
# rbase_s5[n] =  2.59818724658

# %%
n=7
b=5
c=8000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=70
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
end = m
omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS
error = np.zeros(end-omit-1)
average = np.zeros(end-omit-1)
error = error.tolist()
j=0
for i in range (omit, end-1):
    average[j],error[j] = blockAverage((theta[i:end]),3)    
    error[j] = sin(radians(average[j]))*error[j]   
    j = j+1
bestblock = error.index(min(error))
start = bestblock + omit

print "start of bestblock = " , (bestblock+omit)
print "smallest average = ", error[bestblock]
#print "error=", error

average, dummy = blockAverage((theta[start:end]),3)  
theta_avr = average*np.ones(end - start)
errortheta_s5[n] = dummy

average, dummy = blockAverage((rbase[start:end]),3)
rbase_avr = average*np.ones(end - start)
errorr_base_s5[n] = dummy
t_avr = t[start:end]

theta_s5[n]=theta_avr[0] 
rbase_s5[n]=rbase_avr[0] 
print "theta_s5[n] = ", theta_s5[n]
print "rbase_s5[n] = ",rbase_s5[n]


#PLOT FOR CONTACT ANGLE OF SAM 5% & 9000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 146, 'SAM 5%, Water 8000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 9000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 1.8, 'SAM 5%, Water 8000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# start of bestblock =  82
# smallest average =  0.0108629546344
# theta_s5[n] =  136.803814705
# rbase_s5[n] =  2.69140985774

# %%
n=8
b=5
c=9000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=76
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
end = m
omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS
error = np.zeros(end-omit-1)
average = np.zeros(end-omit-1)
error = error.tolist()
j=0
for i in range (omit, end-1):
    average[j],error[j] = blockAverage((theta[i:end]),3)    
    error[j] = sin(radians(average[j]))*error[j]   
    j = j+1
bestblock = error.index(min(error))
start = bestblock + omit

print "start of bestblock = " , (bestblock+omit)
print "smallest average = ", error[bestblock]
#print "error=", error

average, dummy = blockAverage((theta[start:end]),3)  
theta_avr = average*np.ones(end - start)
errortheta_s5[n] = dummy

average, dummy = blockAverage((rbase[start:end]),3)
rbase_avr = average*np.ones(end - start)
errorr_base_s5[n] = dummy
t_avr = t[start:end]

theta_s5[n]=theta_avr[0] 
rbase_s5[n]=rbase_avr[0] 
print "theta_s5[n] = ", theta_s5[n]
print "rbase_s5[n] = ",rbase_s5[n]


#PLOT FOR CONTACT ANGLE OF SAM 5% & 9000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 146, 'SAM 5%, Water 9000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 9000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 2.0, 'SAM 5%, Water 9000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# start of bestblock =  71
# smallest average =  0.00752154068666
# theta_s5[n] =  137.138719662
# rbase_s5[n] =  2.78693344967

# %%
n=9
b=5
c=10000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=130
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
end = m
omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS
error = np.zeros(end-omit-1)
average = np.zeros(end-omit-1)
error = error.tolist()
j=0
for i in range (omit, end-1):
    average[j],error[j] = blockAverage((theta[i:end]),3)    
    error[j] = sin(radians(average[j]))*error[j]   
    j = j+1
bestblock = error.index(min(error))
start = bestblock + omit

print "start of bestblock = " , (bestblock+omit)
print "smallest average = ", error[bestblock]
#print "error=", error

average, dummy = blockAverage((theta[start:end]),3)  
theta_avr = average*np.ones(end - start)
errortheta_s5[n] = dummy

average, dummy = blockAverage((rbase[start:end]),3)
rbase_avr = average*np.ones(end - start)
errorr_base_s5[n] = dummy
t_avr = t[start:end]

theta_s5[n]=theta_avr[0] 
rbase_s5[n]=rbase_avr[0] 
print "theta_s5[n] = ", theta_s5[n]
print "rbase_s5[n] = ",rbase_s5[n]


#PLOT FOR CONTACT ANGLE OF SAM 5% & 10000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(25, 146, 'SAM 5%, Water 10000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 10000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(25, 2, 'SAM 5%, Water 10000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# start of bestblock =  155
# smallest average =  0.0204128208907
# theta_s5[n] =  136.942909983
# rbase_s5[n] =  2.8966487225

# %%
n=0
b=11
c=1000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
#print theta
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=60
end=80
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
end = m
omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS
error = np.zeros(end-omit-1)
average = np.zeros(end-omit-1)
error = error.tolist()
j=0
for i in range (omit, end-1):
    average[j],error[j] = blockAverage((theta[i:end]),3)    
    error[j] = sin(radians(average[j]))*error[j]   
    j = j+1
bestblock = error.index(min(error))
start = bestblock + omit

print "start of bestblock = " , (bestblock+omit)
print "smallest average = ", error[bestblock]
#print "error=", error

average, dummy = blockAverage((theta[start:end]),3)  
theta_avr = average*np.ones(end - start)
errortheta_s11[n] = dummy

average, dummy = blockAverage((rbase[start:end]),3)
rbase_avr = average*np.ones(end - start)
errorr_base_s11[n] = dummy
t_avr = t[start:end]

theta_s11[n]=theta_avr[0] 
rbase_s11[n]=rbase_avr[0] 
print "theta_s11[n] = ", theta_s11[n]
print "rbase_s11[n] = ",rbase_s11[n]

#PLOT FOR CONTACT ANGLE OF SAM 11% & 1000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 102, 'SAM 11%, Water 1000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 1000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 1.65, 'SAM 11%, Water 1000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# start of bestblock =  59
# smallest average =  0.0704139437527
# theta_s11[n] =  117.904725104
# rbase_s11[n] =  1.86127142812

# %%
# n=1 Uncomment when there is more data
n=10
b=11
c=2000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=60
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
end = m
omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS
error = np.zeros(end-omit-1)
average = np.zeros(end-omit-1)
error = error.tolist()
j=0
for i in range (omit, end-1):
    average[j],error[j] = blockAverage((theta[i:end]),3)    
    error[j] = sin(radians(average[j]))*error[j]   
    j = j+1
bestblock = error.index(min(error))
start = bestblock + omit

print "start of bestblock = " , (bestblock+omit)
print "smallest average = ", error[bestblock]
#print "error=", error

average, dummy = blockAverage((theta[start:end]),3)  
theta_avr = average*np.ones(end - start)
errortheta_s11[n] = dummy

average, dummy = blockAverage((rbase[start:end]),3)
rbase_avr = average*np.ones(end - start)
errorr_base_s11[n] = dummy
t_avr = t[start:end]

theta_s11[n]=theta_avr[0] 
rbase_s11[n]=rbase_avr[0] 
print "theta_s11[n] = ", theta_s11[n]
print "rbase_s11[n] = ",rbase_s11[n]

#PLOT FOR CONTACT ANGLE OF SAM 11% & 2000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(1, 150, 'SAM 11%, Water 2000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 20, 90, 170])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 2000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(1, 1.0, 'SAM 11%, Water 2000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 20, 0, 3])
pylab.savefig(namebaserad)
plt.show()end=80
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

#theta_s11[1]=theta_avr[0] #UNCOMMENT THESE 4 LINES ONCE THERE IS THE COMPLETE DATA OF THIS SYSTEM
#rbase_s11[1]=rbase_avr[0] 
#print theta_s11[1]
#print rbase_s11[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-64-4d05da2f8321> in <module>()
#      33 average, dummy = blockAverage((theta[start:end]),3)
#      34 theta_avr = average*np.ones(end - start)
# ---> 35 errortheta_s11[n] = dummy
#      36
#      37 average, dummy = blockAverage((rbase[start:end]),3)
#
# IndexError: index out of bounds
# start of bestblock =  10
# smallest average =  nan

# %%
n=2
b=11
c=3000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
#print theta
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=10
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
end = m
omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS
error = np.zeros(end-omit-1)
average = np.zeros(end-omit-1)
error = error.tolist()
j=0
for i in range (omit, end-1):
    average[j],error[j] = blockAverage((theta[i:end]),3)    
    error[j] = sin(radians(average[j]))*error[j]   
    j = j+1
bestblock = error.index(min(error))
start = bestblock + omit

print "start of bestblock = " , (bestblock+omit)
print "smallest average = ", error[bestblock]
#print "error=", error

average, dummy = blockAverage((theta[start:end]),3)  
theta_avr = average*np.ones(end - start)
errortheta_s11[n] = dummy

average, dummy = blockAverage((rbase[start:end]),3)
rbase_avr = average*np.ones(end - start)
errorr_base_s11[n] = dummy
t_avr = t[start:end]

theta_s11[n]=theta_avr[0] 
rbase_s11[n]=rbase_avr[0] 
print "theta_s11[n] = ", theta_s11[n]
print "rbase_s11[n] = ",rbase_s11[n]

#PLOT FOR CONTACT ANGLE OF SAM 11% & 3000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 155, 'SAM 11%, Water 3000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 100, 170])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 3000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 0.8, 'SAM 11%, Water 3000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 0.5, 3.4])
pylab.savefig(namebaserad)
plt.show()
# Out:
# start of bestblock =  20
# smallest average =  0.167172702063
# theta_s11[n] =  120.337192474
# rbase_s11[n] =  2.55379053314

# %%
n=3
b=11
c=4000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
#print theta
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=20
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
end = m
omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS
error = np.zeros(end-omit-1)
average = np.zeros(end-omit-1)
error = error.tolist()
j=0
for i in range (omit, end-1):
    average[j],error[j] = blockAverage((theta[i:end]),3)    
    error[j] = sin(radians(average[j]))*error[j]   
    j = j+1
bestblock = error.index(min(error))
start = bestblock + omit

print "start of bestblock = " , (bestblock+omit)
print "smallest average = ", error[bestblock]
#print "error=", error

average, dummy = blockAverage((theta[start:end]),3)  
theta_avr = average*np.ones(end - start)
errortheta_s11[n] = dummy

average, dummy = blockAverage((rbase[start:end]),3)
rbase_avr = average*np.ones(end - start)
errorr_base_s11[n] = dummy
t_avr = t[start:end]

theta_s11[n]=theta_avr[0] 
rbase_s11[n]=rbase_avr[0] 
print "theta_s11[n] = ", theta_s11[n]
print "rbase_s11[n] = ",rbase_s11[n]


#PLOT FOR CONTACT ANGLE OF SAM 11% & 4000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 158, 'SAM 11%, Water 4000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 100, 170])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 4000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 1.0, 'SAM 11%, Water 4000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 0.5, 3.6])
pylab.savefig(namebaserad)
plt.show()
# Out:
# start of bestblock =  61
# smallest average =  0.0436727501423
# theta_s11[n] =  119.734827914
# rbase_s11[n] =  2.84079394386

# %%
n=4
b=11
c=5000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=20
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
end = m
omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS
error = np.zeros(end-omit-1)
average = np.zeros(end-omit-1)
error = error.tolist()
j=0
for i in range (omit, end-1):
    average[j],error[j] = blockAverage((theta[i:end]),3)    
    error[j] = sin(radians(average[j]))*error[j]   
    j = j+1
bestblock = error.index(min(error))
start = bestblock + omit

print "start of bestblock = " , (bestblock+omit)
print "smallest average = ", error[bestblock]
#print "error=", error

average, dummy = blockAverage((theta[start:end]),3)  
theta_avr = average*np.ones(end - start)
errortheta_s11[n] = dummy

average, dummy = blockAverage((rbase[start:end]),3)
rbase_avr = average*np.ones(end - start)
errorr_base_s11[n] = dummy
t_avr = t[start:end]

theta_s11[n]=theta_avr[0] 
rbase_s11[n]=rbase_avr[0] 
print "theta_s11[n] = ", theta_s11[n]
print "rbase_s11[n] = ",rbase_s11[n]


#PLOT FOR CONTACT ANGLE OF SAM 11% & 5000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 180, 'SAM 11%, Water 5000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 100, 200])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 5000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 2.2, 'SAM 11%, Water 5000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 2.1, 3.3])
pylab.savefig(namebaserad)
plt.show()
# Out:
# start of bestblock =  69
# smallest average =  0.00899451728502
# theta_s11[n] =  123.481608752
# rbase_s11[n] =  2.89299563874

# %%
b=11
c=6500
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=50
end=80
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s11[4]=theta_avr[0] #CHANGE THESE 4 LINES ONCE THERE IS THE COMPLETE DATA OF SAM 11% WATER 2000
rbase_s11[4]=rbase_avr[0] 
print theta_s11[4]
print rbase_s11[4]


#PLOT FOR CONTACT ANGLE OF SAM 11% & 5000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 150, 'SAM 11%, Water 6500 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 40, 90, 130])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 5000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 1.0, 'SAM 11%, Water 6500 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 40, 2.5, 3.5])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 118.204466246
# 3.40829268094

# %%
b=11
c=7000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=80
end=120
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s11[5]=theta_avr[0] #CHANGE THESE 4 LINES ONCE THERE IS THE COMPLETE DATA OF SAM 11% WATER 2000
rbase_s11[5]=rbase_avr[0] 
print theta_s11[5]
print rbase_s11[5]


#PLOT FOR CONTACT ANGLE OF SAM 11% & 7000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 145, 'SAM 11%, Water 7000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 7000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 1.5, 'SAM 11%, Water 7000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 122.14001964
# 3.29755967254

# %%
b=11
c=8000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=80
end=120
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s11[6]=theta_avr[0] #CHANGE THESE 4 LINES ONCE THERE IS THE COMPLETE DATA OF SAM 11% WATER 2000
rbase_s11[6]=rbase_avr[0] 
print theta_s11[6]
print rbase_s11[6]


#PLOT FOR CONTACT ANGLE OF SAM 11% & 8000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 155, 'SAM 11%, Water 8000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 8000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 1, 'SAM 11%, Water 8000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 119.377280831
# 3.58242811893

# %%
b=11
c=9000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=60
end=80
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s11[7]=theta_avr[0] #CHANGE THESE 4 LINES ONCE THERE IS THE COMPLETE DATA OF SAM 11% WATER 2000
rbase_s11[7]=rbase_avr[0] 
print theta_s11[7]
print rbase_s11[7]


#PLOT FOR CONTACT ANGLE OF SAM 11% & 8000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 165, 'SAM 11%, Water 9000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 8000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 0.6, 'SAM 11%, Water 9000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 121.050159855
# 3.64992610325

# %%
b=11
c=10000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=80
end=160
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s11[8]=theta_avr[0] #CHANGE THESE 4 LINES ONCE THERE IS THE COMPLETE DATA OF SAM 11% WATER 2000
rbase_s11[8]=rbase_avr[0] 
print theta_s11[8]
print rbase_s11[8]


#PLOT FOR CONTACT ANGLE OF SAM 11% & 10000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(25, 155, 'SAM 11%, Water 10000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 10000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(25, 1.0, 'SAM 11%, Water 10000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 118.81494489
# 3.89505989969

# %%
b=17
c=1000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
#print theta
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=40
end=80
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s17[0]=theta_avr[0] 
rbase_s17[0]=rbase_avr[0] 
print theta_s17[0]
print rbase_s17[0]

#PLOT FOR CONTACT ANGLE OF SAM 17% & 1000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 125, 'SAM 17%, Water 1000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 1000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.4, 'SAM 17%, Water 1000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 109.576970237
# 2.06396752727

# %%
b=17
c=2000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
#print theta
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=50
end=80
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s17[1]=theta_avr[0] 
rbase_s17[1]=rbase_avr[0] 
print theta_s17[1]
print rbase_s17[1]


#PLOT FOR CONTACT ANGLE OF SAM 17% & 2000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 123, 'SAM 17%, Water 2000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 2000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.95, 'SAM 17%, Water 2000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 1.8, 3.0])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 108.602581669
# 2.60859416874

# %%
b=17
c=3000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=50
end=80
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s17[2]=theta_avr[0] 
rbase_s17[2]=rbase_avr[0] 
print theta_s17[2]
print rbase_s17[2]


#PLOT FOR CONTACT ANGLE OF SAM 17% & 3000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 160, 'SAM 17%, Water 3000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 90, 180])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 3000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.2, 'SAM 17%, Water 3000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 1.0, 3.5])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 107.890296048
# 2.97603921281

# %%
b=17
c=4000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=24
end=80
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s17[3]=theta_avr[0] 
rbase_s17[3]=rbase_avr[0] 
print theta_s17[3]
print rbase_s17[3]

#PLOT FOR CONTACT ANGLE OF SAM 17% & 4000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 140, 'SAM 17%, Water 4000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 90, 150])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 4000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.9, 'SAM 17%, Water 4000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 1.5, 4])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 106.982871388
# 3.31274460454

# %%
b=17
c=5000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=30
end=80
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s17[4]=theta_avr[0] 
rbase_s17[4]=rbase_avr[0] 
print theta_s17[4]
print rbase_s17[4]

#PLOT FOR CONTACT ANGLE OF SAM 17% & 5000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 160, 'SAM 17%, Water 5000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 90, 175])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 5000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 2.4, 'SAM 17%, Water 5000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 2.2, 3.8])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 107.990180687
# 3.5198947721

# %%
b=17
c=6500
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=40
end=120
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s17[5]=theta_avr[0] 
rbase_s17[5]=rbase_avr[0] 
print theta_s17[5]
print rbase_s17[5]

#PLOT FOR CONTACT ANGLE OF SAM 17% & 6500 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 190, 'SAM 17%, Water 6500 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 60, 90, 220])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 6500 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 3.1, 'SAM 17%, Water 6500 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 60, 3.0, 4.0])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 110.287754561
# 3.75007797699

# %%
b=17
c=7000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=80
end=120
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s17[6]=theta_avr[0] 
rbase_s17[6]=rbase_avr[0] 
print theta_s17[6]
print rbase_s17[6]

#PLOT FOR CONTACT ANGLE OF SAM 17% & 7000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 150, 'SAM 17%, Water 7000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 60, 90, 170])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 7000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 3.2, 'SAM 17%, Water 7000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 60, 3, 4.2])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 108.72066436
# 3.89957392676

# %%
b=17
c=8000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=80
end=120
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s17[7]=theta_avr[0] 
rbase_s17[7]=rbase_avr[0] 
print theta_s17[7]
print rbase_s17[7]

#PLOT FOR CONTACT ANGLE OF SAM 17% & 8000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(25, 160, 'SAM 17%, Water 8000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 60, 90, 180])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 8000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(25, 1, 'SAM 17%, Water 8000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 60, 0.5, 5.0])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 107.522059725
# 4.13236814995

# %%
b=17
c=9000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=100
end=120
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s17[8]=theta_avr[0] 
rbase_s17[8]=rbase_avr[0] 
print theta_s17[8]
print rbase_s17[8]

#PLOT FOR CONTACT ANGLE OF SAM 17% & 9000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(25, 160, 'SAM 17%, Water 9000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 60, 90, 180])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 9000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(25, 1, 'SAM 17%, Water 9000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 60, 0.5, 5.0])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 107.366723902
# 4.31642151431

# %%
b=17
c=10000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

start=100
end=160
theta_avr = np.mean(theta[start:end])*np.ones(end - start)
rbase_avr = np.mean(rbase[start:end])*np.ones(end - start)
t_avr = t[start:end]

theta_s17[9]=theta_avr[0] 
rbase_s17[9]=rbase_avr[0] 
print theta_s17[9]
print rbase_s17[9]

#PLOT FOR CONTACT ANGLE OF SAM 17% & 10000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(25, 155, 'SAM 17%, Water 10000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 80, 90, 170])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 10000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(25, 1.5, 'SAM 17%, Water 10000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 80, 1.0, 5.3])
pylab.savefig(namebaserad)
plt.show()
# Out:
# 105.861758938
# 4.53906756757

# %%
def func(x, a, b):
    return a*x + b

# %%
d = 0
namethetabaserad = "theta_r_s%s.png" % (d)
    
x = 1/rbase_s0
y = cos((theta_s0/180)*np.pi)

popt, pcov = curve_fit(func, x, y)
print "Line equation: a*x+b with a=", popt[0], "and b=", popt[1]
theta_results[0] = math.degrees(np.arccos(popt[1]))
sigma[0] = popt[0]*(-52.7)
print 'Theta =', theta_results[0]
print 'Sigma =', sigma[0]
txt = "$\Theta_{mac}$ = %s deg \n $\sigma$ = %s pN" % (int(theta_results[0]*100)/100.00,int(sigma[0]*100)/100.00)

#PLOT for SAM 0% (Also saved to file)
plt.plot(1/rbase_s0, cos(theta_s0/180*np.pi), 'ro')
plt.plot(x, func(x, popt[0], popt[1]))
plt.xlabel('${R \ _{BASE}}^{-1}\ [ nm ^{-1} ]$')
plt.ylabel(r' $\cos\Theta_{mic}$ ')
plt.suptitle(r'$\cos\Theta_{mic}$ vs. ${R \ _{BASE}}^{-1}$ for SAM 0%', fontsize=14)
plt.text(0.9, -0.85, txt ,style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 80, 3.4, 4.8])
pylab.savefig(namethetabaserad)
plt.show()
print x
print y
# Out:
# Line equation: a*x+b with a= -0.0592211334075 and b= -0.806801534247
# Theta = 143.784599482
# Sigma = 3.12095373058
# [ 1.02195796  0.77120539  0.66964085  0.59569771  0.55869728  0.49900751
#   0.48491727  0.46622925  0.4514459   0.4335264 ]
# [-0.86880451 -0.85135248 -0.84581721 -0.83967864 -0.84229262 -0.83448983
#  -0.8320728  -0.83378939 -0.83721777 -0.83500356]

# %%
d = 5
namethetabaserad = "theta_r_s%s.png" % (d)
    
x = 1/rbase_s5
y = cos((theta_s5/180)*np.pi)

popt, pcov = curve_fit(func, x, y)
print "Line equation: a*x+b with a=", popt[0], "and b=", popt[1]
theta_results[1] = math.degrees(np.arccos(popt[1]))
sigma[1] = popt[0]*(-52.7)
print 'Theta =', theta_results[1]
print 'Sigma =', sigma[1]
txt = "$\Theta_{mac}$ = %s deg \n $\sigma$ = %s pN" % (int(theta_results[1]*100)/100.00,int(sigma[1]*100)/100.00)

#PLOT for SAM 5% (Also saved to file)
plt.plot(1/rbase_s5, cos(theta_s5/180*np.pi), 'ro')
plt.plot(x, func(x, popt[0], popt[1]))
plt.xlabel('${R \ _{BASE}}^{-1}\ [ nm ^{-1} ]$')
plt.ylabel(r' $\cos\Theta_{mic}$ ')
plt.suptitle(r'$\cos\Theta_{mic} $ vs. $ {R \ _{BASE}}^{-1} $ for SAM 5%', fontsize=14)
plt.text(0.75, -0.75, txt ,style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
#plt.annotate("$\Theta$ = %s $\Sigma$ = %s" % (theta_results[1],sigma[1]), xy=(0.55, -0.64),  xycoords='data', xytext=(-110, -90), textcoords='offset points',size=15,bbox=dict(boxstyle="round4,pad=.5", fc="0.8"),arrowprops=dict(arrowstyle="->",connectionstyle="angle,angleA=0,angleB=-90,rad=25"),)
plt.grid(True)
#plt.axis([0, 80, 3.4, 4.8])
pylab.savefig(namethetabaserad)
plt.show()
print x
print y
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-3bff88e62686> in <module>()
#       5 y = cos((theta_s5/180)*np.pi)
#       6
# ----> 7 popt, pcov = curve_fit(func, x, y)
#       8 print "Line equation: a*x+b with a=", popt[0], "and b=", popt[1]
#       9 theta_results[1] = math.degrees(np.arccos(popt[1]))
#
# /usr/lib/python2.7/dist-packages/scipy/optimize/minpack.pyc in curve_fit(f, xdata, ydata, p0, sigma, **kw)
#     432     # Remove full_output from kw, otherwise we're passing it in twice.
#     433     return_full = kw.pop('full_output', False)
# --> 434     res = leastsq(func, p0, args=args, full_output=1, **kw)
#     435     (popt, pcov, infodict, errmsg, ier) = res
#     436
#
# /usr/lib/python2.7/dist-packages/scipy/optimize/minpack.pyc in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     336             R = dot(r, perm)
#     337             try:
# --> 338                 cov_x = inv(dot(transpose(R),R))
#     339             except LinAlgError:
#     340                 pass
#
# /usr/lib/python2.7/dist-packages/scipy/linalg/basic.pyc in inv(a, overwrite_a)
#     285
#     286     """
# --> 287     a1 = np.asarray_chkfinite(a)
#     288     if len(a1.shape) != 2 or a1.shape[0] != a1.shape[1]:
#     289         raise ValueError('expected square matrix')
#
# /usr/lib/pymodules/python2.7/numpy/lib/function_base.pyc in asarray_chkfinite(a)
#     588            and (_nx.isnan(a).any() or _nx.isinf(a).any()):
#     589         raise ValueError(
# --> 590                 "array must not contain infs or NaNs")
#     591     return a
#     592
#
# ValueError: array must not contain infs or NaNs
# -c:4: RuntimeWarning: divide by zero encountered in divide

# %%
d = 11
namethetabaserad = "theta_r_s%s.png" % (d)
    
x = 1/rbase_s11
y = cos((theta_s11/180)*np.pi)

popt, pcov = curve_fit(func, x, y)
print "Line equation: a*x+b with a=", popt[0], "and b=", popt[1]
theta_results[2] = math.degrees(np.arccos(popt[1]))
sigma[2] = popt[0]*(-52.7)
print 'Theta =', theta_results[2]
print 'Sigma =', sigma[2]
txt = "$\Theta_{mac}$ = %s deg \n $\sigma$ = %s pN" % (int(theta_results[2]*100)/100.00,int(sigma[2]*100)/100.00)

#PLOT for SAM 11% (Also saved to file)
plt.plot(1/rbase_s11, cos(theta_s11/180*np.pi), 'ro')
plt.plot(x, func(x, popt[0], popt[1]))
plt.xlabel('${R \ _{BASE}}^{-1}\ [ nm ^{-1} ]$')
plt.ylabel(r' $\cos\Theta_{mic}$ ')
plt.suptitle(r'$\cos\Theta_{mic}$ vs. ${R \ _{BASE}}^{-1}$ for SAM 11%', fontsize=14)
plt.text(0.45, -0.54, txt ,style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 80, 3.4, 4.8])
pylab.savefig(namethetabaserad) 
plt.show()
print x
print y

# %%
plt.plot(1/rbase_s17, cos((theta_s17/180)*np.pi), 'ro')

d = 17
namethetabaserad = "theta_r_s%s.png" % (d)
    
x = 1/rbase_s17
y = cos((theta_s17/180)*np.pi)

popt, pcov = curve_fit(func, x, y)
print "Line equation: a*x+b with a=", popt[0], "and b=", popt[1]
theta_results[3] = math.degrees(np.arccos(popt[1]))
sigma[3] = popt[0]*(-52.7)
print 'Theta =', theta_results[3]
print 'Sigma =', sigma[3]
txt = "$\Theta_{mac}$ = %s deg \n $\sigma$ = %s pN" % (int(theta_results[3]*100)/100.00,int(sigma[3]*100)/100.00)

#PLOT for SAM 17% (Also saved to file)
plt.plot(1/rbase_s17, cos(theta_s17/180*np.pi), 'ro')
plt.plot(x, func(x, popt[0], popt[1]))
plt.xlabel('${R \ _{BASE}}^{-1}\ [ nm ^{-1} ]$')
plt.ylabel(r' $\cos\Theta_{mic}$ ')
plt.suptitle(r'$\cos\Theta_{mic}$ vs. ${R \ _{BASE}}^{-1}$ for SAM 17%', fontsize=14)
plt.text(0.4, -0.295, txt ,style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 80, 3.4, 4.8])
pylab.savefig(namethetabaserad)
plt.show()
print x
print y

# %%
plt.plot(percentages, theta_results, 'ro')
plt.plot(percentages, theta_results)
plt.ylabel(r' Macrosc. Contact Angle $ \Theta_{mac}$ [deg] ')
plt.xlabel('OH- PERCENTAGE [%]')
plt.suptitle('Macroscopic Contact Angles vs. OH- Percentages' , fontsize=14, fontweight='bold')
plt.grid(True)
#plt.axis([0, 80, 3.4, 4.8])
pylab.savefig('C_Angles_OH.png')
plt.show()
print theta_results

# %%
plt.plot(percentages, sigma, 'ro', k)
plt.plot(percentages, sigma)
plt.ylabel(r' $\sigma $ [pN]')
plt.xlabel('OH- PERCENTAGE [%]')
plt.suptitle('Line Tension vs. OH- Percentages' , fontsize=14, fontweight='bold')
plt.grid(True)
#plt.axis([0, 80, 3.4, 4.8])
pylab.savefig('Sigma_OH.png')
plt.show()
print sigma

# %%
plt.plot([1,2,3], label="test1")
plt.plot([3,2,1], label="test2")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
print math.atan(0)
