# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
# %cd /media/BERT/Downloads/g_rad_densmaps
# Out:
# /media/BERT/Downloads/g_rad_densmaps

# %%
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np

# %%
# We save the data in the arrays "theta_all" and "rbase_all"
theta_all, rbase_all = np.loadtxt('Contact_Angles2.txt', skiprows=2, usecols = (0,1),unpack=True)

# %%
# Here we create two dictionaries named "angles" and "radii". Each dictionary consists of a set of "key: value" pairs, each one corresponding to a different system. The keys are (also) a pair of numbers "b, c".
# "b" refers to the OH-coverage percentage of the SAM, and "c" to the number of water molecules of the droplet. For example, the key "5, 1000" refers to the system with a surface with 5% OH-coverage, 
# and a droplet with 1000 water molecules. The value corresponding to each key is an array with the 40 calculated angles/base radii, that belong to that system. For example: "radii[(11, 3000)]" would give back
# the array with the 40 calculated values of the base radii corresponding to the system with a surface with 11% OH-coverage, and a droplet with 3000 water molecules.
angles={}
radii={}
k = 0
for b in [0, 5, 17]:
    for c in [1000, 2000, 3000, 4000, 5000, 6500, 7000, 8000, 9000, 10000]:
        z = b, c
        m = 0
        th = [0] * 40
        r = [0] * 40
        i=k*40
        j=(k+1)*40
        for l in range(i,j):
            th[m]=theta_all[l]
            r[m]=rbase_all[l]
            m = m +1
        angles[z] = th
        radii[z] = r
        k=k+1

#We choose a system and substitute the values "b" and "c" to save the corresponding angle and radii values in two arrays named, respectively, "theta" and "rbase".
#b=0
#c=4000
#theta = array(angles[(b, c)])
#rbase = array(radii[(b, c)])
#print "theta=", theta
#print "rbase=", rbase
#print theta[0]

# %%
# The data of the SAM with 11% OH-coverage gets handled separately, because there are still some simulations missing. We save the data in the arrays "theta_all11" and "rbase_all11"
theta_all11, rbase_all11 = np.loadtxt('Contact_Angles2_s11.txt', skiprows=2, usecols = (0,1),unpack=True)

# %%
# DICTIONARIES FOR SAM 11% (MODIFIED CELL COPY)
# Here we create two dictionaries named "angles11" and "radii11". Each dictionary consists of a set of "key: value" pairs, each one corresponding to a different system. The keys are (also) a pair of numbers "b, c".
# "b" refers to the OH-coverage percentage of the SAM, and "c" to the number of water molecules of the droplet. For example, the key "5, 1000" refers to the system with a surface with 5% OH-coverage, 
# and a droplet with 1000 water molecules. The value corresponding to each key is an array with the 40 calculated angles/base radii, that belong to that system. For example: "radii[(11, 3000)]" would give back
# the array with the 40 calculated values of the base radii corresponding to the system with a surface with 11% OH-coverage, and a droplet with 3000 water molecules.
angles11={}
radii11={}
k = 0
for b in [11]:
    for c in [1000, 2000, 3000, 4000, 5000, 7000, 8000, 10000]:
        z = b, c
        m = 0
        t11 = [0] * 40
        r11 = [0] * 40
        i=k*40
        j=(k+1)*40
        for l in range(i,j):
            t11[m]=theta_all11[l]
            r11[m]=rbase_all11[l]
            m = m +1
        angles11[z] = t11
        radii11[z] = r11
        k=k+1

#We choose a system and substitute the values "b" and "c" to save the corresponding angle and radii values in two arrays named, respectively, "theta" and "rbase".
#b=11
#c=4000
#theta11 = array(angles11[(b, c)])
#rbase11 = array(radii11[(b, c)])
#print "theta11=", theta11
#print "rbase11=", rbase11
#print theta11[0]

# %%
# This function allows to use ranges, just as the built-in function range(), but with float arguments.
# Taken from "http://code.activestate.com/recipes/66472-frange-a-range-function-with-float-increments/"
def frange(start, end=None, inc=None):
    if end == None:
        end = start + 0.0
        start = 0.0

    if inc == None:
        inc = 1.0

    L = []
    while 1:
        next = start + len(L) * inc
        if inc > 0 and next >= end:
            break
        elif inc < 0 and next <= end:
            break
        L.append(next)
    return L

# %%
# We create an array named "t" with the time values.
t = np.zeros(40)
i=0
for d in frange(0, 20, 0.5):
    t[i] = d
    i = i + 1

# %%
b=0
c=1000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 0% & 1000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 136, 'SAM 0%, Water 1000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 1000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.4, 'SAM 0%, Water 1000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=0
c=2000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 0% & 2000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 172, 'SAM 0%, Water 2000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 2000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 0.2, 'SAM 0%, Water 2000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=0
c=3000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 0% & 3000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 162, 'SAM 0%, Water 3000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 3000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1, 'SAM 0%, Water 3000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=0
c=4000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 0% & 4000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 155, 'SAM 0%, Water 4000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 4000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.1, 'SAM 0%, Water 4000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=0
c=5000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 0% & 5000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 152, 'SAM 0%, Water 5000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 5000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.5, 'SAM 0%, Water 5000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=0
c=6500
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 0% & 6500 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 154, 'SAM 0%, Water 6500 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 6500 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.6, 'SAM 0%, Water 6500 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=0
c=7000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 0% & 7000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 157, 'SAM 0%, Water 7000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 7000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.3, 'SAM 0%, Water 7000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=0
c=8000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 0% & 8000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 152, 'SAM 0%, Water 8000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 8000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.7, 'SAM 0%, Water 8000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=0
c=9000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 0% & 9000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 153, 'SAM 0%, Water 9000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 9000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.85, 'SAM 0%, Water 9000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=0
c=10000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 0% & 10000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 153, 'SAM 0%, Water 10000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 10000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.8, 'SAM 0%, Water 10000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=5
c=1000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 5% & 1000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 145, 'SAM 5%, Water 1000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 100, 150])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 1000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.4, 'SAM 5%, Water 1000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 1.3, 2.1])
pylab.savefig(namebaserad)
plt.show()

# %%
b=5
c=2000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 5% & 2000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 150, 'SAM 5%, Water 2000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 115, 155])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 2000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.2, 'SAM 5%, Water 2000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=5
c=3000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 5% & 3000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 155, 'SAM 5%, Water 3000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 3000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.0, 'SAM 5%, Water 3000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=5
c=4000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 5% & 4000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 155, 'SAM 5%, Water 4000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 4000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.2, 'SAM 5%, Water 4000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=5
c=5000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 5% & 5000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 148, 'SAM 5%, Water 5000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 5000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.7, 'SAM 5%, Water 5000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=5
c=6500
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 5% & 6500 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 148, 'SAM 5%, Water 6500 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 6500 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.9, 'SAM 5%, Water 6500 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=5
c=7000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 5% & 7000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 151, 'SAM 5%, Water 7000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 7000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.8, 'SAM 5%, Water 7000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=5
c=8000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 5% & 9000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 152, 'SAM 5%, Water 8000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 9000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.9, 'SAM 5%, Water 8000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()b=5
c=8000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 5% & 9000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 152, 'SAM 5%, Water 8000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 9000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.9, 'SAM 5%, Water 8000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=5
c=9000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 5% & 9000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 152, 'SAM 5%, Water 9000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 9000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.9, 'SAM 5%, Water 9000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=5
c=10000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 5% & 10000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 152, 'SAM 5%, Water 10000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 10000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 2.0, 'SAM 5%, Water 10000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=11
c=1000
theta = array(angles11[(b, c)])
rbase = array(radii11[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 11% & 1000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 150, 'SAM 11%, Water 1000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 80, 160])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 1000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 1.5, 'SAM 11%, Water 1000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 1.4, 2.4])
pylab.savefig(namebaserad)
plt.show()

# %%
b=11
c=2000
theta = array(angles11[(b, c)])
rbase = array(radii11[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 11% & 2000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 155, 'SAM 11%, Water 2000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 2000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 0.5, 'SAM 11%, Water 2000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=11
c=3000
theta = array(angles11[(b, c)])
rbase = array(radii11[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 11% & 3000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 150, 'SAM 11%, Water 3000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 3000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 0.7, 'SAM 11%, Water 3000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=11
c=4000
theta = array(angles11[(b, c)])
rbase = array(radii11[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 11% & 4000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 142, 'SAM 11%, Water 4000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 4000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 1.7, 'SAM 11%, Water 4000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=11
c=5000
theta = array(angles11[(b, c)])
rbase = array(radii11[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 11% & 5000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 160, 'SAM 11%, Water 5000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 5000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 0.7, 'SAM 11%, Water 5000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=11
c=7000
theta = array(angles11[(b, c)])
rbase = array(radii11[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 11% & 7000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 155, 'SAM 11%, Water 7000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 7000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 1.2, 'SAM 11%, Water 7000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=11
c=8000
theta = array(angles11[(b, c)])
rbase = array(radii11[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 11% & 8000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 160, 'SAM 11%, Water 8000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 8000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 0.9, 'SAM 11%, Water 8000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=11
c=10000
theta = array(angles11[(b, c)])
rbase = array(radii11[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 11% & 10000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 162, 'SAM 11%, Water 10000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 10000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 0.8, 'SAM 11%, Water 10000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=17
c=1000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 17% & 1000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 125, 'SAM 17%, Water 1000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 1000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.6, 'SAM 17%, Water 1000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=17
c=2000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 17% & 2000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 115, 'SAM 17%, Water 2000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 2000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 2.2, 'SAM 17%, Water 2000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=17
c=3000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 17% & 3000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 150, 'SAM 17%, Water 3000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 3000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.4, 'SAM 17%, Water 3000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=17
c=4000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 17% & 4000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 150, 'SAM 17%, Water 4000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 4000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 0.9, 'SAM 17%, Water 4000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=17
c=5000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 17% & 5000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 150, 'SAM 17%, Water 5000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 5000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.9, 'SAM 17%, Water 5000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=17
c=6500
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 17% & 6500 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 160, 'SAM 17%, Water 6500 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 6500 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1, 'SAM 17%, Water 6500 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=17
c=7000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 17% & 7000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 161, 'SAM 17%, Water 7000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 7000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 0.9, 'SAM 17%, Water 7000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=17
c=8000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 17% & 8000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 170, 'SAM 17%, Water 8000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 8000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1, 'SAM 17%, Water 8000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=17
c=9000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 17% & 9000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 170, 'SAM 17%, Water 9000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 9000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1, 'SAM 17%, Water 9000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=17
c=10000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 17% & 10000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 165, 'SAM 17%, Water 10000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 10000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.4, 'SAM 17%, Water 10000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
