# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#%cd /home/eixeres/Downloads/g_rad_densmaps_p2
# %cd /Users/burbol/Downloads/g_rad_densmaps_p2
# Out:
# /Users/burbol/Downloads/g_rad_densmaps_p2

# %%
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np

# %%
# We save the data in the arrays "theta_all" and "rbase_all"
theta_all, rbase_all = np.loadtxt('Contact_Angles2_p2_BIG.txt', skiprows=2, usecols = (0,1),unpack=True)

# %%
print len(theta_all), len(rbase_all)
print range(0,4)
# Out:
# 600 600
# [0, 1, 2, 3]

# %%
# Here we create two dictionaries named "angles" and "radii". Each dictionary consists of a set of "key: value" pairs, each one corresponding to a different system. The keys are (also) a pair of numbers "b, c".
# "b" refers to the OH-coverage percentage of the SAM, and "c" to the number of water molecules of the droplet. For example, the key "5, 1000" refers to the system with a surface with 5% OH-coverage, 
# and a droplet with 1000 water molecules. The value corresponding to each key is an array with the 40 calculated angles/base radii, that belong to that system. For example: "radii[(11, 3000)]" would give back
# the array with the 40 calculated values of the base radii corresponding to the system with a surface with 11% OH-coverage, and a droplet with 3000 water molecules.
angles={}
radii={}
k = 0
for b in [0, 5, 17]:
    for c in [6500, 7000, 8000, 9000, 10000]:
        z = b, c
        m = 0
        th = [0] * 40
        r = [0] * 40
        i=k*40
        j=(k+1)*40
        for l in range(i,j):
            th[m]=theta_all[l]
            r[m]=rbase_all[l]
            m = m +1
        angles[z] = th
        radii[z] = r
        k=k+1

#We choose a system and substitute the values "b" and "c" to save the corresponding angle and radii values in two arrays named, respectively, "theta" and "rbase".
#b=0
#c=4000
#theta = array(angles[(b, c)])
#rbase = array(radii[(b, c)])
#print "theta=", theta
#print "rbase=", rbase
#print theta[0]

# %%
# The data of the SAM with 11% OH-coverage gets handled separately, because there are still some simulations missing. We save the data in the arrays "theta_all11" and "rbase_all11"
theta_all11, rbase_all11 = np.loadtxt('Contact_Angles2_s11__p2__BIG.txt', skiprows=2, usecols = (0,1),unpack=True)

# %%
# DICTIONARIES FOR SAM 11% (MODIFIED CELL COPY)
# Here we create two dictionaries named "angles11" and "radii11". Each dictionary consists of a set of "key: value" pairs, each one corresponding to a different system. The keys are (also) a pair of numbers "b, c".
# "b" refers to the OH-coverage percentage of the SAM, and "c" to the number of water molecules of the droplet. For example, the key "5, 1000" refers to the system with a surface with 5% OH-coverage, 
# and a droplet with 1000 water molecules. The value corresponding to each key is an array with the 40 calculated angles/base radii, that belong to that system. For example: "radii[(11, 3000)]" would give back
# the array with the 40 calculated values of the base radii corresponding to the system with a surface with 11% OH-coverage, and a droplet with 3000 water molecules.
#angles11={}
#radii11={}
k = 0
for b in [11]:
    for c in [5000, 7000, 8000, 10000]:
        z = b, c
        m = 0
        t11 = [0] * 40
        r11 = [0] * 40
        i=k*40
        j=(k+1)*40
        for l in range(i,j):
            t11[m]=theta_all11[l]
            r11[m]=rbase_all11[l]
            m = m +1
#        angles11[z] = t11 THESE 2 LINES HAVE BEEN SUBSTITUTED BY THE FOLLOWING TWO.
#        radii11[z] = r11
        angles[z] = t11
        radii[z] = r11
        k=k+1

#We choose a system and substitute the values "b" and "c" to save the corresponding angle and radii values in two arrays named, respectively, "theta" and "rbase".
#b=11
#c=4000
#theta11 = array(angles11[(b, c)])
#rbase11 = array(radii11[(b, c)])
#print "theta11=", theta11
#print "rbase11=", rbase11
#print theta11[0]

# %%
# We save the data in the arrays "theta_all" and "rbase_all"
theta_all_s, rbase_all_s = np.loadtxt('Contact_Angles2_p2_SMALL.txt', skiprows=2, usecols = (0,1),unpack=True)
print len(theta_all_s)
# Out:
# 640

# %%
# Here we create two dictionaries named "angles" and "radii". Each dictionary consists of a set of "key: value" pairs, each one corresponding to a different system. The keys are (also) a pair of numbers "b, c".
# "b" refers to the OH-coverage percentage of the SAM, and "c" to the number of water molecules of the droplet. For example, the key "5, 1000" refers to the system with a surface with 5% OH-coverage, 
# and a droplet with 1000 water molecules. The value corresponding to each key is an array with the 40 calculated angles/base radii, that belong to that system. For example: "radii[(11, 3000)]" would give back
# the array with the 40 calculated values of the base radii corresponding to the system with a surface with 11% OH-coverage, and a droplet with 3000 water molecules.
#angles={}
#radii={}
k = 0
for b in [0, 5, 11, 17]:
    for c in [1000, 2000, 3000, 4000]:
        z = b, c
        m = 0
        th = [0] * 40
        r = [0] * 40
        i=k*40
        j=(k+1)*40
        for l in range(i,j):
            th[m]=theta_all_s[l]
            r[m]=rbase_all_s[l]
            m = m +1
        angles[z] = th
        radii[z] = r
        k=k+1

#We choose a system and substitute the values "b" and "c" to save the corresponding angle and radii values in two arrays named, respectively, "theta" and "rbase".
#b=0
#c=4000
#theta = array(angles[(b, c)])
#rbase = array(radii[(b, c)])
#print "theta=", theta
#print "rbase=", rbase
#print theta[0]

# %%
# We save the data in the arrays "theta_all" and "rbase_all"
theta_all_5b, rbase_all_5b = np.loadtxt('Contact_Angles2_p2_5000b.txt', skiprows=2, usecols = (0,1),unpack=True)

# %%
# Here we create two dictionaries named "angles" and "radii". Each dictionary consists of a set of "key: value" pairs, each one corresponding to a different system. The keys are (also) a pair of numbers "b, c".
# "b" refers to the OH-coverage percentage of the SAM, and "c" to the number of water molecules of the droplet. For example, the key "5, 1000" refers to the system with a surface with 5% OH-coverage, 
# and a droplet with 1000 water molecules. The value corresponding to each key is an array with the 40 calculated angles/base radii, that belong to that system. For example: "radii[(11, 3000)]" would give back
# the array with the 40 calculated values of the base radii corresponding to the system with a surface with 11% OH-coverage, and a droplet with 3000 water molecules.
#angles={}
#radii={}
k = 0
for b in [0, 5, 17]:
    for c in [5000]:
        z = b, c
        m = 0
        th = [0] * 40
        r = [0] * 40
        i=k*40
        j=(k+1)*40
        for l in range(i,j):
            th[m]=theta_all_5b[l]
            r[m]=rbase_all_5b[l]
            m = m +1
        angles[z] = th
        radii[z] = r
        k=k+1

#We choose a system and substitute the values "b" and "c" to save the corresponding angle and radii values in two arrays named, respectively, "theta" and "rbase".
#b=0
#c=4000
#theta = array(angles[(b, c)])
#rbase = array(radii[(b, c)])
#print "theta=", theta
#print "rbase=", rbase
#print theta[0]

# %%
# This function allows to use ranges, just as the built-in function range(), but with float arguments.
# Taken from "http://code.activestate.com/recipes/66472-frange-a-range-function-with-float-increments/"
def frange(start, end=None, inc=None):
    if end == None:
        end = start + 0.0
        start = 0.0

    if inc == None:
        inc = 1.0

    L = []
    while 1:
        next = start + len(L) * inc
        if inc > 0 and next >= end:
            break
        elif inc < 0 and next <= end:
            break
        L.append(next)
    return L

# %%
# We create an array named "t" with the time values.
t = np.zeros(40)
i=0
for d in frange(0, 20, 0.5):
    t[i] = d
    i = i + 1

# %%
b=0
c=1000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 0% & 1000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 140, 'SAM 0%, Water 1000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 85, 150])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 1000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 0.3, 'SAM 0%, Water 1000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 0, 2])
pylab.savefig(namebaserad)
plt.show()

# %%
b=0
c=2000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 0% & 2000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 127, 'SAM 0%, Water 2000 molec.',style='italic',bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 2000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.97, 'SAM 0%, Water 2000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=0
c=3000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 0% & 3000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 129, 'SAM 0%, Water 3000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 3000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 2.2, 'SAM 0%, Water 3000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=0
c=4000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 0% & 4000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 127, 'SAM 0%, Water 4000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 4000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 2.55, 'SAM 0%, Water 4000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=0
c=5000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 0% & 5000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 152, 'SAM 0%, Water 5000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 5000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.5, 'SAM 0%, Water 5000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=0
c=6500
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 0% & 6500 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 136.75, 'SAM 0%, Water 6500 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 6500 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 2.42, 'SAM 0%, Water 6500 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=0
c=7000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 0% & 7000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 139.5, 'SAM 0%, Water 7000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 7000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 2.4, 'SAM 0%, Water 7000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=0
c=8000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 0% & 8000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 139.5, 'SAM 0%, Water 8000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 8000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 2.52, 'SAM 0%, Water 8000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=0
c=9000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 0% & 9000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 141, 'SAM 0%, Water 9000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 9000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 2.52, 'SAM 0%, Water 9000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=0
c=10000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 0% & 10000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 142, 'SAM 0%, Water 10000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 10000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 2.54, 'SAM 0%, Water 10000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=5
c=1000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 5% & 1000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 145, 'SAM 5%, Water 1000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 100, 150])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 1000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.4, 'SAM 5%, Water 1000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 1.3, 2.1])
pylab.savefig(namebaserad)
plt.show()

# %%
b=5
c=2000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
print theta
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 5% & 2000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 145, 'SAM 5%, Water 2000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 2000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.2, 'SAM 5%, Water 2000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-07a86828c274> in <module>()
#      18 #plt.axis([0, 6, 0, 20])
#      19 pylab.savefig(nametheta)
# ---> 20 plt.show()
#      21
#      22 #PLOT FOR BASE RADIUS OF SAM 5% & 2000 WATER MOLECULES.(Also saved to file)
#
# /usr/lib/pymodules/python2.7/matplotlib/pyplot.pyc in show(*args, **kw)
#     137     """
#     138     global _show
# --> 139     _show(*args, **kw)
#     140
#     141
#
# /usr/lib/python2.7/dist-packages/IPython/zmq/pylab/backend_inline.pyc in show(close)
#     100     try:
#     101         for figure_manager in Gcf.get_all_fig_managers():
# --> 102             send_figure(figure_manager.canvas.figure)
#     103     finally:
#     104         show._to_draw = []
#
# /usr/lib/python2.7/dist-packages/IPython/zmq/pylab/backend_inline.pyc in send_figure(fig)
#     209     """
#     210     fmt = InlineBackend.instance().figure_format
# --> 211     data = print_figure(fig, fmt)
#     212     # print_figure will return None if there's nothing to draw:
#     213     if data is None:
#
# /usr/lib/python2.7/dist-packages/IPython/core/pylabtools.pyc in print_figure(fig, fmt)
#     102     try:
#     103         bytes_io = BytesIO()
# --> 104         fig.canvas.print_figure(bytes_io, format=fmt, bbox_inches='tight')
#     105         data = bytes_io.getvalue()
#     106     finally:
#
# /usr/lib/pymodules/python2.7/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2019                 orientation=orientation,
#    2020                 bbox_inches_restore=_bbox_inches_restore,
# -> 2021                 **kwargs)
#    2022         finally:
#    2023             if bbox_inches and restore_bbox:
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     467
#     468     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 469         FigureCanvasAgg.draw(self)
#     470         renderer = self.get_renderer()
#     471         original_dpi = renderer.dpi
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in draw(self)
#     414         if __debug__: verbose.report('FigureCanvasAgg.draw', 'debug-annoying')
#     415
# --> 416         self.renderer = self.get_renderer()
#     417         # acquire a lock on the shared font cache
#     418         RendererAgg.lock.acquire()
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in get_renderer(self)
#     433
#     434         if need_new_renderer:
# --> 435             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     436             self._lastKey = key
#     437         return self.renderer
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in __init__(self, width, height, dpi)
#      70         self.height = height
#      71         if __debug__: verbose.report('RendererAgg.__init__ width=%s, height=%s'%(width, height), 'debug-annoying')
# ---> 72         self._renderer = _RendererAgg(int(width), int(height), dpi, debug=False)
#      73         self._filter_renderers = []
#      74
#
# ValueError: width and height must each be below 32768
# [ nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan]

# %%
b=5
c=3000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 5% & 3000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 141, 'SAM 5%, Water 3000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 100, 150])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 3000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.9, 'SAM 5%, Water 3000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 1.8, 2.6])
pylab.savefig(namebaserad)
plt.show()

# %%
b=5
c=4000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
print rbase
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 5% & 4000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 150, 'SAM 5%, Water 4000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 110, 160])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 4000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 2.1, 'SAM 5%, Water 4000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 2.0, 3.0])
pylab.savefig(namebaserad)
plt.show()
# Out:
# [ 2.83528962  2.83025663  2.8204176   2.80804089         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan]

# %%
b=5
c=5000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 5% & 5000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 170, 'SAM 5%, Water 5000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 125, 180])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 5000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.6, 'SAM 5%, Water 5000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 1.5, 2.5])
pylab.savefig(namebaserad)
plt.show()

# %%
b=5
c=6500
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 5% & 6500 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 170, 'SAM 5%, Water 6500 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 120, 180])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 6500 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 2.1, 'SAM 5%, Water 6500 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 2, 3])
pylab.savefig(namebaserad)
plt.show()

# %%
b=5
c=7000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 5% & 7000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 130, 'SAM 5%, Water 7000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 7000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 2.85, 'SAM 5%, Water 7000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=5
c=8000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 5% & 9000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 131.5, 'SAM 5%, Water 8000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 9000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 2.94, 'SAM 5%, Water 8000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=5
c=9000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 5% & 9000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 132.5, 'SAM 5%, Water 9000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 9000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 3.0, 'SAM 5%, Water 9000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=5
c=10000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 5% & 10000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 134, 'SAM 5%, Water 10000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 10000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 3.04, 'SAM 5%, Water 10000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=11
c=1000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
print theta
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 11% & 1000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 117, 'SAM 11%, Water 1000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 1000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 1.75, 'SAM 11%, Water 1000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-50e7e050e39a> in <module>()
#      18 #plt.axis([0, 6, 0, 20])
#      19 pylab.savefig(nametheta)
# ---> 20 plt.show()
#      21
#      22 #PLOT FOR BASE RADIUS OF SAM 11% & 1000 WATER MOLECULES.(Also saved to file)
#
# /usr/lib/pymodules/python2.7/matplotlib/pyplot.pyc in show(*args, **kw)
#     137     """
#     138     global _show
# --> 139     _show(*args, **kw)
#     140
#     141
#
# /usr/lib/python2.7/dist-packages/IPython/zmq/pylab/backend_inline.pyc in show(close)
#     100     try:
#     101         for figure_manager in Gcf.get_all_fig_managers():
# --> 102             send_figure(figure_manager.canvas.figure)
#     103     finally:
#     104         show._to_draw = []
#
# /usr/lib/python2.7/dist-packages/IPython/zmq/pylab/backend_inline.pyc in send_figure(fig)
#     209     """
#     210     fmt = InlineBackend.instance().figure_format
# --> 211     data = print_figure(fig, fmt)
#     212     # print_figure will return None if there's nothing to draw:
#     213     if data is None:
#
# /usr/lib/python2.7/dist-packages/IPython/core/pylabtools.pyc in print_figure(fig, fmt)
#     102     try:
#     103         bytes_io = BytesIO()
# --> 104         fig.canvas.print_figure(bytes_io, format=fmt, bbox_inches='tight')
#     105         data = bytes_io.getvalue()
#     106     finally:
#
# /usr/lib/pymodules/python2.7/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2019                 orientation=orientation,
#    2020                 bbox_inches_restore=_bbox_inches_restore,
# -> 2021                 **kwargs)
#    2022         finally:
#    2023             if bbox_inches and restore_bbox:
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     467
#     468     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 469         FigureCanvasAgg.draw(self)
#     470         renderer = self.get_renderer()
#     471         original_dpi = renderer.dpi
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in draw(self)
#     414         if __debug__: verbose.report('FigureCanvasAgg.draw', 'debug-annoying')
#     415
# --> 416         self.renderer = self.get_renderer()
#     417         # acquire a lock on the shared font cache
#     418         RendererAgg.lock.acquire()
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in get_renderer(self)
#     433
#     434         if need_new_renderer:
# --> 435             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     436             self._lastKey = key
#     437         return self.renderer
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in __init__(self, width, height, dpi)
#      70         self.height = height
#      71         if __debug__: verbose.report('RendererAgg.__init__ width=%s, height=%s'%(width, height), 'debug-annoying')
# ---> 72         self._renderer = _RendererAgg(int(width), int(height), dpi, debug=False)
#      73         self._filter_renderers = []
#      74
#
# ValueError: width and height must each be below 32768
# [ nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan]

# %%
b=11
c=2000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 11% & 2000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 155, 'SAM 11%, Water 2000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 90, 170])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 2000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 0.5, 'SAM 11%, Water 2000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 0, 3])
pylab.savefig(namebaserad)
plt.show()

# %%
b=11
c=3000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
print theta
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 11% & 3000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 150, 'SAM 11%, Water 3000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 3000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 0.7, 'SAM 11%, Water 3000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-33e1b326be2d> in <module>()
#      18 #plt.axis([0, 6, 0, 20])
#      19 pylab.savefig(nametheta)
# ---> 20 plt.show()
#      21
#      22 #PLOT FOR BASE RADIUS OF SAM 11% & 3000 WATER MOLECULES.(Also saved to file)
#
# /usr/lib/pymodules/python2.7/matplotlib/pyplot.pyc in show(*args, **kw)
#     137     """
#     138     global _show
# --> 139     _show(*args, **kw)
#     140
#     141
#
# /usr/lib/python2.7/dist-packages/IPython/zmq/pylab/backend_inline.pyc in show(close)
#     100     try:
#     101         for figure_manager in Gcf.get_all_fig_managers():
# --> 102             send_figure(figure_manager.canvas.figure)
#     103     finally:
#     104         show._to_draw = []
#
# /usr/lib/python2.7/dist-packages/IPython/zmq/pylab/backend_inline.pyc in send_figure(fig)
#     209     """
#     210     fmt = InlineBackend.instance().figure_format
# --> 211     data = print_figure(fig, fmt)
#     212     # print_figure will return None if there's nothing to draw:
#     213     if data is None:
#
# /usr/lib/python2.7/dist-packages/IPython/core/pylabtools.pyc in print_figure(fig, fmt)
#     102     try:
#     103         bytes_io = BytesIO()
# --> 104         fig.canvas.print_figure(bytes_io, format=fmt, bbox_inches='tight')
#     105         data = bytes_io.getvalue()
#     106     finally:
#
# /usr/lib/pymodules/python2.7/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2019                 orientation=orientation,
#    2020                 bbox_inches_restore=_bbox_inches_restore,
# -> 2021                 **kwargs)
#    2022         finally:
#    2023             if bbox_inches and restore_bbox:
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     467
#     468     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 469         FigureCanvasAgg.draw(self)
#     470         renderer = self.get_renderer()
#     471         original_dpi = renderer.dpi
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in draw(self)
#     414         if __debug__: verbose.report('FigureCanvasAgg.draw', 'debug-annoying')
#     415
# --> 416         self.renderer = self.get_renderer()
#     417         # acquire a lock on the shared font cache
#     418         RendererAgg.lock.acquire()
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in get_renderer(self)
#     433
#     434         if need_new_renderer:
# --> 435             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     436             self._lastKey = key
#     437         return self.renderer
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in __init__(self, width, height, dpi)
#      70         self.height = height
#      71         if __debug__: verbose.report('RendererAgg.__init__ width=%s, height=%s'%(width, height), 'debug-annoying')
# ---> 72         self._renderer = _RendererAgg(int(width), int(height), dpi, debug=False)
#      73         self._filter_renderers = []
#      74
#
# ValueError: width and height must each be below 32768
# [ nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan]

# %%
b=11
c=4000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
print theta
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 11% & 4000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 142, 'SAM 11%, Water 4000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 4000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 1.7, 'SAM 11%, Water 4000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-5daeb801f506> in <module>()
#      18 #plt.axis([0, 6, 0, 20])
#      19 pylab.savefig(nametheta)
# ---> 20 plt.show()
#      21
#      22 #PLOT FOR BASE RADIUS OF SAM 11% & 4000 WATER MOLECULES.(Also saved to file)
#
# /usr/lib/pymodules/python2.7/matplotlib/pyplot.pyc in show(*args, **kw)
#     137     """
#     138     global _show
# --> 139     _show(*args, **kw)
#     140
#     141
#
# /usr/lib/python2.7/dist-packages/IPython/zmq/pylab/backend_inline.pyc in show(close)
#     100     try:
#     101         for figure_manager in Gcf.get_all_fig_managers():
# --> 102             send_figure(figure_manager.canvas.figure)
#     103     finally:
#     104         show._to_draw = []
#
# /usr/lib/python2.7/dist-packages/IPython/zmq/pylab/backend_inline.pyc in send_figure(fig)
#     209     """
#     210     fmt = InlineBackend.instance().figure_format
# --> 211     data = print_figure(fig, fmt)
#     212     # print_figure will return None if there's nothing to draw:
#     213     if data is None:
#
# /usr/lib/python2.7/dist-packages/IPython/core/pylabtools.pyc in print_figure(fig, fmt)
#     102     try:
#     103         bytes_io = BytesIO()
# --> 104         fig.canvas.print_figure(bytes_io, format=fmt, bbox_inches='tight')
#     105         data = bytes_io.getvalue()
#     106     finally:
#
# /usr/lib/pymodules/python2.7/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2019                 orientation=orientation,
#    2020                 bbox_inches_restore=_bbox_inches_restore,
# -> 2021                 **kwargs)
#    2022         finally:
#    2023             if bbox_inches and restore_bbox:
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     467
#     468     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 469         FigureCanvasAgg.draw(self)
#     470         renderer = self.get_renderer()
#     471         original_dpi = renderer.dpi
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in draw(self)
#     414         if __debug__: verbose.report('FigureCanvasAgg.draw', 'debug-annoying')
#     415
# --> 416         self.renderer = self.get_renderer()
#     417         # acquire a lock on the shared font cache
#     418         RendererAgg.lock.acquire()
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in get_renderer(self)
#     433
#     434         if need_new_renderer:
# --> 435             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     436             self._lastKey = key
#     437         return self.renderer
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in __init__(self, width, height, dpi)
#      70         self.height = height
#      71         if __debug__: verbose.report('RendererAgg.__init__ width=%s, height=%s'%(width, height), 'debug-annoying')
# ---> 72         self._renderer = _RendererAgg(int(width), int(height), dpi, debug=False)
#      73         self._filter_renderers = []
#      74
#
# ValueError: width and height must each be below 32768
# [ nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan]

# %%
b=11
c=5000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 11% & 5000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 95, 'SAM 11%, Water 5000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 90, 130])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 5000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 2.6, 'SAM 11%, Water 5000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 2.5, 3.5])
pylab.savefig(namebaserad)
plt.show()

# %%
b=11
c=7000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 11% & 7000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 121, 'SAM 11%, Water 7000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 7000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 3.3, 'SAM 11%, Water 7000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=11
c=8000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 11% & 8000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 119, 'SAM 11%, Water 8000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 8000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 3.53, 'SAM 11%, Water 8000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=11
c=10000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 11% & 10000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 124, 'SAM 11%, Water 10000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 10000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 3.6, 'SAM 11%, Water 10000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()

# %%
b=17
c=1000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
print theta
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 17% & 1000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 125, 'SAM 17%, Water 1000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 1000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.6, 'SAM 17%, Water 1000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-9c53bb148d1a> in <module>()
#      18 #plt.axis([0, 6, 0, 20])
#      19 pylab.savefig(nametheta)
# ---> 20 plt.show()
#      21
#      22 #PLOT FOR BASE RADIUS OF SAM 17% & 1000 WATER MOLECULES.(Also saved to file)
#
# /usr/lib/pymodules/python2.7/matplotlib/pyplot.pyc in show(*args, **kw)
#     137     """
#     138     global _show
# --> 139     _show(*args, **kw)
#     140
#     141
#
# /usr/lib/python2.7/dist-packages/IPython/zmq/pylab/backend_inline.pyc in show(close)
#     100     try:
#     101         for figure_manager in Gcf.get_all_fig_managers():
# --> 102             send_figure(figure_manager.canvas.figure)
#     103     finally:
#     104         show._to_draw = []
#
# /usr/lib/python2.7/dist-packages/IPython/zmq/pylab/backend_inline.pyc in send_figure(fig)
#     209     """
#     210     fmt = InlineBackend.instance().figure_format
# --> 211     data = print_figure(fig, fmt)
#     212     # print_figure will return None if there's nothing to draw:
#     213     if data is None:
#
# /usr/lib/python2.7/dist-packages/IPython/core/pylabtools.pyc in print_figure(fig, fmt)
#     102     try:
#     103         bytes_io = BytesIO()
# --> 104         fig.canvas.print_figure(bytes_io, format=fmt, bbox_inches='tight')
#     105         data = bytes_io.getvalue()
#     106     finally:
#
# /usr/lib/pymodules/python2.7/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2019                 orientation=orientation,
#    2020                 bbox_inches_restore=_bbox_inches_restore,
# -> 2021                 **kwargs)
#    2022         finally:
#    2023             if bbox_inches and restore_bbox:
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     467
#     468     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 469         FigureCanvasAgg.draw(self)
#     470         renderer = self.get_renderer()
#     471         original_dpi = renderer.dpi
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in draw(self)
#     414         if __debug__: verbose.report('FigureCanvasAgg.draw', 'debug-annoying')
#     415
# --> 416         self.renderer = self.get_renderer()
#     417         # acquire a lock on the shared font cache
#     418         RendererAgg.lock.acquire()
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in get_renderer(self)
#     433
#     434         if need_new_renderer:
# --> 435             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     436             self._lastKey = key
#     437         return self.renderer
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in __init__(self, width, height, dpi)
#      70         self.height = height
#      71         if __debug__: verbose.report('RendererAgg.__init__ width=%s, height=%s'%(width, height), 'debug-annoying')
# ---> 72         self._renderer = _RendererAgg(int(width), int(height), dpi, debug=False)
#      73         self._filter_renderers = []
#      74
#
# ValueError: width and height must each be below 32768
# [ nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan]

# %%
b=17
c=2000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
print theta
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 17% & 2000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 115, 'SAM 17%, Water 2000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 2000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 2.2, 'SAM 17%, Water 2000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-7f35f893c2f3> in <module>()
#      18 #plt.axis([0, 6, 0, 20])
#      19 pylab.savefig(nametheta)
# ---> 20 plt.show()
#      21
#      22 #PLOT FOR BASE RADIUS OF SAM 17% & 2000 WATER MOLECULES.(Also saved to file)
#
# /usr/lib/pymodules/python2.7/matplotlib/pyplot.pyc in show(*args, **kw)
#     137     """
#     138     global _show
# --> 139     _show(*args, **kw)
#     140
#     141
#
# /usr/lib/python2.7/dist-packages/IPython/zmq/pylab/backend_inline.pyc in show(close)
#     100     try:
#     101         for figure_manager in Gcf.get_all_fig_managers():
# --> 102             send_figure(figure_manager.canvas.figure)
#     103     finally:
#     104         show._to_draw = []
#
# /usr/lib/python2.7/dist-packages/IPython/zmq/pylab/backend_inline.pyc in send_figure(fig)
#     209     """
#     210     fmt = InlineBackend.instance().figure_format
# --> 211     data = print_figure(fig, fmt)
#     212     # print_figure will return None if there's nothing to draw:
#     213     if data is None:
#
# /usr/lib/python2.7/dist-packages/IPython/core/pylabtools.pyc in print_figure(fig, fmt)
#     102     try:
#     103         bytes_io = BytesIO()
# --> 104         fig.canvas.print_figure(bytes_io, format=fmt, bbox_inches='tight')
#     105         data = bytes_io.getvalue()
#     106     finally:
#
# /usr/lib/pymodules/python2.7/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2019                 orientation=orientation,
#    2020                 bbox_inches_restore=_bbox_inches_restore,
# -> 2021                 **kwargs)
#    2022         finally:
#    2023             if bbox_inches and restore_bbox:
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     467
#     468     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 469         FigureCanvasAgg.draw(self)
#     470         renderer = self.get_renderer()
#     471         original_dpi = renderer.dpi
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in draw(self)
#     414         if __debug__: verbose.report('FigureCanvasAgg.draw', 'debug-annoying')
#     415
# --> 416         self.renderer = self.get_renderer()
#     417         # acquire a lock on the shared font cache
#     418         RendererAgg.lock.acquire()
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in get_renderer(self)
#     433
#     434         if need_new_renderer:
# --> 435             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     436             self._lastKey = key
#     437         return self.renderer
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in __init__(self, width, height, dpi)
#      70         self.height = height
#      71         if __debug__: verbose.report('RendererAgg.__init__ width=%s, height=%s'%(width, height), 'debug-annoying')
# ---> 72         self._renderer = _RendererAgg(int(width), int(height), dpi, debug=False)
#      73         self._filter_renderers = []
#      74
#
# ValueError: width and height must each be below 32768
# [ nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan]

# %%
b=17
c=3000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 17% & 3000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 150, 'SAM 17%, Water 3000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 80, 170])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 3000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 2.2, 'SAM 17%, Water 3000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 1.5, 4])
pylab.savefig(namebaserad)
plt.show()

# %%
b=17
c=4000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 17% & 4000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 130, 'SAM 17%, Water 4000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 80, 140])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 4000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 3, 'SAM 17%, Water 4000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 2.5, 5])
pylab.savefig(namebaserad)
plt.show()

# %%
b=17
c=5000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 17% & 5000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 85, 'SAM 17%, Water 5000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 80, 110])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 5000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 4.2, 'SAM 17%, Water 5000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 3, 4.6])
pylab.savefig(namebaserad)
plt.show()

# %%
b=17
c=6500
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 17% & 6500 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 100, 'SAM 17%, Water 6500 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 80, 110])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 6500 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 4.2, 'SAM 17%, Water 6500 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 3, 4.6])
pylab.savefig(namebaserad)
plt.show()

# %%
b=17
c=7000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 17% & 7000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(9, 97, 'SAM 17%, Water 7000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 80, 110])
pylab.savefig(nametheta)
plt.show()
plt.axis([0, 20, 3, 4.6])
#PLOT FOR BASE RADIUS OF SAM 17% & 7000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(9, 4.2, 'SAM 17%, Water 7000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)

pylab.savefig(namebaserad)
plt.show()

# %%
b=17
c=8000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 17% & 8000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 83, 'SAM 17%, Water 8000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 80, 120])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 8000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 3.2, 'SAM 17%, Water 8000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 3, 4.6])
pylab.savefig(namebaserad)
plt.show()

# %%
b=17
c=9000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 17% & 9000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 95, 'SAM 17%, Water 9000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 90, 120])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 9000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 3.2, 'SAM 17%, Water 9000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 3, 4.6])
pylab.savefig(namebaserad)
plt.show()

# %%
b=17
c=10000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#PLOT FOR CONTACT ANGLE OF SAM 17% & 10000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta$ [deg]')
plt.suptitle(r'Contact Angle $\theta$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10, 114, 'SAM 17%, Water 10000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 90, 120])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 10000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10, 4.1, 'SAM 17%, Water 10000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 20, 3.4, 4.8])
pylab.savefig(namebaserad)
plt.show()
