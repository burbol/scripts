# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
import gromacs
gromacs.config.setup()
import matplotlib 
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import numpy as np
import os
import math
#import pylab as pl 
import gromacs.formats
from matplotlib.backends.backend_pdf import PdfPages
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
# Out:
# /home/eixeres/.local/lib/python2.7/site-packages/GromacsWrapper-0.3.2-py2.7.egg/gromacs/__init__.py:328: GromacsImportWarning: Some Gromacs commands were NOT found; maybe source GMXRC first? The following are missing:
# ['a_gridcalc', 'a_ri3dc', 'demux_pl', 'g_count', 'g_flux', 'g_pme_error', 'g_ri3dc', 'xplor2gmx_pl']

# %%
xvg = gromacs.formats.XVG()

# %%
os.chdir('/home/eixeres/Downloads/global_densmaps_together')

# %%
ticki=np.zeros(24)
for lm in range(0,24): 
    xm = lm*0.5   
    ticki[lm] = xm 
    
def plot_dens(x, y, filename, point):                   

    majorLocator   = MultipleLocator(1)
    majorFormatter = FormatStrFormatter('%d')
    minorLocator   = MultipleLocator(0.2)
  
#    fig = pl.figure()   
    fig, ax = plt.subplots()                        
    pl.plot(x, y, 'b-', x, y, 'k.')
    fig.suptitle(filename)
    # pl.plot(z, R, 'k.')
    #fig.set_xlim(0,4.0)
    #fig.set_ylim(0,3)                
    # fig = plt.gcf()
    plt.xticks(ticki)
#    plt.xticks(range(0,d_max_y,50))
    pl.xlim(0,12)
    pl.ylim(0,max(y))
    pl.xlabel('z [nm]')
    pl.ylabel('Density [kg/nm3]')
#    pl.grid(b=True, which='both', axis='both', color='r', linestyle='-', linewidth=0.5)
    # fig.set_size_inches(18.5,10.5)
    pl.annotate('first peak', xy=(point[0], point[1]),  xycoords='data', xytext=(-50, 30), textcoords='offset points', arrowprops=dict(arrowstyle="->"))

    ax.xaxis.set_major_locator(majorLocator)
    ax.xaxis.set_major_formatter(majorFormatter)

    #for the minor ticks, use no labels; default NullFormatter
    ax.xaxis.set_minor_locator(minorLocator)

    ax.xaxis.grid(True, which='minor')
    ax.yaxis.grid(True, which='major')

    pylab.savefig(test.png)
    plt.show()
    return fig

# %%
b=5
c=1000
filename = 'g_density_sam%d_water%d.xvg'%(b,c, ) 
xvg.read(filename)
input = xvg.array
x = input[0]
y = input[1]

# %%
#pp = PdfPages('/Users/burbol/Downloads/global_densmaps_together/g_density_together_s5_w1000.pdf')

# %%
# 1: last water peak; 2: middle point; 3: last SAM peak
zeropoint1 = [2.5, 8000]
#zeropoint2 =
#zeropoint3 =

# %%
#pylab.savefig(namethetabaserad)
#plt.show()
plot1 =  plot_dens(x, y, filename, zeropoint1)
#pp.savefig(plot1)
#pp.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-305112c06cf6> in <module>()
#       1 #pylab.savefig(namethetabaserad)
#       2 #plt.show()
# ----> 3 plot1 =  plot_dens(x, y, filename, zeropoint1)
#       4 #pp.savefig(plot1)
#       5 #pp.close()
#
# <ipython-input-7-c7822448d32f> in plot_dens(x, y, filename, point)
#      12 #    fig = pl.figure()
#      13     fig, ax = plt.subplots()
# ---> 14     pl.plot(x, y, 'b-', x, y, 'k.')
#      15     fig.suptitle(filename)
#      16     # pl.plot(z, R, 'k.')
#
# NameError: global name 'pl' is not defined

# %%
# 1: last water peak; 2: middle point; 3: last SAM peak
percentages = [0, 5, 11, 17, 66]
sigma1 =[ -8.74887461, -4.12340351, -24.01605397, -10.87687804, 0.0]
sigma2 = [-1.60082848, 2.77376016, -4.82101451, 6.84497087, 0.0]
sigma3 = [ 2.90920998, 7.39262922, -4.82101451,  6.84497019, 0.0]
theta_mac1= [ 143.54838301, 132.57467138,  123.10500018, 105.86919561, 0.0]
theta_mac2= [143.23075827, 132.53000163, 122.15550779, 105.73701235, 0.0]
theta_mac3= [ 144.11772802, 133.30092959, 122.15550779, 105.7370125, 0.0]

# %%
os.chdir('/Users/burbol/Downloads/Results_NEW_together')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-13-1e3bc762b024> in <module>()
# ----> 1 os.chdir('/Users/burbol/Downloads/Results_NEW_together')
#
# OSError: [Errno 2] No such file or directory: '/Users/burbol/Downloads/Results_NEW_together'

# %%
plt.plot(percentages, theta_mac1, 'ro', percentages, theta_mac2,'bs',percentages, theta_mac3,'g^')
plt.plot(percentages, theta_mac1, 'r--')
#plt.plot(percentages, theta_results)
plt.ylabel(r' Macrosc. Contact Angle $ \Theta_{mac}$ [deg] ')
plt.xlabel('OH- PERCENTAGE [%]')
plt.suptitle('Macroscopic Contact Angles vs. OH- Percentages' , fontsize=14, fontweight='bold')
plt.grid(True)
#plt.axis([0, 80, 3.4, 4.8])
pylab.savefig('C_Angles_OH_NEW_together.png')
plt.show()

# %%
zeroline = [0,0,0,0,0]
plt.plot(percentages, sigma1, 'ro', percentages, sigma2,'bs',percentages, sigma3,'g^')
plt.plot(percentages, sigma1, percentages, sigma2,percentages, sigma3)
plt.plot(percentages, zeroline, 'k--')
#plt.plot(percentages, sigma1, 'ro', k)
#plt.plot(percentages, sigma)
plt.ylabel(r' $\sigma $ [pN]')
plt.xlabel('OH- PERCENTAGE [%]')
plt.suptitle('Line Tension vs. OH- Percentages' , fontsize=14, fontweight='bold')
plt.grid(True)
#plt.axis([0, 80, 3.4, 4.8])
pylab.savefig('Sigma_OH_NEW_together.png')
plt.show()

# %%
def func(x, a, b):
    return a*x + b

# %%
# 1: last water peak; 2: middle point; 3: last SAM peak
# y is cos(theta_min); and x is (1/r_base)
x2_s0 = [ 0.80071317, 0.65109003, 0.57462232, 0.52604677, 0.48669925, 0.44462275, 0.43546337, 0.41630514, 0.40278448, 0.38999712]
y2_s0 = [-0.77517837, -0.78322934, -0.78331784, -0.78824301, -0.78594263, -0.78577889, -0.78627883, -0.78589082, -0.78977488, -0.79111381]
x2_s5 =[ 0.69887677,  0.53621916, 0.50780773,  0.48231853,  0.45883042,  0.36967555, 0.35997821,  0.34909518,  0.33736674,  0.3243962 ]
y2_s5 =[-0.69475868, -0.6668232, -0.71473393, -0.74372238, -0.75589537, -0.67873928, -0.67511917, -0.68498742, -0.69038595, -0.68747456]
x2_s11 =[ 0.53493434,  0.39164116,  0.35200843,  0.34691564,  0.29340203, 0.30325456, 0.27914028,  0.27397815,  0.25673546]
y2_s11 =[-0.46304662, -0.50527509, -0.49611339, -0.55522833, -0.47261946, -0.53199014, -0.49055826, -0.51578829, -0.48198223]
x2_s17 =[ 0.48450375,  0.38334825,  0.33601708,  0.3018645, 0.2840994,  0.26666112, 0.25643827, 0.24199199, 0.23167339, 0.22030956]
y2_s17 =[-0.33507289, -0.31900201, -0.30719545, -0.2920858,  -0.308854, -0.34673519, -0.32095459, -0.30107297, -0.29848654, -0.27331726]

x3_s0 =[ 1.01362134, 0.77733552,  0.66893362, 0.60807027,  0.55196363,  0.5024673, 0.48859203,  0.46825251,  0.45177913, 0.43584132]
y3_s0 =[-0.86651276, -0.85369593, -0.84549109, -0.84651793, -0.83830947, -0.83693238, -0.83471196, -0.83531885, -0.83721344, -0.83691626]
x3_s5 =[ 0.80208159,  0.5906295,  0.56369298,  0.53718432,  0.51005718,  0.39476037, 0.38435033,  0.37169607,  0.35871606,  0.34387041]
y3_s5 =[-0.77924471, -0.73637341, -0.77654387, -0.79983643, -0.80817329, -0.72598039, -0.72292099, -0.7292422,  -0.73285411, -0.72846594]
x3_s11 =[ 0.53493434,  0.39164116,  0.35200843,  0.34691564,  0.29340203,  0.30325456, 0.27914028,  0.27397815, 0.25673546]
y3_s11 =[-0.46304662, -0.50527509, -0.49611339, -0.55522833, -0.47261946, -0.53199014, -0.49055826, -0.51578829, -0.48198223]
x3_s17 =[ 0.48450375,  0.38334825, 0.33601708, 0.3018645, 0.2840994, 0.26666112, 0.25643827, 0.24199199,  0.23167339, 0.22030956]
y3_s17 =[-0.33507289, -0.31900201, -0.30719545, -0.2920858, -0.308854, -0.34673519, -0.32095459, -0.30107297, -0.29848654, -0.27331726]

x1_s0 = [ 0.69337752, 0.57706158, 0.51560565, 0.4736207, 0.44279381, 0.40525853, 0.39862632, 0.3804863, 0.36870024, 0.35775193]
y1_s0 = [-0.68401373, -0.71270128, -0.72116111, -0.7299716, -0.73357843, -0.73453872, -0.73784667, -0.73638584, -0.74227983, -0.7452475 ]
x1_s5 = [ 0.63411666,  0.49800054,  0.46870053,  0.44393751, 0.42255069,  0.3500516, 0.34091298, 0.33116799,  0.32034094,  0.30875906]
y1_s5 =[-0.60977945, -0.59690828, -0.65262118, -0.6874386,  -0.70335154, -0.63133962, -0.62711851, -0.64051883, -0.64775278, -0.64642959]
x1_s11 =[ 0.49668818,  0.36731829,  0.33187838, 0.3246245, 0.27985768, 0.28636027, 0.26615758, 0.26094659, 0.24619405]
y1_s11 =[-0.29801742, -0.39170313, -0.38975085, -0.45828097, -0.38261502, -0.44262909, -0.40590945, -0.43692142, -0.40639858]
x1_s17 = [ 0.46417544,  0.3702446,  0.32608491, 0.2941504, 0.27687038,  0.25922246, 0.25014212, 0.23675518,  0.22688782, 0.21638685]
y1_s17 = [-0.18156185, -0.19254885, -0.19589881, -0.19161203, -0.21805319, -0.2626959, -0.23935041, -0.22353874, -0.22419312, -0.20211258]

# %%
# 1: last water peak; 2: middle point; 3: last SAM peak
slope1_s0 = 0.166012801024
b1_s0 =-0.804358867813
slope1_s5 =a= 0.078242950773
b1_s5 =-0.676550498662
slope1_s11 = a= 0.455712599045
b1_s11 = -0.546175066372
slope1_s17 = 0.206392372643
b1_s17 =-0.273442110501


slope3_s0 = -0.0552032254334
b3_s0 = -0.810223032488
slope3_s5 = -0.14027759436 
b3_s5 = -0.685830160516
slope3_s11 = 0.0914803512964
b3_s11 = -0.532219016323
slope3_s17 = -0.129885582297
b3_s17 = -0.27122228017


slope2_s0 = 0.0303762520568
b2_s0 = -0.801052831279
slope2_s5 = -0.0526330201838
b2_s5 = -0.675976173514
slope2_s11 = 0.0914803512964
b2_s11 =  -0.532219016323
slope2_s17 = -0.129885595348 
b2_s17 = -0.271222276245

# %%
d = 0
namethetabaserad = "theta_r_s%s_NEW_together.png" % (d)

y1_s0_fit = np.zeros(len(x1_s0))
y2_s0_fit = np.zeros(len(x2_s0))
y3_s0_fit = np.zeros(len(x3_s0))
for i in range(len(x1_s0)):
    y1_s0_fit[i] = func(x1_s0[i], slope1_s0, b1_s0)
    y2_s0_fit[i] = func(x2_s0[i], slope2_s0, b2_s0)
    y3_s0_fit[i] = func(x3_s0[i], slope3_s0, b3_s0)

#t = np.arange(0.3, 1.1, 0.2)    
#PLOT for SAM 0% (Also saved to file)
plt.plot(x1_s0, y1_s0, 'ro',x2_s0, y2_s0, 'bs',x3_s0, y3_s0, 'g^')
plt.plot(x1_s0, y1_s0_fit, 'r', x2_s0, y2_s0_fit,'b', x3_s0, y3_s0_fit, 'g')
#plt.plot(slope1_s0*t + b1_s0)
plt.xlabel('${R \ _{BASE}}^{-1}\ [ nm ^{-1} ]$')
plt.ylabel(r' $\cos\Theta_{mic}$ ')
plt.suptitle(r'$\cos\Theta_{mic}$ vs. ${R \ _{BASE}}^{-1}$ for SAM 0%', fontsize=14)
#plt.text(0.37, -0.7, txt ,style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 80, 3.4, 4.8])
pylab.savefig(namethetabaserad)
plt.show()

# %%
d = 5
namethetabaserad = "theta_r_s%s_NEW_together.png" % (d)

y1_s5_fit = np.zeros(len(x1_s0))
y2_s5_fit = np.zeros(len(x2_s0))
y3_s5_fit = np.zeros(len(x3_s0))
for i in range(len(x1_s0)):
    y1_s5_fit[i] = func(x1_s5[i], slope1_s5, b1_s0)
    y2_s5_fit[i] = func(x2_s5[i], slope2_s5, b2_s0)
    y3_s5_fit[i] = func(x3_s5[i], slope3_s5, b3_s0)

#t = np.arange(0.3, 1.1, 0.2)    
#PLOT for SAM 0% (Also saved to file)
plt.plot(x1_s5, y1_s5, 'ro',x2_s5, y2_s5, 'bs',x3_s5, y3_s5, 'g^')
plt.plot(x1_s5, y1_s5_fit, 'r', x2_s5, y2_s5_fit,'b', x3_s5, y3_s0_fit, 'g')
#plt.plot(slope1_s0*t + b1_s0)
plt.xlabel('${R \ _{BASE}}^{-1}\ [ nm ^{-1} ]$')
plt.ylabel(r' $\cos\Theta_{mic}$ ')
plt.suptitle(r'$\cos\Theta_{mic}$ vs. ${R \ _{BASE}}^{-1}$ for SAM 5%', fontsize=14)
#plt.text(0.37, -0.7, txt ,style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 80, 3.4, 4.8])
pylab.savefig(namethetabaserad)
plt.show()

# %%
d = 5
namethetabaserad = "theta_r_s%s_NEW_together.png" % (d)

y1_s5_fit = np.zeros(len(x1_s5))
y2_s5_fit = np.zeros(len(x2_s5))
y3_s5_fit = np.zeros(len(x3_s5))
for i in range(len(x1_s5)):
    y1_s5_fit[i] = func(x1_s5[i], slope1_s5, b1_s5)
    y2_s5_fit[i] = func(x2_s5[i], slope2_s5, b2_s5)
    y3_s5_fit[i] = func(x3_s5[i], slope3_s5, b3_s5)

#t = np.arange(0.3, 1.1, 0.2)    
#PLOT for SAM 0% (Also saved to file)
plt.plot(x1_s5, y1_s5, 'ro',x2_s5, y2_s5, 'bs',x3_s5, y3_s5, 'g^')
plt.plot(x1_s5, y1_s5_fit, 'r', x2_s5, y2_s5_fit,'b', x3_s5, y3_s5_fit, 'g')
#plt.plot(slope1_s0*t + b1_s0)
plt.xlabel('${R \ _{BASE}}^{-1}\ [ nm ^{-1} ]$')
plt.ylabel(r' $\cos\Theta_{mic}$ ')
plt.suptitle(r'$\cos\Theta_{mic}$ vs. ${R \ _{BASE}}^{-1}$ for SAM 5%', fontsize=14)
#plt.text(0.37, -0.7, txt ,style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 80, 3.4, 4.8])
pylab.savefig(namethetabaserad)
plt.show()

# %%
d = 11
namethetabaserad = "theta_r_s%s_NEW_together.png" % (d)

y1_s11_fit = np.zeros(len(x1_s11))
y2_s11_fit = np.zeros(len(x2_s11))
y3_s11_fit = np.zeros(len(x3_s11))
for i in range(len(x1_s11)):
    y1_s11_fit[i] = func(x1_s11[i], slope1_s11, b1_s11)
    y2_s11_fit[i] = func(x2_s11[i], slope2_s11, b2_s11)
    y3_s11_fit[i] = func(x3_s11[i], slope3_s11, b3_s11)

#t = np.arange(0.3, 1.1, 0.2)    
#PLOT for SAM 0% (Also saved to file)
plt.plot(x1_s11, y1_s11, 'ro',x2_s11, y2_s11, 'bs',x3_s11, y3_s11, 'g^')
plt.plot(x1_s11, y1_s11_fit, 'r', x2_s11, y2_s11_fit,'b', x3_s11, y3_s11_fit, 'g')
#plt.plot(slope1_s0*t + b1_s0)
plt.xlabel('${R \ _{BASE}}^{-1}\ [ nm ^{-1} ]$')
plt.ylabel(r' $\cos\Theta_{mic}$ ')
plt.suptitle(r'$\cos\Theta_{mic}$ vs. ${R \ _{BASE}}^{-1}$ for SAM 11%', fontsize=14)
#plt.text(0.37, -0.7, txt ,style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 80, 3.4, 4.8])
pylab.savefig(namethetabaserad)
plt.show()

# %%
d = 17
namethetabaserad = "theta_r_s%s_NEW_together.png" % (d)

y1_s17_fit = np.zeros(len(x1_s17))
y2_s17_fit = np.zeros(len(x2_s17))
y3_s17_fit = np.zeros(len(x3_s17))
for i in range(len(x1_s11)):
    y1_s17_fit[i] = func(x1_s17[i], slope1_s17, b1_s17)
    y2_s17_fit[i] = func(x2_s17[i], slope2_s17, b2_s17)
    y3_s17_fit[i] = func(x3_s17[i], slope3_s17, b3_s17)

#t = np.arange(0.3, 1.1, 0.2)    
#PLOT for SAM 0% (Also saved to file)
plt.plot(x1_s17, y1_s17, 'ro',x2_s17, y2_s17, 'bs',x3_s17, y3_s17, 'g^')
plt.plot(x1_s17, y1_s17_fit, 'r', x2_s17, y2_s17_fit,'b', x3_s17, y3_s17_fit, 'g')
#plt.plot(slope1_s0*t + b1_s0)
plt.xlabel('${R \ _{BASE}}^{-1}\ [ nm ^{-1} ]$')
plt.ylabel(r' $\cos\Theta_{mic}$ ')
plt.suptitle(r'$\cos\Theta_{mic}$ vs. ${R \ _{BASE}}^{-1}$ for SAM 17%', fontsize=14)
#plt.text(0.37, -0.7, txt ,style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 80, 3.4, 4.8])
pylab.savefig(namethetabaserad)
plt.show()
