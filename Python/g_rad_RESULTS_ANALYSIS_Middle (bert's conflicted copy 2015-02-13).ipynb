# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from scipy import stats

# %%
# %cd /home/eixeres/Downloads/Python/Results_Middle
#%cd /Users/burbol/Downloads/Results_Middle
# Out:
# /home/eixeres/Downloads/Python/Results_Middle

# %%
theta_results = np.zeros(5)
sigma = np.zeros(5)
percentages = np.zeros(5)
percentages = [0, 5, 11, 17, 66]

# %%
# We save the data in the arrays "theta_all" and "rbase_all"
theta_all, rbase_all = np.loadtxt('Contact_Angles2_Middle_s5.txt', skiprows=2, usecols = (0,1),unpack=True)

# %%
print len(theta_all), len(rbase_all)
# Out:
# 1600 1600

# %%
# Here we create two dictionaries named "angles" and "radii". Each dictionary consists of a set of "key: value" pairs, each one corresponding to a different system. The keys are (also) a pair of numbers "b, c".
# "b" refers to the OH-coverage percentage of the SAM, and "c" to the number of water molecules of the droplet. For example, the key "5, 1000" refers to the system with a surface with 5% OH-coverage, 
# and a droplet with 1000 water molecules. The value corresponding to each key is an array with the 40 calculated angles/base radii, that belong to that system. For example: "radii[(11, 3000)]" would give back
# the array with the 40 calculated values of the base radii corresponding to the system with a surface with 11% OH-coverage, and a droplet with 3000 water molecules.
angles={}
radii={}
k = 0
for b in [5]:
    for c in [1000, 2000, 3000, 4000, 5000, 6500, 7000, 8000, 9000, 10000]:
        z = b, c
        m = 0
        th = [0] * 160
        r = [0] * 160
        i=k*160
        j=(k+1)*160
        for l in range(i,j):
            th[m]=theta_all[l]
            r[m]=rbase_all[l]
            m = m +1
        angles[z] = th
        radii[z] = r
        k=k+1


theta_s5 = np.zeros(10)
rbase_s5 = np.zeros(10)
errortheta_s5 = np.zeros(10)
errorr_base_s5 = np.zeros(10)
#We choose a system and substitute the values "b" and "c" to save the corresponding angle and radii values in two arrays named, respectively, "theta" and "rbase".
#b=0
#c=4000
#theta = array(angles[(b, c)])
#rbase = array(radii[(b, c)])
#print "theta=", th
#print "rbase=", r
#print theta[0]

# %%
# The data of the SAM with 11% OH-coverage gets handled separately, because there are still some simulations missing. We save the data in the arrays "theta_all11" and "rbase_all11"
theta_all11, rbase_all11 = np.loadtxt('Contact_Angles2_Middle_s11.txt', skiprows=2, usecols = (0,1),unpack=True)

# %%
# DICTIONARIES FOR SAM 11% (MODIFIED CELL COPY)
# Here we create two dictionaries named "angles11" and "radii11". Each dictionary consists of a set of "key: value" pairs, each one corresponding to a different system. The keys are (also) a pair of numbers "b, c".
# "b" refers to the OH-coverage percentage of the SAM, and "c" to the number of water molecules of the droplet. For example, the key "5, 1000" refers to the system with a surface with 5% OH-coverage, 
# and a droplet with 1000 water molecules. The value corresponding to each key is an array with the 40 calculated angles/base radii, that belong to that system. For example: "radii[(11, 3000)]" would give back
# the array with the 40 calculated values of the base radii corresponding to the system with a surface with 11% OH-coverage, and a droplet with 3000 water molecules.
#angles11={}
#radii11={}
k = 0
for b in [11]:
    for c in [1000, 2000, 3000, 4000, 5000, 6500, 7000, 8000, 9000, 10000]:
        z = b, c
        m = 0
        t11 = [0] * 160
        r11 = [0] * 160
        i=k*160
        j=(k+1)*160
        for l in range(i,j):
            t11[m]=theta_all11[l]
            r11[m]=rbase_all11[l]
            m = m +1
#        angles11[z] = t11 THESE 2 LINES HAVE BEEN SUBSTITUTED BY THE FOLLOWING TWO.
#        radii11[z] = r11
        angles[z] = t11
        radii[z] = r11
        k=k+1
    
#theta_s11 = np.zeros(10) # UNCOMMENT THESE 2 LINES AND DELETE THE NEXT TWO, ONCE THE DATA FOR SAM11% WATER 2000
#rbase_s11 = np.zeros(10)

theta_s11 = np.zeros(9)
rbase_s11 = np.zeros(9)
errortheta_s11 = np.zeros(9)
errorr_base_s11 = np.zeros(9)

#We choose a system and substitute the values "b" and "c" to save the corresponding angle and radii values in two arrays named, respectively, "theta" and "rbase".
#b=11
#c=4000
#theta11 = array(angles11[(b, c)])
#rbase11 = array(radii11[(b, c)])
#print "theta11=", theta11
#print "rbase11=", rbase11
#print theta11[0]

# %%
# We save the data in the arrays "theta_all" and "rbase_all"
theta_all_s, rbase_all_s = np.loadtxt('Contact_Angles2_Middle_s0.txt', skiprows=2, usecols = (0,1),unpack=True)
print len(theta_all_s)
# Out:
# 1600

# %%
# Here we create two dictionaries named "angles" and "radii". Each dictionary consists of a set of "key: value" pairs, each one corresponding to a different system. The keys are (also) a pair of numbers "b, c".
# "b" refers to the OH-coverage percentage of the SAM, and "c" to the number of water molecules of the droplet. For example, the key "5, 1000" refers to the system with a surface with 5% OH-coverage, 
# and a droplet with 1000 water molecules. The value corresponding to each key is an array with the 40 calculated angles/base radii, that belong to that system. For example: "radii[(11, 3000)]" would give back
# the array with the 40 calculated values of the base radii corresponding to the system with a surface with 11% OH-coverage, and a droplet with 3000 water molecules.
#angles={}
#radii={}
k = 0
for b in [0]:
    for c in [1000, 2000, 3000, 4000, 5000, 6500, 7000, 8000, 9000, 10000]:
        z = b, c
        m = 0
        th = [0] * 160
        r = [0] * 160
        i=k*160
        j=(k+1)*160
        for l in range(i,j):
            th[m]=theta_all_s[l]
            r[m]=rbase_all_s[l]
            m = m +1
        angles[z] = th
        radii[z] = r
        k=k+1

theta_s0 = np.zeros(10)
rbase_s0 = np.zeros(10)
errortheta_s0 = np.zeros(10)
errorr_base_s0 = np.zeros(10)
#We choose a system and substitute the values "b" and "c" to save the corresponding angle and radii values in two arrays named, respectively, "theta" and "rbase".
#b=0
#c=4000
#theta = array(angles[(b, c)])
#rbase = array(radii[(b, c)])
#print "theta=", theta
#print "rbase=", rbase
#print theta[0]

# %%
# We save the data in the arrays "theta_all" and "rbase_all"
theta_all_17, rbase_all_17 = np.loadtxt('Contact_Angles2_Middle_s17.txt', skiprows=2, usecols = (0,1),unpack=True)

# %%
# Here we create two dictionaries named "angles" and "radii". Each dictionary consists of a set of "key: value" pairs, each one corresponding to a different system. The keys are (also) a pair of numbers "b, c".
# "b" refers to the OH-coverage percentage of the SAM, and "c" to the number of water molecules of the droplet. For example, the key "5, 1000" refers to the system with a surface with 5% OH-coverage, 
# and a droplet with 1000 water molecules. The value corresponding to each key is an array with the 40 calculated angles/base radii, that belong to that system. For example: "radii[(11, 3000)]" would give back
# the array with the 40 calculated values of the base radii corresponding to the system with a surface with 11% OH-coverage, and a droplet with 3000 water molecules.
#angles={}
#radii={}
k = 0
for b in [17]:
    for c in [1000, 2000, 3000, 4000, 5000, 6500, 7000, 8000, 9000, 10000]:
        z = b, c
        m = 0
        th = [0] * 160
        r = [0] * 160
        i=k*160
        j=(k+1)*160
        for l in range(i,j):
            th[m]=theta_all_17[l]
            r[m]=rbase_all_17[l]
            m = m +1
        angles[z] = th
        radii[z] = r
        k=k+1

theta_s17 = np.zeros(10)
rbase_s17 = np.zeros(10)
errortheta_s17 = np.zeros(10)
errorr_base_s17 = np.zeros(10)
#We choose a system and substitute the values "b" and "c" to save the corresponding angle and radii values in two arrays named, respectively, "theta" and "rbase".
#b=0
#c=4000
#theta = array(angles[(b, c)])
#rbase = array(radii[(b, c)])
#print "theta=", theta
#print "rbase=", rbase
#print theta[0]

# %%
# This function allows to use ranges, just as the built-in function range(), but with float arguments.
# Taken from "http://code.activestate.com/recipes/66472-frange-a-range-function-with-float-increments/"
def frange(start, end=None, inc=None):
    if end == None:
        end = start + 0.0
        start = 0.0

    if inc == None:
        inc = 1.0

    L = []
    while 1:
        next = start + len(L) * inc
        if inc > 0 and next >= end:
            break
        elif inc < 0 and next <= end:
            break
        L.append(next)
    return L

# %%
# We create an array named "t" with the time values.
t = np.zeros(160)
i=0
for d in frange(0, 80, 0.5):
    t[i] = d
    i = i + 1

# %%
def naive_variance(data):
    n = 0
    Sum = 0
    Sum_sqr = 0
 
    for x in data:
        n = n + 1
        Sum = Sum + x
        Sum_sqr = Sum_sqr + x*x
 
    variance = (Sum_sqr - (Sum*Sum)/n)/(n - 1)
    return variance

def blockAverage(datastream, Nblocks):
    
    # FIRST WE CREATE AN ARRAY TO STORE THE MEAN VALUES OF THE DATA BLOCKS (blockMean)
    blockMean = np.zeros(Nblocks)  
        
    # Nobs is the number of points (observations) in our data
    Nobs = len(datastream) 
    # BlockSize is the size of each block of data
    BlockSize = int(Nobs//Nblocks) 
    
    if Nblocks==1:
        errorbar = naive_variance(datastream)
        return errorbar

    else:
       # WE CALCULATE IN A LOOP THE MEAN VALUES OF EACH DATA BLOCK (blockMean)
        for i in range(0,Nblocks-1):
            ibeg = i*BlockSize
            iend = (i+1)*BlockSize
            blockMean[i] = mean(datastream[ibeg:iend])
        # WE TREAT THE LAST BLOCK SEPARATELY, BECAUSE WE HAVE TO TAKE INTO ACCOUNT THE POSSIBLE REMAINING POINTS 
        # WHEN THE NUMBER OF DATA POINTS ISN'T A MULTIPLE OF THE NUMBER OF BLOCKS
        ibeg = (Nblocks-1)*BlockSize
        iend = Nobs
        blockMean[Nblocks-1] = mean(datastream[ibeg:iend])
     
        errorbar = (np.std(blockMean))/sqrt(Nblocks -1) #np.std(blockMean) is the standard deviation of blockmean
        simulavr = mean(blockMean)
        return simulavr, errorbar

# %%
n=0
b=0
c=1000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=9
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break

omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=20 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])   
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s0[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s0[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s0[n]=t_average 
rbase_s0[n]=r_average


# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 



#PLOT FOR CONTACT ANGLE OF SAM 0% & 1000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta_{mic}$ vs. Time')
plt.text(20, 166, 'SAM 0%, Water 1000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 125, 180])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 1000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta_{mic}$ vs. Time')
plt.text(20, 0.3, 'SAM 0%, Water 1000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 0, 1.7])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 80
# endblocks = 60
# Start of bestblock =  18 ns
#
# Average of r_base =  1.24320883109 nm
# Average of Theta =  141.026700041 deg
#
# Smallest error of theta = 0.0398059770879 deg
# sin(average) = 0.628958169889
# sin(average)*error = 0.000436965771522

# %%
n=1
b=0
c=2000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=50
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break

omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=20 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s0[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s0[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s0[n]=t_average 
rbase_s0[n]=r_average


# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 


#PLOT FOR CONTACT ANGLE OF SAM 0% & 2000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta_{mic}$ vs. Time')
plt.text(20, 155, 'SAM 0%, Water 2000 molec.',style='italic',bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 2000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta_{mic}$ vs. Time')
plt.text(20, 1.0, 'SAM 0%, Water 2000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 80
# endblocks = 60
# Start of bestblock =  28 ns
#
# Average of r_base =  1.53534872882 nm
# Average of Theta =  141.579503845 deg
#
# Smallest error of theta = 0.123655842609 deg
# sin(average) = 0.621428087575
# sin(average)*error = 0.00134116708845

# %%
n=2
b=0
c=3000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
        
#start=22
omit=20 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=20 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s0[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s0[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s0[n]=t_average 
rbase_s0[n]=r_average


# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 


#PLOT FOR CONTACT ANGLE OF SAM 0% & 3000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta_{mic}$ vs. Time')
plt.text(20, 162, 'SAM 0%, Water 3000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 3000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta_{mic}$ vs. Time')
plt.text(20, 1.0, 'SAM 0%, Water 3000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 0.8, 2.3])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 79
# endblocks = 59
# Start of bestblock =  13 ns
#
# Average of r_base =  1.73899206656 nm
# Average of Theta =  141.59484846 deg
#
# Smallest error of theta = 0.0413745119756 deg
# sin(average) = 0.621218240693
# sin(average)*error = 0.000448595023184

# %%
n=3
b=0
c=4000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=42
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break

omit=30 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=20 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])  
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s0[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s0[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s0[n]=t_average 
rbase_s0[n]=r_average


# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 


#PLOT FOR CONTACT ANGLE OF SAM 0% & 4000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta_{mic}$ vs. Time')
plt.text(11, 160, 'SAM 0%, Water 4000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 4000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1, 'SAM 0%, Water 4000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 0.6, 2.5])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 76
# endblocks = 56
# Start of bestblock =  20 ns
#
# Average of r_base =  1.9021776414 nm
# Average of Theta =  141.994160988 deg
#
# Smallest error of theta = 0.0777205030031 deg
# sin(average) = 0.615741778298
# sin(average)*error = 0.000835240590774

# %%
n=4
b=0
c=5000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=50
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
omit=30 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=20 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])  
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s0[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s0[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s0[n]=t_average 
rbase_s0[n]=r_average


# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 


#PLOT FOR CONTACT ANGLE OF SAM 0% & 5000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 150, 'SAM 0%, Water 5000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 134, 154])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 5000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.55, 'SAM 0%, Water 5000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 1.4, 2.5])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 80
# endblocks = 60
# Start of bestblock =  27 ns
#
# Average of r_base =  2.05555642153 nm
# Average of Theta =  141.786396105 deg
#
# Smallest error of theta = 0.13565037403 deg
# sin(average) = 0.618594966094
# sin(average)*error = 0.00146455182628

# %%
n=5
b=0
c=6500
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=80
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
omit=40 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=20 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])   
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s0[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s0[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s0[n]=t_average 
rbase_s0[n]=r_average


# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 

#PLOT FOR CONTACT ANGLE OF SAM 0% & 6500 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 150, 'SAM 0%, Water 6500 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 6500 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 1.6, 'SAM 0%, Water 6500 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 120
# endblocks = 100
# Start of bestblock =  48 ns
#
# Average of r_base =  2.25540247519 nm
# Average of Theta =  141.665559352 deg
#
# Smallest error of theta = 0.0683961453256 deg
# sin(average) = 0.620250650995
# sin(average)*error = 0.000740416729195

# %%
n=6
b=0
c=7000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=86
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
end = m
omit=60 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=20 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])     
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s0[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s0[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s0[n]=t_average 
rbase_s0[n]=r_average


# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 


#PLOT FOR CONTACT ANGLE OF SAM 0% & 7000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 155, 'SAM 0%, Water 7000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 60, 133, 160])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 7000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 1.4, 'SAM 0%, Water 7000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 60, 1.2, 2.8])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 120
# endblocks = 100
# Start of bestblock =  43 ns
#
# Average of r_base =  2.29660641016 nm
# Average of Theta =  141.836930262 deg
#
# Smallest error of theta = 0.131807248964 deg
# sin(average) = 0.617901739203
# sin(average)*error = 0.00142146470589

# %%
n=7
b=0
c=8000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=90
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
omit=70 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=20 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])  
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s0[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s0[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s0[n]=t_average 
rbase_s0[n]=r_average


# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 


#PLOT FOR CONTACT ANGLE OF SAM 0% & 8000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 150, 'SAM 0%, Water 8000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 8000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 1.8, 'SAM 0%, Water 8000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 120
# endblocks = 100
# Start of bestblock =  47 ns
#
# Average of r_base =  2.40488916651 nm
# Average of Theta =  141.749549189 deg
#
# Smallest error of theta = 0.0594307370843 deg
# sin(average) = 0.619100128274
# sin(average)*error = 0.000642169061404

# %%
n=8
b=0
c=9000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=100
omit=70 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=20 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])   
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s0[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s0[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s0[n]=t_average 
rbase_s0[n]=r_average


# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 


#PLOT FOR CONTACT ANGLE OF SAM 0% & 9000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 150, 'SAM 0%, Water 9000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 9000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 2, 'SAM 0%, Water 9000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 120
# endblocks = 100
# Start of bestblock =  49 ns
#
# Average of r_base =  2.48170252744 nm
# Average of Theta =  142.182321732 deg
#
# Smallest error of theta = 0.0659080886227 deg
# sin(average) = 0.613150822052
# sin(average)*error = 0.000705315453639

# %%
n=9
b=0
c=10000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=120
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
end = m
omit=90 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=20 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])  
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s0[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s0[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s0[n]=t_average 
rbase_s0[n]=r_average


# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 

#PLOT FOR CONTACT ANGLE OF SAM 0% & 10000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(25, 150, 'SAM 0%, Water 10000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 0% & 10000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(25, 1.8, 'SAM 0%, Water 10000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 159
# endblocks = 139
# Start of bestblock =  68 ns
#
# Average of r_base =  2.56747800206 nm
# Average of Theta =  142.232556651 deg
#
# Smallest error of theta = 0.0297335520194 deg
# sin(average) = 0.612457972252
# sin(average)*error = 0.000317834073162

# %%
n=0
b=5
c=1000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=10
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
omit=11 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=20 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])  
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s5[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s5[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s5[n]=t_average 
rbase_s5[n]=r_average


# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 


#PLOT FOR CONTACT ANGLE OF SAM 5% & 1000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 160, 'SAM 5%, Water 1000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 115, 170])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 1000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.1, 'SAM 5%, Water 1000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 1.0, 1.8])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 80
# endblocks = 60
# Start of bestblock =  6 ns
#
# Average of r_base =  1.24320883109 nm
# Average of Theta =  141.026700041 deg
#
# Smallest error of theta = 0.0205540987419 deg
# sin(average) = 0.719540079397
# sin(average)*error = 0.000258125432037

# %%
n=1
b=5
c=2000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
#print theta
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=10
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
omit=11 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=20 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])  
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s5[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s5[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s5[n]=t_average 
rbase_s5[n]=r_average


# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 


#PLOT FOR CONTACT ANGLE OF SAM 5% & 2000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 147, 'SAM 5%, Water 2000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 120, 155])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 2000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.2, 'SAM 5%, Water 2000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 1.0, 2.3])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 80
# endblocks = 60
# Start of bestblock =  15 ns
#
# Average of r_base =  1.53534872882 nm
# Average of Theta =  141.579503845 deg
#
# Smallest error of theta = 0.0166973891399 deg
# sin(average) = 0.743984338374
# sin(average)*error = 0.000216815202051

# %%
n=2
b=5
c=3000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=16
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
omit=11 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=20 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])  
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s5[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s5[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s5[n]=t_average 
rbase_s5[n]=r_average


# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error)


#PLOT FOR CONTACT ANGLE OF SAM 5% & 3000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 160, 'SAM 5%, Water 3000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 120, 170])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 3000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.6, 'SAM 5%, Water 3000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 1.45, 2.35])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 80
# endblocks = 60
# Start of bestblock =  27 ns
#
# Average of r_base =  1.73899206656 nm
# Average of Theta =  141.59484846 deg
#
# Smallest error of theta = 0.0194812391293 deg
# sin(average) = 0.694179207294
# sin(average)*error = 0.000236029097619

# %%
n=3
b=5
c=4000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
#print rbase
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=15
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
        
omit=14 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=20 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])  
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s5[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s5[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s5[n]=t_average 
rbase_s5[n]=r_average


# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(error)

#PLOT FOR CONTACT ANGLE OF SAM 5% & 4000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 180, 'SAM 5%, Water 4000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 115, 205])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 4000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 0.8, 'SAM 5%, Water 4000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 0.6, 2.6])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 80
# endblocks = 60
# Start of bestblock =  19 ns
#
# Average of r_base =  1.9021776414 nm
# Average of Theta =  141.994160988 deg
#
# Smallest error of theta = 0.00871884153523 deg
# sin(average) = 0.663736791786
# sin(average)*error = [  4.94736163e-05   4.88960319e-05   4.82876579e-05   4.63760811e-05
#    4.52497550e-05   4.29026064e-05   4.01260451e-05   3.97960390e-05
#    3.71720854e-05   3.57065538e-05   3.48336703e-05   3.24162881e-05
#    2.94729914e-05   2.78894730e-05   2.43423895e-05   1.92108236e-05
#    1.97914772e-05   1.69733038e-05   1.39751868e-05   1.35032538e-05
#    9.83062865e-06   5.56404883e-06   6.83262592e-06   3.47302897e-06
#    1.17005238e-06   3.00911611e-06   3.01794448e-06   6.92499265e-06
#    6.43141094e-06   1.16643731e-05   1.69612028e-05   1.77093393e-05
#    2.17617247e-05   2.48356728e-05   2.43489325e-05   2.74244254e-05
#    2.85940933e-05   2.89919627e-05   3.04684161e-05   2.82360379e-05
# ...

# %%
n=4
b=5
c=5000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=20
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
        
        
omit=14 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=20 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])  
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s5[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s5[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s5[n]=t_average 
rbase_s5[n]=r_average


# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 


#PLOT FOR CONTACT ANGLE OF SAM 5% & 5000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 170, 'SAM 5%, Water 5000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 125, 180])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 5000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.8, 'SAM 5%, Water 5000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 1.6, 2.6])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 80
# endblocks = 60
# Start of bestblock =  29 ns
#
# Average of r_base =  2.05555642153 nm
# Average of Theta =  141.786396105 deg
#
# Smallest error of theta = 0.0317865274087 deg
# sin(average) = 0.648971282358
# sin(average)*error = 0.000360036003165

# %%
n=5
b=5
c=6500
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=50
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
        
omit=40 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=20 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])     
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s5[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s5[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s5[n]=t_average 
rbase_s5[n]=r_average


# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 

print "rbase_s5[n] = ",rbase_s5[n]


#PLOT FOR CONTACT ANGLE OF SAM 5% & 6500 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 181, 'SAM 5%, Water 6500 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 60, 120, 200])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 6500 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 2.1, 'SAM 5%, Water 6500 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 60, 2, 3])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 120
# endblocks = 100
# Start of bestblock =  44 ns
#
# Average of r_base =  2.25540247519 nm
# Average of Theta =  141.665559352 deg
#
# Smallest error of theta = 0.00864016812282 deg
# sin(average) = 0.738514792054
# sin(average)*error = 0.000111367573995
# rbase_s5[n] =  2.72248405087

# %%
n=6
b=5
c=7000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=70
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break

omit=44 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=20 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])     
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s5[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s5[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s5[n]=t_average 
rbase_s5[n]=r_average


# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 


#PLOT FOR CONTACT ANGLE OF SAM 5% & 7000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 150, 'SAM 5%, Water 7000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 7000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 2.05, 'SAM 5%, Water 7000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 60, 1.9, 3.2])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 120
# endblocks = 100
# Start of bestblock =  46 ns
#
# Average of r_base =  2.29660641016 nm
# Average of Theta =  141.836930262 deg
#
# Smallest error of theta = 0.0507834305231 deg
# sin(average) = 0.736321058358
# sin(average)*error = 0.000652629384356

# %%
n=7
b=5
c=8000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=70
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
        
        
omit=44 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=20 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])    
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s5[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s5[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s5[n]=t_average 
rbase_s5[n]=r_average


# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 


#PLOT FOR CONTACT ANGLE OF SAM 5% & 9000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 146, 'SAM 5%, Water 8000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 9000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 1.8, 'SAM 5%, Water 8000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 120
# endblocks = 100
# Start of bestblock =  43 ns
#
# Average of r_base =  2.40488916651 nm
# Average of Theta =  141.749549189 deg
#
# Smallest error of theta = 0.014996871777 deg
# sin(average) = 0.728841196261
# sin(average)*error = 0.000190770385865

# %%
n=8
b=5
c=9000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=76
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
        
omit=60 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=20 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])     
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s5[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s5[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s5[n]=t_average 
rbase_s5[n]=r_average


# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 


#PLOT FOR CONTACT ANGLE OF SAM 5% & 9000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 146, 'SAM 5%, Water 9000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 9000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 2.0, 'SAM 5%, Water 9000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 120
# endblocks = 100
# Start of bestblock =  35 ns
#
# Average of r_base =  2.48170252744 nm
# Average of Theta =  142.182321732 deg
#
# Smallest error of theta = 0.0107046369727 deg
# sin(average) = 0.723301236737
# sin(average)*error = 0.000135135209381

# %%
n=9
b=5
c=10000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=130
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
        
omit=60 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=20 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])    
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s5[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s5[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s5[n]=t_average 
rbase_s5[n]=r_average


# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 

#PLOT FOR CONTACT ANGLE OF SAM 5% & 10000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(25, 146, 'SAM 5%, Water 10000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 5% & 10000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(25, 2, 'SAM 5%, Water 10000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 159
# endblocks = 139
# Start of bestblock =  60 ns
#
# Average of r_base =  2.56747800206 nm
# Average of Theta =  142.232556651 deg
#
# Smallest error of theta = 0.0352934623423 deg
# sin(average) = 0.725821249778
# sin(average)*error = 0.000447096542956

# %%
n=0
b=11
c=1000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
#print theta
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=60
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
        
omit=40 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=20 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])  
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s11[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s11[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s11[n]=t_average 
rbase_s11[n]=r_average


# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 

#PLOT FOR CONTACT ANGLE OF SAM 11% & 1000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(20, 134, 'SAM 11%, Water 1000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 1000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(20, 1.4, 'SAM 11%, Water 1000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 80
# endblocks = 60
# Start of bestblock =  29 ns
#
# Average of r_base =  1.24320883109 nm
# Average of Theta =  141.026700041 deg
#
# Smallest error of theta = 0.0796783857009 deg
# sin(average) = 0.883727037556
# sin(average)*error = 0.0012289551578

# %%
#n=2 #UNCOMMENT THIS LINE ONCE THERE IS THE COMPLETE DATA OF THIS SYSTEM
b=11
c=2000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=60
for m in range(0, len(theta)): ##### TEST FOR CORRECTNESS!!!!!
    if math.isnan(theta[m]):
        break
omit=1 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=1 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

m =len(theta) ##### TEST FOR CORRECTNESS!!!!!

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])     
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s11[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s11[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s11[n]=t_average 
rbase_s11[n]=r_average


# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 

#PLOT FOR CONTACT ANGLE OF SAM 11% & 2000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(1.3, 135, 'SAM 11%, Water 2000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 20, 90, 170])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 2000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(1.3, 1.7, 'SAM 11%, Water 2000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 20, 0, 3])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 160
# endblocks = 159
# Start of bestblock =  0 ns
#
# Average of r_base =  1.24320883109 nm
# Average of Theta =  141.026700041 deg
#
# Smallest error of theta = nan deg
# sin(average) = nan
# sin(average)*error = nan

# %%
n=1
b=11
c=3000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
#print theta
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=10
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
        
omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=20 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])  
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s11[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s11[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s11[n]=t_average 
rbase_s11[n]=r_average


# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 


#PLOT FOR CONTACT ANGLE OF SAM 11% & 3000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 155, 'SAM 11%, Water 3000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 100, 170])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 3000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 0.8, 'SAM 11%, Water 3000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 0.5, 3.4])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 80
# endblocks = 60
# Start of bestblock =  10 ns
#
# Average of r_base =  1.53534872882 nm
# Average of Theta =  141.579503845 deg
#
# Smallest error of theta = 0.193695894622 deg
# sin(average) = 0.863067864138
# sin(average)*error = 0.00291771407046

# %%
n=2
b=11
c=4000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
#print theta
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=20
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
        
omit=16 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=20 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])     
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s11[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s11[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s11[n]=t_average 
rbase_s11[n]=r_average


# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 


#PLOT FOR CONTACT ANGLE OF SAM 11% & 4000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 158, 'SAM 11%, Water 4000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 100, 170])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 4000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 1.0, 'SAM 11%, Water 4000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 0.5, 3.6])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 80
# endblocks = 60
# Start of bestblock =  19 ns
#
# Average of r_base =  1.73899206656 nm
# Average of Theta =  141.59484846 deg
#
# Smallest error of theta = 0.0712985432049 deg
# sin(average) = 0.868865143969
# sin(average)*error = 0.00108121085938

# %%
n=3
b=11
c=5000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=20
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
        
omit=16 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=20 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])     
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s11[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s11[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s11[n]=t_average 
rbase_s11[n]=r_average


# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 


#PLOT FOR CONTACT ANGLE OF SAM 11% & 5000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 180, 'SAM 11%, Water 5000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 100, 200])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 5000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 2.2, 'SAM 11%, Water 5000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 2.1, 3.3])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 80
# endblocks = 60
# Start of bestblock =  9 ns
#
# Average of r_base =  1.9021776414 nm
# Average of Theta =  141.994160988 deg
#
# Smallest error of theta = 0.010848929857 deg
# sin(average) = 0.831722824187
# sin(average)*error = 0.000157486339426

# %%
n=4
b=11
c=6500
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=50
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
        
omit=26 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=20 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])     
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s11[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s11[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s11[n]=t_average 
rbase_s11[n]=r_average


# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 


#PLOT FOR CONTACT ANGLE OF SAM 11% & 5000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 150, 'SAM 11%, Water 6500 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 40, 90, 130])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 5000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 1.0, 'SAM 11%, Water 6500 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 40, 2.5, 3.5])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 80
# endblocks = 60
# Start of bestblock =  28 ns
#
# Average of r_base =  2.05555642153 nm
# Average of Theta =  141.786396105 deg
#
# Smallest error of theta = 0.0999811658944 deg
# sin(average) = 0.880258642824
# sin(average)*error = 0.00153605180253

# %%
n=5
b=11
c=7000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=80
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
        
omit=60 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=20 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])     
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s11[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s11[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s11[n]=t_average 
rbase_s11[n]=r_average

# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 


#PLOT FOR CONTACT ANGLE OF SAM 11% & 7000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 145, 'SAM 11%, Water 7000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 7000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 1.5, 'SAM 11%, Water 7000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 120
# endblocks = 100
# Start of bestblock =  36 ns
#
# Average of r_base =  2.25540247519 nm
# Average of Theta =  141.665559352 deg
#
# Smallest error of theta = 0.09211009821 deg
# sin(average) = 0.845876263066
# sin(average)*error = 0.00135985139441

# %%
n=6
b=11
c=8000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=80
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
        
omit=46 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=20 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])     
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s11[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s11[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s11[n]=t_average 
rbase_s11[n]=r_average

# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error)


#PLOT FOR CONTACT ANGLE OF SAM 11% & 8000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 155, 'SAM 11%, Water 8000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 8000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 1, 'SAM 11%, Water 8000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 120
# endblocks = 100
# Start of bestblock =  39 ns
#
# Average of r_base =  2.29660641016 nm
# Average of Theta =  141.836930262 deg
#
# Smallest error of theta = 0.0268058560829 deg
# sin(average) = 0.87130735737
# sin(average)*error = 0.000407641537022

# %%
n=7
b=11
c=9000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=60
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
        
omit=40 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=20 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])     
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s11[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s11[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s11[n]=t_average 
rbase_s11[n]=r_average

# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 



#PLOT FOR CONTACT ANGLE OF SAM 11% & 8000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 165, 'SAM 11%, Water 9000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 8000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(10.5, 0.6, 'SAM 11%, Water 9000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 80
# endblocks = 60
# Start of bestblock =  29 ns
#
# Average of r_base =  2.40488916651 nm
# Average of Theta =  141.749549189 deg
#
# Smallest error of theta = 0.0849975091231 deg
# sin(average) = 0.856526471742
# sin(average)*error = 0.00127064536367

# %%
n=8
b=11
c=10000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=80
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
        
omit=60 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=60 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])     
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s11[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s11[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s11[n]=t_average 
rbase_s11[n]=r_average

# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 



#PLOT FOR CONTACT ANGLE OF SAM 11% & 10000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(25, 155, 'SAM 11%, Water 10000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 11% & 10000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(25, 1.0, 'SAM 11%, Water 10000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 159
# endblocks = 99
# Start of bestblock =  49 ns
#
# Average of r_base =  2.48170252744 nm
# Average of Theta =  142.182321732 deg
#
# Smallest error of theta = 0.112117968808 deg
# sin(average) = 0.87714593535
# sin(average)*error = 0.0017164234688

# %%
n=0
b=17
c=1000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
#print theta
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
        
omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=10 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])     
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s17[n] = sin(radians(t_average))*radians(t_error) 
################ TEST #################
### We will test another way to calculate the errorbars !!!!!!!
#errortheta_s17[n] = cos(radians(t_average)-t_error)-cos(radians(t_average))
#print "t_average=",t_average, ", t_error=",t_error 
#print "radians(t_average)=",radians(t_average)," = pi*",radians(t_average)/np.pi
#print "radians(t_average)-t_error=",radians(t_average)-t_error
#print "cos(radians(t_average)-t_error)=",cos(radians(t_average)-t_error)," = a"
#print "cos(radians(t_average))=",cos(radians(t_average))," = b"
#print "errorbar=",errortheta_s17[n],"= a-b"
#######################################
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s17[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s17[n]=t_average 
rbase_s17[n]=r_average

# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error)

#PLOT FOR CONTACT ANGLE OF SAM 17% & 1000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 125, 'SAM 17%, Water 1000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([30, 40, 103.5, 112.5])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 1000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.4, 'SAM 17%, Water 1000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 0.8, 2.4])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 80
# endblocks = 70
# Start of bestblock =  30 ns
#
# Average of r_base =  1.24320883109 nm
# Average of Theta =  141.026700041 deg
#
# Smallest error of theta = 0.478741674921 deg
# sin(average) = 0.950987504107
# sin(average)*error = 0.00794608877678

# %%
n=1
b=17
c=2000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
#print theta
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)


#start=50
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
        
omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=10 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])     
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s17[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s17[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s17[n]=t_average 
rbase_s17[n]=r_average

# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 



#PLOT FOR CONTACT ANGLE OF SAM 17% & 2000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 123, 'SAM 17%, Water 2000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
#plt.axis([0, 6, 0, 20])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 2000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.95, 'SAM 17%, Water 2000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 1.8, 3.0])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 80
# endblocks = 70
# Start of bestblock =  21 ns
#
# Average of r_base =  1.53534872882 nm
# Average of Theta =  141.579503845 deg
#
# Smallest error of theta = 0.0521224763716 deg
# sin(average) = 0.948405242655
# sin(average)*error = 0.000862772620795

# %%
n=2
b=17
c=3000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
        
omit=10 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=10 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])     
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s17[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s17[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s17[n]=t_average 
rbase_s17[n]=r_average

# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 


#PLOT FOR CONTACT ANGLE OF SAM 17% & 3000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 160, 'SAM 17%, Water 3000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 90, 180])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 3000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.2, 'SAM 17%, Water 3000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 1.0, 3.5])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 80
# endblocks = 70
# Start of bestblock =  34 ns
#
# Average of r_base =  1.73899206656 nm
# Average of Theta =  141.59484846 deg
#
# Smallest error of theta = 0.149973622979 deg
# sin(average) = 0.950203844566
# sin(average)*error = 0.00248719040651

# %%
n=3
b=17
c=4000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=24
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
        
omit=20 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=10 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])    
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s17[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s17[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s17[n]=t_average 
rbase_s17[n]=r_average

# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 


#PLOT FOR CONTACT ANGLE OF SAM 17% & 4000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 140, 'SAM 17%, Water 4000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 90, 150])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 4000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 1.9, 'SAM 17%, Water 4000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 1.5, 4])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 80
# endblocks = 70
# Start of bestblock =  21 ns
#
# Average of r_base =  1.9021776414 nm
# Average of Theta =  141.994160988 deg
#
# Smallest error of theta = 0.043996663748 deg
# sin(average) = 0.955092686368
# sin(average)*error = 0.000733402916016

# %%
n=4
b=17
c=5000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=30
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
        
omit=20 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=10 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])     
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s17[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s17[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s17[n]=t_average 
rbase_s17[n]=r_average

# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 



#PLOT FOR CONTACT ANGLE OF SAM 17% & 5000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 160, 'SAM 17%, Water 5000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 90, 175])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 5000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(11, 2.4, 'SAM 17%, Water 5000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 40, 2.2, 3.8])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 80
# endblocks = 70
# Start of bestblock =  29 ns
#
# Average of r_base =  2.05555642153 nm
# Average of Theta =  141.786396105 deg
#
# Smallest error of theta = 0.0287558086492 deg
# sin(average) = 0.952338679742
# sin(average)*error = 0.00047796310787

# %%
n=5
b=17
c=6500
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=40
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
        
omit=24 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=10 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])     
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s17[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s17[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s17[n]=t_average 
rbase_s17[n]=r_average

# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 


#PLOT FOR CONTACT ANGLE OF SAM 17% & 6500 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 190, 'SAM 17%, Water 6500 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 60, 90, 220])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 6500 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 3.1, 'SAM 17%, Water 6500 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 60, 3.0, 4.0])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 120
# endblocks = 110
# Start of bestblock =  54 ns
#
# Average of r_base =  2.25540247519 nm
# Average of Theta =  141.665559352 deg
#
# Smallest error of theta = 0.0552097864407 deg
# sin(average) = 0.936870795102
# sin(average)*error = 0.000902761721015

# %%
n=6
b=17
c=7000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=80
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
        
omit=40 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=10 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])     
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s17[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s17[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s17[n]=t_average 
rbase_s17[n]=r_average

# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 

#PLOT FOR CONTACT ANGLE OF SAM 17% & 7000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 150, 'SAM 17%, Water 7000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 60, 90, 170])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 7000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(21, 3.2, 'SAM 17%, Water 7000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 60, 3, 4.2])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 120
# endblocks = 110
# Start of bestblock =  43 ns
#
# Average of r_base =  2.29660641016 nm
# Average of Theta =  141.836930262 deg
#
# Smallest error of theta = 0.0249599280406 deg
# sin(average) = 0.946800275227
# sin(average)*error = 0.000412457373638

# %%
n=7
b=17
c=8000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=80
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
        
omit=40 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=10 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])     
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s17[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s17[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s17[n]=t_average 
rbase_s17[n]=r_average

# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 


#PLOT FOR CONTACT ANGLE OF SAM 17% & 8000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(25, 160, 'SAM 17%, Water 8000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 60, 90, 180])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 8000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(25, 1, 'SAM 17%, Water 8000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 60, 0.5, 5.0])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 120
# endblocks = 110
# Start of bestblock =  54 ns
#
# Average of r_base =  2.40488916651 nm
# Average of Theta =  141.749549189 deg
#
# Smallest error of theta = 0.021483584061 deg
# sin(average) = 0.954385586914
# sin(average)*error = 0.000357855729643

# %%
n=8
b=17
c=9000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=100
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
        
omit=50 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=10 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])     
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s17[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s17[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s17[n]=t_average 
rbase_s17[n]=r_average

# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 


#PLOT FOR CONTACT ANGLE OF SAM 17% & 9000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(25, 160, 'SAM 17%, Water 9000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 60, 90, 180])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 9000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(25, 1, 'SAM 17%, Water 9000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 60, 0.5, 5.0])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 120
# endblocks = 110
# Start of bestblock =  52 ns
#
# Average of r_base =  2.48170252744 nm
# Average of Theta =  142.182321732 deg
#
# Smallest error of theta = 0.0338361235713 deg
# sin(average) = 0.954445913617
# sin(average)*error = 0.000563649716432

# %%
n=9
b=17
c=10000
theta = array(angles[(b, c)])
rbase = array(radii[(b, c)])
nametheta = "thetas%sw%s.png" % (b,c)
namebaserad = "rads%sw%s.png" % (b,c)

#start=100
for m in range(20, len(theta)):
    if math.isnan(theta[m]):
        break
        
omit=80 #number of points at the beggining which shouldn't be taken into account to buid the average value
omitend=10 #number of points omitted at the end, so that when doing the block average the total interval doesn't get too small 

end = m
endblocks = m -omitend
print "end =", end
print "endblocks =", endblocks

# HERE WE SEARCH FOR THE STARTING POINT (start) OF THE BEST TIME INTERVAL TO GET THE SMALLEST ERROR IN THE CONTACT ANGLE COSINUS

error = np.zeros(endblocks-omit) #error will be the total error (of all the points taken each time we choose a different set of data to make the blocks)
average = np.zeros(endblocks-omit) # average is the same, but for the average
error = error.tolist()
j=0
# Loop for finding the "best" interval to do the block averaging
for i in range (omit, endblocks):
    average[j],error[j] = blockAverage((theta[i:end]),3)   
    #print "j= ", j , "i=", i, "end=", end, "error =", error[j] 
    error[j] = sin(radians(average[j]))*radians(error[j])     
    j = j+1  
bestblock = error.index(min(error))
start = bestblock + omit


# ONCE WE HAVE THE "BEST" INTERVAL WE CALCULATE THE AVERAGE OF THETA AND ITS ERRORBAR
t_average, t_error = blockAverage((theta[start:end]),3)  
errortheta_s17[n] = sin(radians(t_average))*radians(t_error) 
theta_avr = t_average*np.ones(end - start)

# WE DO THE SAME FOR r_base (AVERAGE AND ERRORBAR)
r_average, r_error = blockAverage((rbase[start:end]),3)
errorr_base_s17[n] = (1/(r_average**2))*r_error
rbase_avr = r_average*np.ones(end - start)
t_avr = t[start:end]

theta_s17[n]=t_average 
rbase_s17[n]=r_average

# Printing results...
print "Start of bestblock = " , (bestblock+omit)/2, "ns"
print " "
print "Average of r_base = ",rbase_s0[n],"nm"
print "Average of Theta = ", theta_s0[n],"deg"
print " "
print "Smallest error of theta =", t_error, "deg"
print "sin(average) =", sin(radians(t_average))
print "sin(average)*error =", sin(radians(t_average))*radians(t_error) 


#PLOT FOR CONTACT ANGLE OF SAM 17% & 10000 WATER MOLECULES. (Also saved to file)
plt.plot(t,theta,'ro')
plt.plot(t_avr, theta_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'$\theta_{mic}$ [deg]')
plt.suptitle(r'Contact Angle $\theta_{mic}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(25, 155, 'SAM 17%, Water 10000 molec.',style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 80, 90, 170])
pylab.savefig(nametheta)
plt.show()

#PLOT FOR BASE RADIUS OF SAM 17% & 10000 WATER MOLECULES.(Also saved to file)
plt.plot(t,rbase,'ro')
plt.plot(t_avr, rbase_avr, linewidth=2.5,)
plt.xlabel('time [ns]')
plt.ylabel(r'R$\ _{BASE} $ [nm]')
plt.suptitle(r'Base Radius R$\ _{BASE}$ vs. Time', fontsize=14, fontweight='bold')
#plt.title(r'Contact Angle $\theta$ vs. Time')
plt.text(25, 1.5, 'SAM 17%, Water 10000 molec.',style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0, 80, 1.0, 5.3])
pylab.savefig(namebaserad)
plt.show()
# Out:
# end = 159
# endblocks = 149
# Start of bestblock =  73 ns
#
# Average of r_base =  2.56747800206 nm
# Average of Theta =  142.232556651 deg
#
# Smallest error of theta = 0.0197955908334 deg
# sin(average) = 0.962539914616
# sin(average)*error = 0.000332555843947

# %%
def func(x, a, b):
    return a*x + b

# %%
#for n in range(0, 10):
#    errortheta_s0[n] = sin(radians(theta_s0[n]))*errortheta_s0[n]
#    errorr_base_s0[n] = (1/(rbase_s0[n]**2))*errorr_base_s0[n]
#    errortheta_s5[n] = sin(radians(theta_s5[n]))*errortheta_s5[n]
#    errorr_base_s5[n] = (1/(rbase_s5[n]**2))*errorr_base_s5[n]
#    #errortheta_s17[n] = sin(radians(theta_s17[n]))*errortheta_s17[n]
#    #errorr_base_s17[n] = (1/(rbase_s17[n]**2))*errorr_base_s17[n]
## When the results of the system with SAM 11% and 2000 molec. of water are calculated add the next loop to the previous one
#for n in range(0, 9):  
#    errortheta_s11[n] = sin(radians(theta_s11[n]))*errortheta_s11[n]
#    errorr_base_s11[n] = (1/(rbase_s11[n]**2))*errorr_base_s11[n]    
#    
print "errorr_base_s0 = ", errorr_base_s0
print "errortheta_s0 = ", errortheta_s0
print "errorr_base_s5 = ", errorr_base_s5
print "errortheta_s5 = ", errortheta_s5
print "errorr_base_s11 = ", errorr_base_s11
print "errortheta_s11 = ", errortheta_s11
print "errorr_base_s17 = ", errorr_base_s17
print "errortheta_s17 = ", errortheta_s17
#print "theta_s0 = ", theta_s0
#print "cos(radians(theta_s0))= ",cos(radians(theta_s0))
# Out:
# errorr_base_s0 =  [ 0.00069901  0.00189411  0.00056802  0.00105477  0.00152497  0.00065471
#   0.00133706  0.00060079  0.00065424  0.00024832]
# errortheta_s0 =  [ 0.00043697  0.00134117  0.0004486   0.00083524  0.00146455  0.00074042
#   0.00142146  0.00064217  0.00070532  0.00031783]
# errorr_base_s5 =  [  2.60500494e-04   2.37048656e-04   2.27044618e-04   8.74402586e-05
#    3.58069940e-04   1.12826290e-04   3.29712619e-04   7.77115113e-05
#    4.12059754e-05   2.80249247e-04]
# errortheta_s5 =  [ 0.00025813  0.00021682  0.00023603  0.000101    0.00036004  0.00011137
#   0.00065263  0.00019077  0.00013514  0.0004471 ]
# errorr_base_s11 =  [             nan   1.06343910e-03   3.40607290e-04   7.72086987e-05
#    4.73312409e-04   4.20532952e-04   1.23168067e-04   3.23832687e-04
#    3.73170268e-04]
# errortheta_s11 =  [        nan  0.00291771  0.00108121  0.00015749  0.00153605  0.00135985
#   0.00040764  0.00127065  0.00171642]
# ...

# %%
d = 0
namethetabaserad = "theta_r_s%s.png" % (d)
    
#First System to take into account (smallest droplet is number 0, the second smallest is number 1, etc.)
firstpt = 0
#Last System to take into account (biggest droplet is number 10, the second biggest is number 8, etc.)
lastpt = 10
x = 1/rbase_s0[firstpt:lastpt]
y = cos(radians(theta_s0[firstpt:lastpt]))
error_y = errortheta_s0[firstpt:lastpt]
error_x = errorr_base_s0[firstpt:lastpt]

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)

print "Line equation: a*x+b with a=", slope, "and b=", intercept
theta_results[0] = math.degrees(np.arccos(intercept))
sigma[0] = slope*(-52.7)

#txt = "$\Theta_{mac}$ = %s deg \n $\sigma$ = %s pN" % (int(theta_results[0]*100)/100.00,int(sigma[0]*100)/100.00)
txt = "$\Theta_{mac}$ = %s deg \n $\sigma$ = %s pN" % (round(theta_results[0]),round(sigma[0],2))

#PLOT for SAM 0% (Also saved to file)
plt.figure()
plt.errorbar(x, y,xerr=error_x, yerr=error_y,fmt='x', ecolor='red',elinewidth=1.5, color='black',markeredgewidth=1.5)
plt.plot(x, func(x, slope, intercept))
plt.xlabel('${R \ _{BASE}}^{-1}\ [ nm ^{-1} ]$')
plt.ylabel(r' $\cos\Theta_{mic}$ ')
plt.suptitle(r'$\cos\Theta_{mic}$ vs. ${R \ _{BASE}}^{-1}$ for SAM 0%', fontsize=14)
plt.text(0.7, -0.3, txt ,style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0.3, 0.9, -1.0, 0.0])
pylab.savefig(namethetabaserad)
plt.show()


print "Standard Error of Line Regression std_err = ", std_err
print "Arccos(intercept) = ", degrees(np.arccos(intercept))
print "Slope*(-52.7) = ", slope*(-52.7)
print " "
# To get coefficient of determination (r_squared)
print "(To get coefficient of determination: r-squared = ", r_value**2, ")"
# Out:
# Line equation: a*x+b with a= 0.0242474595464 and b= -0.797903541201
# Standard Error of Line Regression std_err =  0.00516676164846
# Arccos(intercept) =  142.930369061
# Slope*(-52.7) =  -1.27784111809
#
# (To get coefficient of determination: r-squared =  0.733546241395 )

# %%
d = 5
namethetabaserad = "theta_r_s%s.png" % (d)
 
#First System to take into account (smallest droplet is number 0, the second smallest is number 1, etc.)
firstpt = 0
#Last System to take into account (biggest droplet is number 10, the second biggest is number 8, etc.)
lastpt = 10
x = 1/rbase_s5[firstpt:lastpt]
y = cos(radians(theta_s5[firstpt:lastpt]))
error_y = errortheta_s5[firstpt:lastpt]
error_x = errorr_base_s5[firstpt:lastpt]

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print "Line equation: a*x+b with a=", slope, "and b=", intercept
theta_results[1] = degrees(np.arccos(intercept))
sigma[1] = slope*(-52.7)

#txt = "$\Theta_{mac}$ = %s deg \n $\sigma$ = %s pN" % (int(theta_results[1]*100)/100.00,int(sigma[1]*100)/100.00)
txt = "$\Theta_{mac}$ = %s deg \n $\sigma$ = %s pN" % (round(theta_results[1]),round(sigma[1],2))


#PLOT for SAM 5% (Also saved to file)
plt.figure()
#plt.errorbar(1/x, cos(radians(y)),xerr=errorr_base_s5, yerr=errortheta_s5,fmt='x', ecolor='red',elinewidth=1.5, color='black',markeredgewidth=1.5)
plt.errorbar(x, y,xerr=error_x, yerr=error_y,fmt='x', ecolor='red',elinewidth=1.5, color='black',markeredgewidth=1.5)
plt.plot(x, func(x, slope, intercept))
plt.xlabel('${R \ _{BASE}}^{-1}\ [ nm ^{-1} ]$')
plt.ylabel(r' $\cos\Theta_{mic}$ ')
plt.suptitle(r'$\cos\Theta_{mic} $ vs. $ {R \ _{BASE}}^{-1} $ for SAM 5%', fontsize=14)
plt.text(0.6, -0.5, txt ,style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
#plt.annotate("$\Theta$ = %s $\sigma$ = %s" % (theta_results[1],sigma[1]), xy=(0.55, -0.64),  xycoords='data', xytext=(-110, -90), textcoords='offset points',size=15,bbox=dict(boxstyle="round4,pad=.5", fc="0.8"),arrowprops=dict(arrowstyle="->",connectionstyle="angle,angleA=0,angleB=-90,rad=25"),)
plt.grid(True)
plt.axis([0.30, 0.80, -1.0, 0.0])
pylab.savefig(namethetabaserad)
plt.show()

print "Standard Error of Line Regression std_err = ", std_err
print "Arccos(intercept) = ", degrees(np.arccos(intercept))
print "Slope*(-52.7) = ", slope*(-52.7)
print " "
# To get coefficient of determination (r_squared)
print "(To get coefficient of determination: r-squared = ", r_value**2, ")"
# Out:
# Line equation: a*x+b with a= -0.0626222083617 and b= -0.672736812396
# Standard Error of Line Regression std_err =  0.0917874005314
# Arccos(intercept) =  132.278646338
# Slope*(-52.7) =  3.30019038066
#
# (To get coefficient of determination: r-squared =  0.0549844140034 )

# %%
d = 11
namethetabaserad = "theta_r_s%s.png" % (d)
    
#First System to take into account (smallest droplet is number 0, the second smallest is number 1, etc.)
firstpt = 0
#Last System to take into account (biggest droplet is number 10, the second biggest is number 8, etc.)
lastpt = 10
x = 1/rbase_s11[firstpt:lastpt]
y = cos(radians(theta_s11[firstpt:lastpt]))
error_y = errortheta_s11[firstpt:lastpt]
error_x = errorr_base_s11[firstpt:lastpt]

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)

print "Line equation: a*x+b with a=", slope, "and b=", intercept
theta_results[2] = math.degrees(np.arccos(intercept))
sigma[2] = slope*(-52.7)

#txt = "$\Theta_{mac}$ = %s deg \n $\sigma$ = %s pN" % (int(theta_results[2]*100)/100.00,int(sigma[2]*100)/100.00)
txt = "$\Theta_{mac}$ = %s deg \n $\sigma$ = %s pN" % (round(theta_results[0]),round(sigma[0],2))


#PLOT for SAM 11% (Also saved to file)
plt.figure()
plt.errorbar(x, y,xerr=error_x, yerr=error_y,fmt='x', ecolor='red',elinewidth=1.5, color='black',markeredgewidth=1.5)
plt.plot(x, func(x, slope, intercept))
plt.xlabel('${R \ _{BASE}}^{-1}\ [ nm ^{-1} ]$')
plt.ylabel(r' $\cos\Theta_{mic}$ ')
plt.suptitle(r'$\cos\Theta_{mic}$ vs. ${R \ _{BASE}}^{-1}$ for SAM 11%', fontsize=14)
plt.text(0.45, -0.3, txt ,style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0.25, 0.55, -1.0, 0.0])
pylab.savefig(namethetabaserad) 
plt.show()
# Out:
# Line equation: a*x+b with a= nan and b= nan

# %%
d = 17
namethetabaserad = "theta_r_s%s.png" % (d)
    
#First System to take into account (smallest droplet is number 0, the second smallest is number 1, etc.)
firstpt = 0
#Last System to take into account (biggest droplet is number 10, the second biggest is number 8, etc.)
lastpt = 10
x = 1/rbase_s17[firstpt:lastpt]
y = cos(radians(theta_s17[firstpt:lastpt]))
error_y = errortheta_s17[firstpt:lastpt]
error_x = errorr_base_s17[firstpt:lastpt]

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)

print "Line equation: a*x+b with a=", slope, "and b=", intercept
theta_results[3] = math.degrees(np.arccos(intercept))
sigma[3] = slope*(-52.7)

#txt = "$\Theta_{mac}$ = %s deg \n $\sigma$ = %s pN" % (int(theta_results[3]*100)/100.00,int(sigma[3]*100)/100.00)
txt = "$\Theta_{mac}$ = %s deg \n $\sigma$ = %s pN" % (round(theta_results[0]),round(sigma[0],2))


#PLOT for SAM 17% (Also saved to file)
plt.figure()
plt.errorbar(x, y,xerr=error_x, yerr=error_y,fmt='x', ecolor='red',elinewidth=1.5, color='black',markeredgewidth=1.5)
plt.plot(x, func(x, slope, intercept))
plt.xlabel('${R \ _{BASE}}^{-1}\ [ nm ^{-1} ]$')
plt.ylabel(r' $\cos\Theta_{mic}$ ')
plt.suptitle(r'$\cos\Theta_{mic}$ vs. ${R \ _{BASE}}^{-1}$ for SAM 17%', fontsize=14)
plt.text(0.38, -0.9, txt ,style='italic', bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
plt.grid(True)
plt.axis([0.20, 0.50, -1, 0])
pylab.savefig(namethetabaserad)
plt.show()
# Out:
# Line equation: a*x+b with a= -0.0580053462743 and b= -0.290488381155

# %%
plt.plot(percentages, theta_results, 'ro')
plt.plot(percentages, theta_results)
plt.ylabel(r' Macrosc. Contact Angle $ \Theta_{mac}$ [deg] ')##errortheta_s17[n] = sin(radians(t_average))*radians(t_error) ### We will test another way to calculate the errorbars !!!!!!!
errortheta_s17[n] = cos(radians(t_average)-t_error)-cos(radians(t_average))
plt.xlabel('OH- PERCENTAGE [%]')
plt.suptitle('Macroscopic Contact Angles vs. OH- Percentages' , fontsize=14, fontweight='bold')
plt.grid(True)
#plt.axis([0, 80, 3.4, 4.8])
pylab.savefig('C_Angles_OH.png')
plt.show()

# %%
##errortheta_s17[n] = sin(radians(t_average))*radians(t_error)  ### We will test another way to calculate the errorbars !!!!!!!
errortheta_s17[n] = cos(radians(t_average)-t_error)-cos(radians(t_average))
plt.plot(percentages, sigma, 'ro', k, xunits=radians)
plt.plot(percentages, sigma)
matplotlib.pyplot.axhline(y=0, xmin=0, xmax=50,linewidth=2, color='black')
plt.ylabel(r' $\sigma $ [pN]')
plt.xlabel('OH- PERCENTAGE [%]')
plt.suptitle('Line Tension vs. OH- Percentages' , fontsize=14, fontweight='bold')
plt.grid(True)
#plt.axis([0, 80, 3.4, 4.8])
pylab.savefig('Sigma_OH.png')
plt.show()

# %%
"""
Plot with radians from the basic_units mockup example package
This example shows how the unit class can determine the tick locating,
formatting and axis labeling.
"""
import numpy as np
from basic_units import radians, degrees, cos
from matplotlib.pyplot import figure, show

sigmay = [val*radians for val in np.arange(-6, 8, 0.01)]

sigmay = sigma/np.pi
fig = figure()
fig.subplots_adjust(hspace=0.3)

ax = fig.add_subplot(211)
line1, = ax.plot(percentages, sigmay, yunits=radians)

ax = fig.add_subplot(212)
line2, = ax.plot(percentages, sigma, yunits=degrees)

show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-248-d00ffeaf0305> in <module>()
#       7 """
#       8 import numpy as np
# ----> 9 from basic_units import radians, degrees, cos
#      10 from matplotlib.pyplot import figure, show
#      11
#
# ImportError: No module named basic_units

# %%
plt.plot([1,2,3], label="test1")
plt.plot([3,2,1], label="test2")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
print theta_results
# Out:
# [ 142.93036906  132.27864634           nan  106.88719695    0.        ]

# %%
print sigma
# Out:
# [-1.27784112  3.30019038         nan  3.05688175  0.        ]

# %%
>>> from scipy import stats
>>> import numpy as np
>>> x = np.random.random(10)
>>> y = np.random.random(10)
>>> slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
